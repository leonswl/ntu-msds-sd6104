# %% [markdown]
# # Violations

# %%
import pandas as pd
import re
from collections import Counter
#test2
# Load the dataset
file_path = "Food_Inspections_20250216.csv"  # Ensure the correct path
df = pd.read_csv(file_path, low_memory=False)

# Function to find pattern per row
def row_pattern(row_text):
    if not isinstance(row_text, str):
        return "missing"

    entries = [e.strip() for e in row_text.split("|") if e.strip()]
    structure = []
    for entry in entries:
        if re.match(r"\d+\.\s+.*?- Comments:", entry):
            structure.append("number.text-Comments")
        elif re.match(r"\d+\.\s+.*", entry):
            structure.append("number.text")
        else:
            structure.append("unknown")
    return " | ".join(structure)

# Apply function to all rows
df['Pattern_Structure'] = df['Violations'].apply(row_pattern)

# Count unique patterns
pattern_counts = Counter(df['Pattern_Structure'])

# Show most common patterns
print("Most common row patterns:")
for pattern, count in pattern_counts.most_common():
    print(f"{pattern}: {count} rows")

# Optional: see patterns per row
# print(df[['Violations', 'Pattern_Structure']])
# Out:
# Most common row patterns:
# missing: 79652 rows
# number.text-Comments | number.text-Comments | number.text-Comments: 33693 rows
# number.text-Comments | number.text-Comments: 33407 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 29251 rows
# number.text-Comments: 27404 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 22996 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 17296 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 12384 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 8847 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6240 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4305 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3024 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2187 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1481 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1089 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 791 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 541 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 420 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 340 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 239 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 172 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 127 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 75 rows
# number.text | number.text-Comments | number.text-Comments: 74 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 65 rows
# number.text: 64 rows
# number.text | number.text-Comments: 63 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments: 48 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 34 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 30 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 29 rows
# number.text-Comments | number.text | number.text-Comments: 26 rows
# number.text-Comments | number.text-Comments | number.text: 25 rows
# number.text-Comments | number.text: 24 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 24 rows
# number.text | number.text: 24 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 22 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 22 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 20 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 19 rows
# number.text | number.text | number.text | number.text | number.text: 19 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 19 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 18 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text: 18 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments: 18 rows
# number.text | number.text | number.text | number.text: 17 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 17 rows
# number.text | number.text | number.text: 16 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 15 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 14 rows
# number.text | number.text | number.text | number.text | number.text | number.text: 13 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 11 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 10 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments: 10 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 10 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 9 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 9 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text: 9 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 8 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 8 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 8 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 7 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 7 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 7 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 6 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 5 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 5 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 5 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 5 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 5 rows
# number.text-Comments | number.text | number.text: 5 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 5 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text | number.text-Comments | number.text: 4 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 4 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 4 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text | number.text-Comments | number.text | number.text-Comments: 3 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 3 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 2 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 2 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 2 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text: 2 rows
# number.text-Comments | number.text | number.text | number.text: 2 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 2 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text-Comments: 2 rows
# number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text: 2 rows
# number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 2 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 2 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text: 1 rows
# number.text | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments: 1 rows
# number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 1 rows
# number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text | number.text | number.text | number.text | number.text: 1 rows
# number.text | number.text | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text | number.text | number.text | number.text: 1 rows
# number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text | number.text | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text: 1 rows
# number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows
# number.text-Comments | number.text | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments | number.text-Comments: 1 rows

# %%
import pandas as pd
import re

# Sample data
file_path = "Food_Inspections_20250216.csv"  # Ensure the correct path
df = pd.read_csv(file_path, low_memory=False)

# Regex to detect correct format
valid_pattern = re.compile(r"^\d+\.\s+.*?- Comments:")

# Reason checks
def get_invalid_reason(segment):
    if not re.search(r"\d+\.", segment):
        return "Missing starting number"
    elif "- Comments:" not in segment:
        return "Missing '- Comments:'"
    else:
        return "Malformed format"

# Function to process each row
def analyze_violations(text):
    if not isinstance(text, str):
        return pd.Series({
            'PatternStatus': 'missing',
            'ViolationCount': 0,
            'InvalidSegments': '',
            'InvalidReasons': ''
        })

    segments = [seg.strip() for seg in text.split("|") if seg.strip()]
    invalid_segments = []
    reasons = []

    for seg in segments:
        if not valid_pattern.match(seg):
            invalid_segments.append(seg)
            reasons.append(get_invalid_reason(seg))

    return pd.Series({
        'PatternStatus': 'valid' if not invalid_segments else 'invalid',
        'ViolationCount': len(segments),
        'InvalidSegments': "; ".join(invalid_segments),
        'InvalidReasons': "; ".join(reasons)
    })

# Apply to the DataFrame
df[['PatternStatus', 'ViolationCount', 'InvalidSegments', 'InvalidReasons']] = df['Violations'].apply(analyze_violations)

# Show only the invalid rows
print("🔍 Invalid rows with detailed reasons:")
print(df[df['PatternStatus'] == 'invalid'][['Violations', 'ViolationCount', 'InvalidSegments', 'InvalidReasons']])
# Out:
# 🔍 Invalid rows with detailed reasons:
#                                                Violations  ViolationCount  \
# 54      1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...               5
# 469     2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...               8
# 773     2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...               2
# 775     5. PROCEDURES FOR RESPONDING TO VOMITING AND D...               9
# 823     1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...               7
# ...                                                   ...             ...
# 286630  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...              11
# 286723  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...              10
# 286755  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...               8
# 286793  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...               6
# 286794  5. PROCEDURES FOR RESPONDING TO VOMITING AND D...               9
#
#                                           InvalidSegments  \
# 54      1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# 469     57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING
# 773     53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...
# 775     36. THERMOMETERS PROVIDED & ACCURATE; 53. TOIL...
# 823     1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# ...                                                   ...
# 286630  56. ADEQUATE VENTILATION & LIGHTING; DESIGNATE...
# 286723  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...
# 286755  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# 286793          41. WIPING CLOTHS: PROPERLY USED & STORED
# 286794         52. SEWAGE & WASTE WATER PROPERLY DISPOSED
#
#                                       InvalidReasons
# 54                             Missing '- Comments:'
# 469                            Missing '- Comments:'
# 773                            Missing '- Comments:'
# 775     Missing '- Comments:'; Missing '- Comments:'
# 823                            Missing '- Comments:'
# ...                                              ...
# 286630                         Missing '- Comments:'
# 286723                         Missing '- Comments:'
# 286755                         Missing '- Comments:'
# 286793                         Missing '- Comments:'
# 286794                         Missing '- Comments:'
#
# [1091 rows x 4 columns]

# %%
invalid_rows = df[df['PatternStatus'] == 'invalid']
invalid_rows
# Out:
#         Inspection ID                                           DBA Name  \
# 54            2608106  STATION RESTAURANT AND BAR, VINNY'S PIZZA BAR,...
# 469           2497525                                EDIBLE ARRANGEMENTS
# 773           2604777                                PEET'S TEA & COFFEE
# 775           2312266                                             BP GAS
# 823           2545756                           FITTINGLY DELICIOUS, LLC
# ...               ...                                                ...
# 286630        2556682                                        TATAS TACOS
# 286723        2243530                                POMP & CIRCUMSTANCE
# 286755        2290421                         DUNKIN DONUTS/BASKIN ROBIN
# 286793        2362770                                         ASTER HALL
# 286794        2362915                                 Whole Foods Market
#
#                                                  AKA Name  License #  \
# 54      STATION RESTAURANT AND BAR, VINNY'S PIZZA BAR,...  2141717.0
# 469              EDIBLE ARRANGEMENTS OF CHICAGO-HYDE PARK  2622530.0
# 773                                   PEET'S TEA & COFFEE  2341239.0
# 775                                                BP GAS  2551845.0
# 823                                   FITTINGLY DELICIOUS  2495771.0
# ...                                                   ...        ...
# 286630                                        TATAS TACOS  2589789.0
# 286723                   BROKEN ENGLISH TACO PUB OLD TOWN  2348608.0
# 286755                       DUNKIN DONUTS/BASKIN ROBBINS  1675002.0
# 286793                          3-GREENS MARKET/ TOP GOLF  2589784.0
# 286794                                 Whole Foods Market  2340694.0
#
#         Facility Type             Risk                Address     City State  \
# 54         Restaurant    Risk 1 (High)        120 N CANAL ST   CHICAGO    IL
# 469        Restaurant    Risk 1 (High)  1465 E HYDE PARK BLVD  CHICAGO    IL
# 773        Restaurant  Risk 2 (Medium)   222 S RIVERSIDE PLZ   CHICAGO    IL
# 775     Grocery Store     Risk 3 (Low)     6308 N CENTRAL AVE  CHICAGO    IL
# 823        Restaurant    Risk 1 (High)  3939 W IRVING PARK RD  CHICAGO    IL
# ...               ...              ...                    ...      ...   ...
# 286630     Restaurant    Risk 1 (High)  4929 W IRVING PARK RD  CHICAGO    IL
# 286723     Restaurant    Risk 1 (High)        1400 N WELLS ST  CHICAGO    IL
# 286755     Restaurant  Risk 2 (Medium)       5205 N NAGLE AVE  CHICAGO    IL
# 286793     Restaurant    Risk 1 (High)     900 N MICHIGAN AVE  CHICAGO    IL
# 286794  Grocery Store    Risk 1 (High)    959 W FULLERTON AVE  CHICAGO    IL
#
#             Zip  ... Inspection Type             Results  \
# 54      60606.0  ...         Canvass  Pass w/ Conditions
# 469     60615.0  ...         Canvass  Pass w/ Conditions
# 773     60606.0  ...         Canvass  Pass w/ Conditions
# 775     60646.0  ...         Canvass  Pass w/ Conditions
# 823     60618.0  ...         Canvass                Fail
# ...         ...  ...             ...                 ...
# 286630  60641.0  ...         Canvass                Fail
# 286723  60610.0  ...         Canvass  Pass w/ Conditions
# 286755  60630.0  ...         Canvass  Pass w/ Conditions
# 286793  60611.0  ...         Canvass                Pass
# 286794  60614.0  ...         Canvass  Pass w/ Conditions
#
#                                                Violations   Latitude  \
# 54      1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.883872
# 469     2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.802344
# 773     2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.878582
# 775     5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.996372
# 823     1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.953552
# ...                                                   ...        ...
# 286630  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.953264
# 286723  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.907738
# 286755  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.975911
# 286793  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.899249
# 286794  5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.925268
#
#         Longitude                                  Location PatternStatus  \
# 54     -87.639940   (41.88387173662125, -87.63994016069968)       invalid
# 469    -87.589218  (41.802344169636754, -87.58921808934608)       invalid
# 773    -87.638579    (41.87858156072147, -87.6385786681057)       invalid
# 775    -87.764277   (41.99637159702214, -87.76427703822098)       invalid
# 823    -87.726673  (41.953551804435314, -87.72667299244584)       invalid
# ...           ...                                       ...           ...
# 286630 -87.751092   (41.953263831201625, -87.7510919961523)       invalid
# 286723 -87.634755   (41.90773847735842, -87.63475461836646)       invalid
# 286755 -87.787723   (41.97591106463358, -87.78772272010706)       invalid
# 286793 -87.624275   (41.89924859703626, -87.62427497820545)       invalid
# 286794 -87.653488  (41.925268275703296, -87.65348756413924)       invalid
#
#        ViolationCount                                    InvalidSegments  \
# 54                  5  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# 469                 8  57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING
# 773                 2  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...
# 775                 9  36. THERMOMETERS PROVIDED & ACCURATE; 53. TOIL...
# 823                 7  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# ...               ...                                                ...
# 286630             11  56. ADEQUATE VENTILATION & LIGHTING; DESIGNATE...
# 286723             10  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...
# 286755              8  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...
# 286793              6          41. WIPING CLOTHS: PROPERLY USED & STORED
# 286794              9         52. SEWAGE & WASTE WATER PROPERLY DISPOSED
#
#                                       InvalidReasons
# 54                             Missing '- Comments:'
# 469                            Missing '- Comments:'
# 773                            Missing '- Comments:'
# 775     Missing '- Comments:'; Missing '- Comments:'
# 823                            Missing '- Comments:'
# ...                                              ...
# 286630                         Missing '- Comments:'
# 286723                         Missing '- Comments:'
# 286755                         Missing '- Comments:'
# 286793                         Missing '- Comments:'
# 286794                         Missing '- Comments:'
#
# [1091 rows x 21 columns]

# %%
valid_rows = df[df['PatternStatus'] == 'valid']
valid_rows
# Out:
#         Inspection ID                            DBA Name  \
# 0             1106427                BLOOMING BUD DAYCARE
# 1             2608378                         Babas Halal
# 2             1106406            FIRST ZABIHA MEAT BAZAAR
# 3             2609909                        HAPPY MARKET
# 4             2609927          SAT KAIVAL FOOD INC/SUBWAY
# ...               ...                                 ...
# 287230        2610806                       HILTON O'HARE
# 287232        2610937            DAPPER'S EAST RESTAURANT
# 287234        2610409            ACE SUSHI @POTASH MARKET
# 287235        2610823                Kitchen Chicago, LLC
# 287236        2610068  HANNAH'S BRETZEL 227 W. MONROE LLC
#
#                                      AKA Name  License #       Facility Type  \
# 0                        BLOOMING BUD DAYCARE  2215789.0  Daycare Combo 1586
# 1                                 Babas Halal  2684170.0          Restaurant
# 2                    FIRST ZABIHA MEAT BAZAAR  2232559.0       Grocery Store
# 3                                HAPPY MARKET  2912802.0       Grocery Store
# 4                  SAT KAIVAL FOOD INC/SUBWAY  2728400.0          Restaurant
# ...                                       ...        ...                 ...
# 287230  HILTON O'HARE/ANDIAMO'S/CAFFE MERCATO  2647047.0          Restaurant
# 287232               DAPPER'S EAST RESTAURANT    12540.0          Restaurant
# 287234                              ACE SUSHI  2808766.0          Restaurant
# 287235                   Kitchen Chicago, LLC  2119905.0      Shared Kitchen
# 287236                       HANNAH'S BRETZEL  2428372.0          Restaurant
#
#                    Risk               Address     City State      Zip  ...  \
# 0         Risk 1 (High)    5715 N LINCOLN AVE  CHICAGO    IL  60659.0  ...
# 1         Risk 1 (High)      7901 S DAMEN AVE  CHICAGO    IL  60620.0  ...
# 2       Risk 2 (Medium)      2907 W DEVON AVE  CHICAGO    IL  60659.0  ...
# 3       Risk 2 (Medium)  2334 S WENTWORTH AVE  CHICAGO    IL  60616.0  ...
# 4         Risk 1 (High)       1916 S STATE ST  CHICAGO    IL  60616.0  ...
# ...                 ...                   ...      ...   ...      ...  ...
# 287230    Risk 1 (High)     11601 W TOUHY AVE  CHICAGO    IL  60666.0  ...
# 287232    Risk 1 (High)     2901 W ADDISON ST  CHICAGO    IL  60618.0  ...
# 287234    Risk 1 (High)        875 N STATE ST  CHICAGO    IL  60610.0  ...
# 287235    Risk 1 (High)      324 N LEAVITT ST  CHICAGO    IL  60612.0  ...
# 287236    Risk 1 (High)       227 W MONROE ST  CHICAGO    IL  60606.0  ...
#
#                 Inspection Type             Results  \
# 0                       License                Pass
# 1                     Complaint                Fail
# 2                       License                Fail
# 3                       Canvass  Pass w/ Conditions
# 4                       Canvass                Pass
# ...                         ...                 ...
# 287230    Canvass Re-Inspection                Pass
# 287232  Complaint Re-Inspection                Pass
# 287234                  Canvass                Pass
# 287235                  Canvass                Pass
# 287236                  Canvass                Pass
#
#                                                Violations   Latitude  \
# 0       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.985390
# 1       1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.750189
# 2       11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  41.997401
# 3       2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.849954
# 4       36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.856053
# ...                                                   ...        ...
# 287230  43. IN-USE UTENSILS: PROPERLY STORED - Comment...  42.008751
# 287232  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  41.946553
# 287234  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.898878
# 287235  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  41.887434
# 287236  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.880539
#
#         Longitude                                  Location PatternStatus  \
# 0      -87.698734   (41.98538950526786, -87.69873407149943)         valid
# 1      -87.672986  (41.750189342293375, -87.67298583977204)         valid
# 2      -87.702385   (41.99740137039031, -87.70238538227812)         valid
# 3      -87.632094   (41.84995400192252, -87.63209419559098)         valid
# 4      -87.627311   (41.85605269621059, -87.62731125804903)         valid
# ...           ...                                       ...           ...
# 287230 -87.906874   (42.00875076599798, -87.90687413400109)         valid
# 287232 -87.700536     (41.94655282616904, -87.700535765616)         valid
# 287234 -87.628111    (41.89887819742381, -87.6281111483033)         valid
# 287235 -87.681849   (41.88743405025222, -87.68184949426895)         valid
# 287236 -87.634592   (41.88053924995021, -87.63459246351388)         valid
#
#        ViolationCount  InvalidSegments InvalidReasons
# 0                   4
# 1                  19
# 2                  15
# 3                   4
# 4                   2
# ...               ...              ...            ...
# 287230              4
# 287232              2
# 287234              2
# 287235              2
# 287236              1
#
# [206494 rows x 21 columns]

# %%
valid_rows.groupby('ViolationCount').count()
# Out:
#                 Inspection ID  DBA Name  AKA Name  License #  Facility Type  \
# ViolationCount
# 1                       27404     27404     27213      27403          27372
# 2                       33407     33407     33253      33405          33377
# 3                       33693     33693     33531      33688          33664
# 4                       29251     29251     29121      29250          29235
# 5                       22996     22996     22864      22996          22984
# 6                       17296     17296     17204      17296          17289
# 7                       12384     12384     12331      12384          12376
# 8                        8847      8847      8800       8844           8842
# 9                        6240      6240      6203       6240           6238
# 10                       4305      4305      4282       4305           4303
# 11                       3024      3024      3014       3024           3023
# 12                       2187      2187      2180       2187           2185
# 13                       1481      1481      1477       1481           1481
# 14                       1089      1089      1081       1089           1089
# 31                            1        1           1         1          1
# 33                            3        3           3         3          3
# 34                            2        2           2         2          2
# 35                            1        1           1         1          1
#
#                 Location  PatternStatus  InvalidSegments  InvalidReasons
# ViolationCount
# 1                  27266          27404            27404           27404
# 2                  33244          33407            33407           33407
# 3                  33571          33693            33693           33693
# 4                  29163          29251            29251           29251
# 5                  22927          22996            22996           22996
# 6                  17262          17296            17296           17296
# 7                  12360          12384            12384           12384
# 8                   8823           8847             8847            8847
# 9                   6226           6240             6240            6240
# 10                  4300           4305             4305            4305
# 11                  3018           3024             3024            3024
# 12                  2187           2187             2187            2187
# 13                  1479           1481             1481            1481
# 14                  1089           1089             1089            1089
# 15                   790            791              791             791
# 16                   541            541              541             541
# 17                   420            420              420             420
# 18                   340            340              340             340
# 19                   239            239              239             239
# 20                   172            172              172             172
# 21                   127            127              127             127
# 22                    75             75               75              75
# 23                    65             65               65              65
# 24                    34             34               34              34
# 25                    19             19               19              19
# 26                    22             22               22              22
# 27                    18             18               18              18
# 28                     8              8                8               8
# 29                     6              6                6               6
# 30                     6              6                6               6
# 31                     1              1                1               1
# 33                     3              3                3               3
# 34                     2              2                2               2
# 35                     1              1                1               1

# %%
pd.DataFrame(df[df['PatternStatus'] == 'invalid'][['Violations', 'ViolationCount', 'InvalidSegments', 'InvalidReasons']]).to_csv('InvalidSegments.csv')

# %%
missing_rows = df[df['PatternStatus'] == 'missing']
len(missing_rows['Violations'])
# Out:
# 79652

# %%
import pandas as pd
import re

# Load your CSV
df = pd.read_csv("Food_Inspections_20250216.csv")  # Adjust filename if needed

# Function to extract and analyze violations
def extract_violations(row):
    violation_text = row.get('Violations', '')
    row_index = row.name

    if pd.isna(violation_text):
        return []

    parts = [v.strip() for v in violation_text.split('|') if v.strip()]
    pattern = r"(?P<number>\d+)\.\s+(?P<text>.+?)\s+-\s+Comments:\s+(?P<comment>.+)"

    extracted = []
    for part in parts:
        match = re.match(pattern, part)
        combined = row.drop(labels=['Violations']).to_dict()
        combined['raw_violation'] = part

        if match:
            v = match.groupdict()
            combined['violation_number'] = v['number']
            combined['violation_text'] = v['text']
            combined['violation_comment'] = v['comment']
            combined['parse_error'] = False
            combined['error_reason'] = ""
        else:
            # Attempt to detect error reason
            if not re.search(r"\d+\.", part):
                reason = "missing violation number"
            elif "Comments:" not in part:
                reason = "missing 'Comments:'"
            else:
                reason = "general format mismatch"
            
            combined['violation_number'] = None
            combined['violation_text'] = None
            combined['violation_comment'] = None
            combined['parse_error'] = True
            combined['error_reason'] = reason

        extracted.append(combined)
    return extracted

# Process each row
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(extract_violations(row))

# Create the final DataFrame
violations_expanded_df = pd.DataFrame(expanded_rows)

# Save to CSV
violations_expanded_df.to_csv("Food_Inspections_Violations_Expanded.csv", index=False)

print("✅ Done! File saved as: Food_Inspections_Violations_Expanded.csv")
# Out:
# ✅ Done! File saved as: Food_Inspections_Violations_Expanded.csv

# %% [markdown]
# # License #

# %%
import pandas as pd

# Load your Excel file
df = pd.read_csv("Food_Inspections_20250216.csv")  # Update filename if needed

# Function to validate License # pattern
def license_pattern(value):
    if pd.isna(value):
        return "missing"
    elif isinstance(value, (int, float)) and not pd.isnull(value):
        return "numeric"
    elif isinstance(value, str):
        if value.isdigit():
            return "numeric"
        else:
            return "non-numeric string"
    else:
        return "unknown format"

# Apply function to each row in the 'License #' column
df['License_Pattern'] = df['License #'].apply(license_pattern)

# Count occurrences
pattern_counts = df['License_Pattern'].value_counts()

# Show invalid ones
invalid_rows = df[df['License_Pattern'] != 'numeric']

# Display results
print("🔎 License # Pattern Summary:")
print(pattern_counts)

print("\n❌ Rows with invalid License # format:")
print(invalid_rows[['License #', 'License_Pattern']])
# Out:
# 🔎 License # Pattern Summary:
# License_Pattern
# numeric    287219
# missing        18
# Name: count, dtype: int64
#
# ❌ Rows with invalid License # format:
#         License # License_Pattern
# 5707          NaN         missing
# 31473         NaN         missing
# 76251         NaN         missing
# 108186        NaN         missing
# 123035        NaN         missing
# 137611        NaN         missing
# 168473        NaN         missing
# 210537        NaN         missing
# 213577        NaN         missing
# 232201        NaN         missing
# 234026        NaN         missing
# 235864        NaN         missing
# 254046        NaN         missing
# 255822        NaN         missing
# 260126        NaN         missing
# 266439        NaN         missing
# 278851        NaN         missing
# 281377        NaN         missing

# %% [markdown]
# # Inspection ID

# %%
import pandas as pd

# Load your Excel file
df = pd.read_csv("Food_Inspections_20250216.csv")  # Update filename if needed

# Function to validate License # pattern
def license_pattern(value):
    if pd.isna(value):
        return "missing"
    elif isinstance(value, (int, float)) and not pd.isnull(value):
        return "numeric"
    elif isinstance(value, str):
        if value.isdigit():
            return "numeric"
        else:
            return "non-numeric string"
    else:
        return "unknown format"

# Apply function to each row in the 'License #' column
df['InspectionID_Pattern'] = df['Inspection ID'].apply(license_pattern)

# Count occurrences
pattern_counts = df['InspectionID_Pattern'].value_counts()

# Show invalid ones
invalid_rows = df[df['InspectionID_Pattern'] != 'numeric']

# Display results
print("🔎 InspectionID_Pattern Pattern Summary:")
print(pattern_counts)

print("\n❌ Rows with invalid InspectionID_Pattern format:")
print(invalid_rows[['Inspection ID', 'InspectionID_Pattern']])
# Out:
# 🔎 InspectionID_Pattern Pattern Summary:
# InspectionID_Pattern
# numeric    287237
# Name: count, dtype: int64
#
# ❌ Rows with invalid InspectionID_Pattern format:
# Empty DataFrame
# Columns: [Inspection ID, InspectionID_Pattern]
# Index: []

# %% [markdown]
# # Facility Type

# %%
import pandas as pd

# Load your Excel file
df = pd.read_csv("Food_Inspections_20250216.csv")  # Update filename if needed

# Count missing values
missing_facility = df['Facility Type'].isna().sum()

# Get distinct non-null values
facility_types = df['Facility Type'].dropna().unique()

# Output
print("🏢 Distinct Facility Types:")
for val in sorted(facility_types):
    print("-", val)
print(f"🔸 Missing Facility Type values: {missing_facility}")
# Out:
# 🏢 Distinct Facility Types:
# - (REHAB CENTER)
# - (convenience store)
# - (gas station)
# - 1005 NURSING HOME
# - 1023
# - 1023 CHILDERN'S SERVICE S FACILITY
# - 1023 CHILDERN'S SERVICES FACILITY
# - 1023 CHILDREN'S SERVICES FACILITY
# - 1023-CHILDREN'S SERVICES FACILITY
# - 1475 LIQUOR
# - 15 monts to 5 years old
# - 1584-DAY CARE ABOVE 2 YEARS
# - A-Not-For-Profit Chef Training Program
# - ADULT DAY SERVICE
# - ADULT DAYCARE
# - AFTER SCHOOL CARE
# - AFTER SCHOOL PROGRAM
# - ALTERNATIVE SCHOOL
# - ARCHDIOCESE
# - ART CENTER
# - ART GALLERY
# - ART GALLERY W/WINE AND BEER
# - ASSISSTED LIVING
# - ASSISTED LIVING
# - Adult Family Care Center
# - Airport Lounge
# - Animal Shelter Cafe Permit
# - Assisted Living
# - Assisted Living Senior Care
# - BAKERY/ RESTAURANT
# - BAKERY/DELI
# - BAKERY/GROCERY
# - BANQUET
# - BANQUET FACILITY
# - BANQUET HALL
# - BANQUET HALL/CATERING
# - BANQUET ROOM
# - BAR
# - BAR/GRILL
# - BEFORE AND AFTER SCHOOL PROGRAM
# - BEVERAGE/SILVERWARE WAREHOUSE
# - BOOK STORE
# - BOWLING LANES/BANQUETS
# - BOYS AND GIRLS CLUB
# - BREWERY
# - BUTCHER SHOP
# - BUTCHER, DELI
# - Bakery
# - Banquet
# - Banquet Dining
# - Banquet Hall
# - Banquet rooms
# - Banquet/kitchen
# - CAFE
# - CAFE/STORE
# - CAFETERIA
# - CANDY MAKER
# - CANDY SHOP
# - CANDY STORE
# - CANDY/GELATO
# - CAR WASH
# - CAT/LIQUOR
# - CATERED EVENTS
# - CATERED LIQUOR
# - CATERING/BANQUET
# - CATERING/CAFE
# - CELL PHONE STORE
# - CHARITY AID KITCHEN
# - CHARTER
# - CHARTER SCHOOL
# - CHARTER SCHOOL CAFETERIA
# - CHARTER SCHOOL/CAFETERIA
# - CHICAGO PARK DISTRICT
# - CHILDERN ACTIVITY FACILITY
# - CHILDERN'S SERVICES  FACILITY
# - CHILDRENS SERVICES FACILITY
# - CHINESE HERBS
# - CHURCH
# - CHURCH (FOOD PANTRY)
# - CHURCH (SPECIAL EVENTS)
# - CHURCH KITCHEN
# - CHURCH/AFTER SCHOOL PROGRAM
# - CHURCH/DAY CARE
# - CHURCH/SPECIAL EVENT
# - CHURCH/SPECIAL EVENTS
# - CITY OF CHICAGO COLLEGE
# - CLOTHING STORE
# - COFFEE  SHOP
# - COFFEE AND/OR DRINKS
# - COFFEE CART
# - COFFEE KIOSK
# - COFFEE ROASTER
# - COFFEE SHOP
# - COFFEE VENDING MACHINE
# - COFFEE/TEA
# - COLD STORAGE FACILITY
# - COLD/FROZEN FOOD STORAGE
# - COLLEGE
# - COMMIASARY
# - COMMISARY
# - COMMISSARY
# - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
# - CONVENIENCE
# - CONVENIENCE STORE
# - CONVENIENCE/GAS STATION
# - CONVENIENT STORE
# - CONVNIENCE STORE
# - COOKING CLASS
# - COOKING SCHOOL
# - CPS (CHARTER)
# - CULINARY ARTS SCHOOL
# - CULINARY CLASS ROOMS
# - CULINARY KITCHEN
# - CULINARY SCHOOL
# - CUSTOM POULTRY SLAUGHTER
# - Cafeteria
# - Candy
# - Catering
# - Catering and Wholesale
# - Children's Services Facility
# - Church
# - Church Kitchen
# - Coffee shop
# - Commissary
# - Convenience Store
# - DAY CARE
# - DAY CARE 1023
# - DAY CARE 2-14
# - DAYCARE
# - DAYCARE 1586
# - DAYCARE 2 YRS TO 12 YRS
# - DAYCARE 2-6, UNDER 6
# - DAYCARE 6 WKS-5YRS
# - DAYCARE COMBO
# - DELI/BAKERY
# - DINING HALL
# - DISTILLERY WITH TASTING ROOM
# - DISTRIBUTION CENTER
# - DISTRIBUTOR
# - DOLLAR & GROCERY STORE
# - DOLLAR STORE
# - DOLLAR STORE WITH GROCERY
# - DOLLAR TREE
# - DRUG STORE
# - DRUG STORE/GROCERY
# - DRUG STORE/W/ FOOD
# - DRUG/FOOD STORE
# - Day Care Combo (1586)
# - Daycare (2 - 6 Years)
# - Daycare (2 Years)
# - Daycare (Under 2 Years)
# - Daycare Above and Under 2 Years
# - Daycare Combo 1586
# - Daycare Night
# - Deli
# - Dollar store
# - ENTERTAINMENT VENUE
# - EVENT CENTER
# - EVENT SPACE
# - EVENT VENU
# - EXERCISE AND NUTRITION BAR
# - FARMER'S MARKET
# - FITNESS CENTER
# - FITNESS STUDIO
# - FLEA MARKET
# - FOOD BOOTH
# - FOOD HALL
# - FOOD PANTRY
# - FOOD PANTRY/CHURCH
# - FREE FOOD PANTRY
# - FRENCH MARKET SPACE
# - FROZEN DESSERT PUSHCARTS
# - FROZEN DESSERTS DISPENSER -NON MOTORIZED
# - FROZEN DESSERTS DISPENSER-NON-MOTORIZED
# - FURNITURE STORE
# - Food Pantry
# - Food Vending Machines
# - GAS STATION
# - GAS STATION /GROCERY
# - GAS STATION /SUBWAY MINI MART.
# - GAS STATION FOOD STORE
# - GAS STATION STORE
# - GAS STATION/ GROCERY STORE
# - GAS STATION/CONVENIENCE STORE
# - GAS STATION/FOOD
# - GAS STATION/GROCERY
# - GAS STATION/MINI MART
# - GAS STATION/RESTAURANT
# - GAS STATION/STORE
# - GAS STATION/STORE GROCERY
# - GAS/MINI MART
# - GELATO SHOP
# - GENERAL STORE
# - GOLF COURSE
# - GOLF COURSE CONNCESSION STAND
# - GREENHOUSE
# - GROCERY
# - GROCERY & LIQUOR STORE
# - GROCERY & RESTAURANT
# - GROCERY AND BUTCHER
# - GROCERY STORE
# - GROCERY STORE / GAS STATION
# - GROCERY STORE /PHARMACY
# - GROCERY STORE PLUS WIRELESS STORE
# - GROCERY STORE/ RESTAURANT
# - GROCERY STORE/BAKERY
# - GROCERY STORE/COOKING SCHOOL
# - GROCERY STORE/DELI
# - GROCERY STORE/GAS STATION
# - GROCERY STORE/RESTAURANT
# - GROCERY STORE/TAQUERIA
# - GROCERY(GAS STATION)
# - GROCERY/ RESTAURANT
# - GROCERY/BAKERY
# - GROCERY/CAFE
# - GROCERY/DELI
# - GROCERY/DRUG STORE
# - GROCERY/GAS STATION
# - GROCERY/LIQUOR
# - GROCERY/LIQUOR STORE
# - GROCERY/RESTAURANT
# - GROCERY/SERVICE GAS STATION
# - GROCERY/TAQUERIA
# - GYM
# - GYM STORE
# - Gas station
# - Gift Shop
# - Golden Diner
# - Grocery & Restaurant
# - Grocery Store
# - Grocery(Sushi prep)
# - HAIR SALON
# - HEALTH CARE STORE
# - HEALTH CENTER
# - HEALTH CENTER/NUTRITION CLASSES
# - HEALTH FOOD STORE
# - HELICOPTER TERMINAL
# - HERBAL
# - HERBAL DRINKS
# - HERBAL LIFE
# - HERBAL LIFE SHOP
# - HERBAL MEDICINE
# - HERBAL REMEDY
# - HERBAL STORE
# - HERBALCAL
# - HERBALIFE
# - HERBALIFE STORE
# - HERBALIFE/ZUMBA
# - HIGH SCHOOL KITCHEN
# - HOOKA BAR
# - HOSTEL
# - HOT DOG CART
# - HOT DOG STATION
# - HOTEL
# - Hair Salon
# - Herabalife
# - Herbalife Nutrition
# - Hospital
# - ICE CREAM
# - ICE CREAM PARLOR
# - ICE CREAM SHOP
# - Ice cream
# - Illegal Vendor
# - Internet Cafe
# - JUICE AND SALAD BAR
# - JUICE BAR
# - JUICE BAR/GROCERY
# - KIDS CAFE
# - KIOSK
# - KITCHEN DEMO
# - Kids Cafe'
# - LAUNDROMAT
# - LINITED BUSINESS
# - LIQOUR BREWERY TASTING
# - LIQUOR CONSUMPTION ON PREMISES.
# - LIQUOR STORE
# - LIQUOR/COFFEE KIOSK
# - LIQUOR/GROCERY STORE/BAR
# - LIQUORE STORE/BAR
# - LIVE POULTRY
# - LIVE POULTRY SLAUGHTER
# - LIVE POULTRY SLAUGHTER FACILITY
# - LONG TERM CARE FACILITY
# - LOUNGE/BANQUET HALL
# - Laundromat
# - Liquor
# - Live Poultry
# - Long Term Care
# - Long Term Care Facility
# - Long-Term Care
# - Long-Term Care Facility
# - Lounge
# - MAIN KITCHEN
# - MASSAGE BAR
# - MEXICAN CANDY STORE
# - MFD TRUCK
# - MILK TEA
# - MOBIL FOOD 1315
# - MOBIL FOOD PREPARED
# - MOBILE DESSERT CART
# - MOBILE DESSERT VENDOR
# - MOBILE DESSERTS VENDOR
# - MOBILE FOOD
# - MOBILE FOOD DESSERTS VENDOR
# - MOBILE FOOD TRUCK
# - MOBILE FROZEN DESSERT VENDOR
# - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
# - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
# - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
# - MOBILE PUSH CART
# - MOBILPREPARED FOOD VENDOR
# - MOVIE THEATER
# - MOVIE THEATRE
# - MUSIC VENUE
# - Meat Market
# - Mobile Food Dispenser
# - Mobile Food Preparer
# - Mobile Frozen Dessert Disp/Non-motorized
# - Mobile Frozen Dessert Dispenser_non  Motorized.
# - Mobile Frozen Desserts Vendor
# - Mobile Prepared Food Vendor
# - Mobile frozen dessert vendor
# - Museum/Gallery
# - NAIL SHOP
# - NEWSSTAND
# - NIGHT CLUB
# - NON -PROFIT
# - NON-FOR PROFIT BASEMENT KIT
# - NORTHERLY ISLAND
# - NOT FOR PROFIT
# - NOT-FOR-PROFIT CLUB
# - NP-KIOSK
# - NURSING HOME
# - NUTRITION SHAKES
# - NUTRITION..SMOOTHIES/SHAKES
# - NUTRITION/HERBALIFE
# - Navy Pier Kiosk
# - Nutrition Store
# - OUTREACH CULINARY KITCHEN
# - Other
# - PACKAGED FOOD DISTRIBUTION
# - PACKAGED HEALTH FOODS
# - PACKAGED LIQUOR
# - PALETERIA
# - PALETERIA /ICECREAM SHOP
# - PANTRY
# - PASTRY SCHOOL
# - PASTRY school
# - PEDDLER
# - PHARMACY
# - POPCORN CORN
# - POPCORN SHOP
# - POULTRY SLAUGHTER
# - PRE PACKAGED
# - PREP INSIDE SCHOOL
# - PREPACAKAGED FOODS
# - PREPACKAGE MEAL DISTRIBUTOR (1006 Retail)
# - PRIVATE CLUB
# - PRIVATE EVENT SPACE
# - PRIVATE SCHOOL
# - PRODUCE STAND
# - PRODUCE VENDOR
# - PROTEIN SHAKE BAR
# - PUBLIC SHCOOL
# - PUSH CARTS
# - PUSHCART
# - Pool
# - Pop-Up Establishment Host-Tier II
# - Pop-Up Establishment Host-Tier III
# - Pop-Up Food Establishment User-Tier I
# - Pop-Up Food Establishment User-Tier II
# - Poultry Slaughter
# - Private School
# - REGULATED BUSINESS
# - REHAB CENTER
# - REPACKAGING PLANT
# - REST/GROCERY
# - REST/ROOFTOP
# - RESTAURANT AND LIQUOR
# - RESTAURANT.BANQUET HALLS
# - RESTAURANT/BAKERY
# - RESTAURANT/BAR
# - RESTAURANT/BAR/THEATER
# - RESTAURANT/GROCERY
# - RESTAURANT/GROCERY STORE
# - RESTAURANT/HOSPITAL
# - RESTAURANT/LIQUOR
# - RESTUARANT AND BAR
# - RETAIL
# - RETAIL FOOD
# - RETAIL FOOD/GAS STATION
# - RETAIL SALES
# - RETAIL STORE
# - RETAIL STORE OFFERS COOKING CLASSES
# - RETAIL WINE/WINE BAR
# - RIVERWALK
# - RIVERWALK CAFE
# - ROOF TOP
# - ROOF TOPS
# - ROOFTOP
# - ROOFTOP PATIO
# - ROOFTOPS
# - ROOM SERVICE
# - Rest/GYM
# - Restaurant
# - Restaurant(protein shake bar)
# - SENIOR DAY CARE
# - SERVICE BAR/THEATRE
# - SERVICE GAS STATION
# - SHAKES/TEAS
# - SHARED KITCHEN USER (LONG TREM)
# - SHELTER
# - SLAUGHTER HOUSE/ GROCERY
# - SMOKEHOUSE
# - SOCIAL CLUB
# - SOUP KITCHEN
# - SPA
# - STADIUM
# - STORE
# - SUMMER FEEDING
# - SUMMER FEEDING PREP AREA
# - SUPPORTIVE LIVING
# - SUSHI COUNTER
# - School
# - School Cafeteria
# - Shared Kitchen
# - Shared Kitchen User (Long Term)
# - Shared Kitchen User (Short Term)
# - Shelter
# - Shuffleboard Club with Bar
# - Social Club
# - Special Event
# - TAP room/tavern/liquor store
# - TAVERN
# - TAVERN-LIQUOR
# - TAVERN/1006
# - TAVERN/LIQUOR
# - TAVERN/PACKAGED GOODS
# - TAVERN/RESTAURANT
# - TEA STORE
# - TEACHING SCHOOL
# - TEMPORARY KIOSK
# - TENT RSTAURANT
# - TEST KITCHEN/ STORAGE
# - THC INFUSED BAKERY
# - THEATER
# - THEATER/BAR
# - THEATRE
# - TOBACCO STORE
# - TRUCK
# - Tavern
# - Tavern/Bar
# - UNIVERSITY CAFETERIA
# - UNLICENSED FACILITY
# - UNUSED STORAGE
# - URBAN FARM
# - VENDING COMMISSARY
# - VENDING MACHINE
# - VFW HALL
# - WAREHOUSE
# - WEIGHT LOSS PROGRAM
# - WHOLESALE & RETAIL
# - WHOLESALE BAKERY
# - WINE STORE
# - WINE TASTING BAR
# - WRIGLEY ROOFTOP
# - Wholesale
# - Wrigley Roof Top
# - after school program
# - bakery/restaurant
# - banquet hall
# - banquets
# - banquets/room service
# - bar
# - blockbuster video
# - butcher shop
# - cafeteria
# - candy/gelato
# - coffee
# - coffee shop
# - convenience
# - convenience store
# - convenience/drug store
# - cooking school
# - day spa
# - dollar store
# - donut shop
# - drug treatment facility
# - employee kitchen
# - fish market
# - fitness center
# - gas station
# - grocery
# - grocery & restaurant
# - grocery/butcher
# - grocery/dollar store
# - hair salon
# - health club
# - hooka lounge
# - incubator
# - liquor store
# - live butcher
# - meat packing
# - newsstand
# - night club
# - private school
# - religious
# - school cafeteria
# - smoothie bar
# - snack shop
# - tavern
# - tavern/restaurant
# - theater
# - unlicensed facility
# - video store
# - warehouse
# - watermelon house
# - weight loss program
# - youth housing
# 🔸 Missing Facility Type values: 5197

# %% [markdown]
# # Risk

# %%
missing_risk = df['Risk'].isna().sum()
risk_levels = df['Risk'].dropna().unique()
print("\n⚠️ Distinct Risk Levels:")
for val in sorted(risk_levels):
    print("-", val)
print(f"🔸 Missing Risk values: {missing_risk}")
# Out:
# ⚠️ Distinct Risk Levels:
# - All
# - Risk 1 (High)
# - Risk 2 (Medium)
# - Risk 3 (Low)
# 🔸 Missing Risk values: 88

# %% [markdown]
# # City

# %%
missing_city = df['City'].isna().sum()
city_levels = df['City'].dropna().unique()
print("\n⚠️ Distinct City Levels:")
for val in sorted(city_levels):
    print("-", val)
print(f"🔸 Missing City values: {missing_city}")
# Out:
# ⚠️ Distinct City Levels:
# - 312CHICAGO
# - ALGONQUIN
# - ALSIP
# - BANNOCKBURNDEERFIELD
# - BERWYN
# - BLOOMINGDALE
# - BLUE ISLAND
# - BOLINGBROOK
# - BRIDGEVIEW
# - BROADVIEW
# - BROOKFIELD
# - BURBANK
# - BURNHAM
# - CALUMET CITY
# - CCHICAGO
# - CH
# - CHARLES A HAYES
# - CHCHICAGO
# - CHCICAGO
# - CHICAGO
# - CHICAGO HEIGHTS
# - CHICAGO.
# - CHICAGOC
# - CHICAGOCHICAGO
# - CHICAGOI
# - CHICAGOO
# - CHicago
# - CICERO
# - COUNTRY CLUB HILLS
# - Chicago
# - DES PLAINES
# - EAST HAZEL CREST
# - ELK GROVE VILLAGE
# - ELMHURST
# - EVANSTON
# - EVERGREEN
# - EVERGREEN PARK
# - FRANKFORT
# - GLEN ELLYN
# - GLENCOE
# - GRAYSLAKE
# - GRIFFITH
# - HAMMOND
# - HIGHLAND PARK
# - INACTIVE
# - JUSTICE
# - LAKE BLUFF
# - LAKE ZURICH
# - LANSING
# - LOMBARD
# - LOS ANGELES
# - MATTESON
# - MAYWOOD
# - MERRILLVILLE
# - MERRIVILLE
# - MORTON GROVE
# - Maywood
# - NAPERVILLE
# - NEW HOLSTEIN
# - NEW YORK
# - NILES NILES
# - Norridge
# - OAK LAWN
# - OAK PARK
# - OLYMPIA FIELDS
# - OOLYMPIA FIELDS
# - PALOS PARK
# - PLAINFIELD
# - ROSEMONT
# - SCHAUMBURG
# - SCHILLER PARK
# - SKOKIE
# - STREAMWOOD
# - SUMMIT
# - TINLEY PARK
# - TORRANCE
# - WADSWORTH
# - WESTERN SPRINGS
# - WESTMONT
# - WHEATON
# - WHITING
# - WILMETTE
# - WORTH
# - alsip
# - chicago
# - chicagoBEDFORD PARK
# 🔸 Missing City values: 164

# %% [markdown]
# # State

# %%
missing_state = df['State'].isna().sum()
state_levels = df['State'].dropna().unique()
print("\n⚠️ Distinct State Levels:")
for val in sorted(state_levels):
    print("-", val)
print(f"🔸 Missing State values: {missing_state}")
# Out:
# ⚠️ Distinct State Levels:
# - CA
# - CO
# - IL
# - IN
# - NY
# - WI
# 🔸 Missing State values: 58

# %% [markdown]
# # Inspection Type

# %%
missing_InspectionType = df['Inspection Type'].isna().sum()
InspectionType_levels = df['Inspection Type'].dropna().unique()
print("\n⚠️ Distinct State Levels:")
for val in sorted(InspectionType_levels):
    print("-", val)
print(f"🔸 Missing State values: {missing_InspectionType}")
# Out:
# ⚠️ Distinct State Levels:
# - 1315 license reinspection
# - ADDENDUM
# - ASSESSMENT
# - Business Not Located
# - CANVAS
# - CANVASS
# - CANVASS FOR RIB FEST
# - CANVASS RE INSPECTION OF CLOSE UP
# - CANVASS SCHOOL/SPECIAL EVENT
# - CANVASS SPECIAL EVENTS
# - CANVASS/SPECIAL EVENT
# - CHANGED COURT DATE
# - CITF
# - CLOSE-UP/COMPLAINT REINSPECTION
# - CORRECTIVE ACTION
# - COVID COMPLAINT
# - Canvass
# - Canvass Re-Inspection
# - Complaint
# - Complaint Re-Inspection
# - Complaint-Fire
# - Complaint-Fire Re-inspection
# - Consultation
# - DAY CARE LICENSE RENEWAL
# - Duplicated
# - FIRE
# - FIRE/COMPLAIN
# - HACCP QUESTIONAIRE
# - Illegal Operation
# - KIDS CAFE
# - KITCHEN CLOSED FOR RENOVATION
# - Kids Cafe'
# - LICENSE
# - LICENSE CANCELED BY OWNER
# - LICENSE CONSULTATION
# - LICENSE DAYCARE 1586
# - LICENSE RENEWAL FOR DAYCARE
# - LICENSE RENEWAL INSPECTION FOR DAYCARE
# - LICENSE REQUEST
# - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
# - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
# - LICENSE WRONG ADDRESS
# - LICENSE/NOT READY
# - LIQOUR TASK FORCE NOT READY
# - LIQUOR CATERING
# - License
# - License Re-Inspection
# - License consultation
# - License-Task Force
# - NO ENTRY
# - NO ENTRY-SHORT COMPLAINT)
# - No Entry
# - No entry
# - Non-Inspection
# - Not Ready
# - O.B.
# - OUT OF BUSINESS
# - OWNER SUSPENDED OPERATION/LICENSE
# - Out of Business
# - POSSIBLE FBI
# - Package Liquor 1474
# - Pre-License Consultation
# - RE-INSPECTION OF CLOSE-UP
# - RECALL INSPECTION
# - REINSPECTION
# - REINSPECTION OF 48 HOUR NOTICE
# - Recent Inspection
# - Recent inspection
# - SFP
# - SFP RECENTLY INSPECTED
# - SFP/COMPLAINT
# - SFP/Complaint
# - SMOKING COMPLAINT
# - SPECIAL TASK FORCE
# - Sample Collection
# - Short Form Complaint
# - Short Form Fire-Complaint
# - Special Events (Festivals)
# - Special Task Force
# - Summer Feeding
# - Suspected Food Poisoning
# - Suspected Food Poisoning Re-inspection
# - TASK FORCE LIQUOR (1481)
# - TASK FORCE LIQUOR 1470
# - TASK FORCE LIQUOR 1474
# - TASK FORCE NIGHT
# - TASK FORCE NOT READY
# - TASK FORCE PACKAGE GOODS 1474
# - TASK FORCE PACKAGE LIQUOR
# - TASKFORCE
# - TASTE OF CHICAGO
# - TAVERN 1470
# - TWO PEOPLE ATE AND GOT SICK.
# - Tag Removal
# - Task Force Liquor 1475
# - Task Force Liquor Catering
# - Task Force for liquor 1474
# - Task force liquor inspection 1474
# - citation re-issued
# - error save
# - expansion
# - finish complaint inspection from 5-18-10
# - fire complaint
# - license
# - license task 1474
# - no entry
# - out ofbusiness
# - sfp/complaint
# - task force
# - task force(1470) liquor tavern
# 🔸 Missing State values: 1

# %% [markdown]
# # Results

# %%
missing_Results = df['Results'].isna().sum()
Resultse_levels = df['Results'].dropna().unique()
print("\n⚠️ Distinct State Levels:")
for val in sorted(Resultse_levels):
    print("-", val)
print(f"🔸 Missing State values: {missing_Results}")
# Out:
# ⚠️ Distinct State Levels:
# - Business Not Located
# - Fail
# - No Entry
# - Not Ready
# - Out of Business
# - Pass
# - Pass w/ Conditions
# 🔸 Missing State values: 0

# %% [markdown]
# # latitude longitude location

# %%
import pandas as pd
import re

# Load the Excel file
df = pd.read_csv("Food_Inspections_20250216.csv")  # Adjust filename if needed

# === Validation functions ===

def check_latitude(val):
    if pd.isna(val):
        return "missing"
    try:
        lat = float(val)
        if -90 <= lat <= 90:
            return "valid"
        else:
            return "out of range"
    except:
        return "not a number"

def check_longitude(val):
    if pd.isna(val):
        return "missing"
    try:
        lon = float(val)
        if -180 <= lon <= 180:
            return "valid"
        else:
            return "out of range"
    except:
        return "not a number"

def check_location(val):
    if pd.isna(val):
        return "missing"
    if not isinstance(val, str):
        return "not a string"
    
    match = re.match(r"\(\s*(-?\d+\.\d+)\s*,\s*(-?\d+\.\d+)\s*\)", val)
    if not match:
        return "pattern mismatch"
    
    lat, lon = float(match.group(1)), float(match.group(2))
    if not (-90 <= lat <= 90):
        return "latitude out of range"
    if not (-180 <= lon <= 180):
        return "longitude out of range"
    
    return "valid"

# === Apply validation functions ===
df['Latitude_Status'] = df['Latitude'].apply(check_latitude)
df['Longitude_Status'] = df['Longitude'].apply(check_longitude)
df['Location_Status'] = df['Location'].apply(check_location)

# === Count invalid reasons ===
lat_counts = df['Latitude_Status'].value_counts()
lon_counts = df['Longitude_Status'].value_counts()
loc_counts = df['Location_Status'].value_counts()

# === Display summary ===
print("📊 Invalid Reason Counts:")

print("\n🧭 Latitude Issues:")
print(lat_counts[lat_counts.index != 'valid'])

print("\n🗺️ Longitude Issues:")
print(lon_counts[lon_counts.index != 'valid'])

print("\n📍 Location Issues:")
print(loc_counts[loc_counts.index != 'valid'])
# Out:
# 📊 Invalid Reason Counts:
#
# 🧭 Latitude Issues:
# Latitude_Status
# missing    978
# Name: count, dtype: int64
#
# 🗺️ Longitude Issues:
# Longitude_Status
# missing    978
# Name: count, dtype: int64
#
# 📍 Location Issues:
# Location_Status
# missing    978
# Name: count, dtype: int64

# %% [markdown]
# # Zip	Inspection Date

# %%
import pandas as pd

# Load your file
df = pd.read_csv("Food_Inspections_20250216.csv", dtype={"Zip": str})

# === Zip Validation ===
def check_zip(val):
    if pd.isna(val):
        return "missing"
    val_str = str(val).strip()
    if not val_str.isdigit():
        return "not numeric"
    if len(val_str) != 5:
        return "not 5-digit"
    return "valid"

# === Inspection Date Validation ===
def check_inspection_date(val):
    if pd.isna(val):
        return "missing"
    try:
        pd.to_datetime(val, errors='raise')
        return "valid"
    except:
        return "invalid date format"

# Apply functions
df['Zip_Status'] = df['Zip'].apply(check_zip)
df['InspectionDate_Status'] = df['Inspection Date'].apply(check_inspection_date)

# Count invalids
zip_counts = df['Zip_Status'].value_counts()
date_counts = df['InspectionDate_Status'].value_counts()

# Display
print("📦 ZIP Code Issues:")
print(zip_counts[zip_counts.index != 'valid'])

print("\n📅 Inspection Date Issues:")
print(date_counts[date_counts.index != 'valid'])
# Out:
# 📦 ZIP Code Issues:
# Zip_Status
# missing    39
# Name: count, dtype: int64
#
# 📅 Inspection Date Issues:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # Address

# %%
import pandas as pd
import re

# Load your CSV
df = pd.read_csv("Food_Inspections_20250216.csv")  # Update path if needed

# Address validation function
def check_address(addr):
    if pd.isna(addr):
        return "missing"
    
    addr = addr.strip()

    # Basic regex:
    # - Starts with number or number-range
    # - Optional direction (N, S, E, W)
    # - Street name + suffix
    pattern = r"^(\d+(-\d+)?)(\s+[NSEW])?\s+[\w\s\.\(\)'\-/]+$"

    if re.match(pattern, addr, flags=re.IGNORECASE):
        return "valid"
    else:
        # Diagnose why it's invalid
        if not re.match(r"^\d+(-\d+)?", addr):
            return "missing or invalid street number"
        elif not re.search(r"\s+[A-Za-z]+", addr):
            return "missing street name"
        else:
            return "general format issue"

# Apply
df['Address_Status'] = df['Address'].apply(check_address)

# Count issues
address_issue_counts = df['Address_Status'].value_counts()

# Show result
print("📬 Address Issue Summary:")
print(address_issue_counts[address_issue_counts.index != 'valid'])

# Optional: Show invalid addresses
invalid_addresses = df[df['Address_Status'] != 'valid'][['Address', 'Address_Status']]
print("\n❌ Invalid Address Rows:")
print(invalid_addresses)
# Out:
# 📬 Address Issue Summary:
# Address_Status
# general format issue                342
# missing or invalid street number      4
# Name: count, dtype: int64
#
# ❌ Invalid Address Rows:
#                         Address        Address_Status
# 67        2812-1/2 W DEVON AVE   general format issue
# 293           2169A S CHINA PL   general format issue
# 1347     5255 S State (1E&W) ST  general format issue
# 2169       2812-1/2 W DEVON AVE  general format issue
# 2579         2140A S ARCHER AVE  general format issue
# ...                         ...                   ...
# 279363     1570-1/2 N DAMEN AVE  general format issue
# 280196     12450 S State (1E&W)  general format issue
# 280799     1570-1/2 N DAMEN AVE  general format issue
# 283008  12302 S State St (1E&W)  general format issue
# 283869       806- 808 E 79TH ST  general format issue
#
# [346 rows x 2 columns]

# %%
invalid_addresses.to_csv('invalid_addresses.csv')

# %% [markdown]
# # DBA Name

# %%
import pandas as pd

# Load your Excel file
df = pd.read_csv("Food_Inspections_20250216.csv")  # Update filename if needed

# Count missing values
missing_DBA_Name= df['DBA Name'].isna().sum()

# Get distinct non-null values
DBA_Name_types = df['DBA Name'].dropna().unique()

# Output
print("🏢 Distinct DBA Name Types:")
for val in sorted(DBA_Name_types):
    print("-", val)
print(f"🔸 Missing Facility Type values: {missing_DBA_Name}")
# Out:
# 🏢 Distinct DBA Name Types:
# - "GENGHIS" EATERY
# - "M" BAR
# - "SWEET SUGAH" CATERING BOUTIQUE
# - #1 CHINA EXPRESS, LTD.
# - #1 CHOP SUEY
# - #1 CHOP SUEY RESTAURANT
# - #1 CHOP SUEY RESTAURANT, INC
# - #1 DELI
# - #1 DELI, INC
# - #1 MARKET INC.
# - #1 WOK N ROLL
# - 'C' A CATERING AND EVENT COMPANY
# - 'LAINE'S BAKE SHOP
# - (K)  NEW  RESTAURANT
# - 1 2 3 EXPRESS
# - 1 FISH 2 FISH
# - 1 JACKPOT MINI MART, INC.
# - 1 KARACHI CHAAT HOUSE
# - 1 N WACKER KITCHEN AND BAR
# - 1 SHOP & SAVE, INC
# - 1 STOP  FOOD MART
# - 1 STOP & SHOP INC.
# - 1 STOP MARKET & GRILL
# - 1,200 SQ.FT. - YEMEN RESTAURANT, INC.
# - 1,4,3,7 SOUL RESTAURANT
# - 1-94 RIBS & GRILL
# - 10 PIN  BOWLING LOUNGE
# - 10 SOUTH MARKET
# - 100 PENNIES STORE
# - 1000 LIQUORS / BIG CITY TAP
# - 101 CLUB
# - 1021 MONTROSE
# - 103 CHICKEN & MORE, INC.
# - 103RD CITGO INC
# - 1053 W 103RD INC
# - 106 & HALSTED
# - 10640 S HALSTED
# - 10Q CHICKEN
# - 11 DEGREES NORTH
# - 11 DINING
# - 11 DINING, LLC
# - 11 DINING,LLC
# - 11 DINNING
# - 11-7 FOOD & LIQUOR
# - 1104 WABASH
# - 111 COFFEE BAR
# - 111 CONCESSION SHOP
# - 111 FOOD Z & Z
# - 111 MEXICAN GRILL
# - 111 TH FOOD & CELLULAR, INC
# - 111TH AND RACINE MARATHON, INC.
# - 111TH FOOD MART, INC.
# - 111TH STREET CLARK
# - 111TH STREET OTB
# - 111th STREET SUPER SAVE
# - 1154 FULTON MARKET
# - 1155 CAFETERIA
# - 116TH GAS & FOOD MART INC
# - 118TH STREET MARKET
# - 12 WEST ELM
# - 1200 GRILL
# - 1200 Herb'N Deli
# - 1200 JES FUELS,INC
# - 123 CONCESSION SHOP
# - 123 FOOD
# - 123 FOOD MARKET
# - 25 DEGREES
# - 260 SPORTS BAR
# - 267 FOODS
# - 26TH & KEDZIE GAS INC
# - 26TH CONVENIENT STORE, INC
# - 26TH DISCOUNT STORE INC
# - 26TH STREET SUGAR SHACK
# - 2715 WEST MADISON, LLC
# - 2750 RESTAURANT
# - 290 EXPRESS INC
# - 290 FOOD MART
# - 290 QUICK MART & TOBACCO
# - 2934 W DIVERSEY LLC
# - 2960 BEVERAGE CORPORATION
# - 2AM IZAKAYA
# - 2D RESTAURANT
# - 2H CAFE BAR
# - 3 ABEJAS
# - 3 ABEJAS CORP.
# - 3 ASIAN SISTERS
# - 3 BROTHERS FOOD MARKET, INC
# - 3 BROTHERS FOOD MART, INC.
# - 3 CHEFS CATERING, INC.
# - 3 GREENS MARKET
# - 3 JJJ'S BETTER TASTE JAMAICAN JERK RESTAURANT
# - 3 KING'S JERK & GOURMET EGG ROLLS LLC
# - 3 KINGS JERK & SOUL LLC
# - 3 M RESTAURANT, INC.
# - 3 R'S ORIENTAL FOOD MART
# - 3 SAUCES
# - 3 SMOKIN' SISTERS
# - 3 SQUARES
# - 3-PENNY CINEMA
# - 300 CONCESSION SHOP INC.
# - 300 CONVENIENCE
# - 303 MARKET
# - 31 FOOD & DOLLAR, INC.
# - 312 BEER GARDEN
# - 312 CHICAGO
# - 312 CHICAGO STYLE FOOD
# - 312 Chicago
# - 312 FISH MARKET
# - 3123 CLUB
# - 31ST FOOD MART
# - 325 BAKE
# - 33 CLUB
# - 333 S WABASH
# - 3330 KIMBALL, INC. dba BP
# - 3400 FOOD & LIQUOR
# - 3401 Y.D. INC
# - 34TH ST COFFE HOUSE
# - 3517 CAFE
# - 3517 N. SPAULDING AVE. CHI LLC
# - 3521 GRILL INC
# - 35TH & ASHLAND OIL, INC.
# - 35TH STREET GRILL, INC.
# - 35TH STREET INC.
# - 35TH STREET REDHOTS
# - 360 CHICAGO
# - 3600 COMMISSARY
# - 3639 LLC
# - 365 FOODMART CORPORATION
# - 365 SUPERMARKET INC
# - 3658 FIT DANCE
# - 37 N KEDZIE FOOD MART
# - 3756-58 W. NORTH, INC.
# - 38 LITTLE ANGELS HOME DAYCARE
# - 3811 PIRAMID INC
# - 3976 N ELSTON, INC.
# - 3GS BBQ RESTAURANT
# - 3J'S
# - 3JJJ'S BETTER TASTE JAMAICAN JERK RESTAURANT
# - 3LP
# - 3RD BASE STEAK AND HOAGIES LLC
# - 4 & 1 CANDY STORE
# - 4 - CAMINOS
# - 4 BANDERAS
# - 4 BROTHERS DISCOUNT STORE
# - 4 Brothers Food Mart Corp.
# - 4 CAMINOS RESTAURANT INC.
# - 4 EVER YOUNG DAY CARE,INC.
# - 4 GUYS SHOP
# - 4 HERMANOS
# - 4 HERMANOS TOO
# - 4 SEASONS
# - 4 SISTERS RESTAURANT
# - 4 SUYOS
# - 4 YOLKS,INC
# - 404 WINE BAR
# - 40s TF HEALTHY MEDITERRANEAN CUISINE
# - 40th ACRE CAFE
# - 418 FAMILY CHILDCARE CENTER
# - 42 N LATITUDE
# - 42 grams
# - 4211 CORPORATION
# - 4301 ALLSTYLE BUFFET
# - 4319 CITGO INC.
# - 4343 PETES FRESH MARKET
# - 437 RUSH
# - 43RD DAN RYAN CITGO
# - 43RD FOOD & MORE
# - 43RD FOOD & TOBACCO, INC.
# - 43RD ST. FOOD PANTRY
# - 4401 FOOD & FUEL, INC.
# - 44TH WHOLESALE & RETAIL
# - 45TH & CICERO, INC.
# - 45TH FOOD MART
# - 47 MINI MART
# - 4700 PETE'S FRESH MARKET
# - 4744 CORP
# - 47TH &  DAMEN MARTHON
# - 47TH & CALIFORNIA SHELL
# - 47TH CALIFORNIA SHELL
# - 47TH DOLLAR FOOD & MART
# - 47TH FOOD & TOBACCO
# - 47TH GROCERY,INC
# - 47TH ST CANTINA
# - 47TH STREET SUMMERTIME CANTINA
# - 47th NUTRITION
# - 481725
# - 4884 S ARCHER INC,.
# - 4902 N. PULASKI KLOKCAFE
# - 49ER'S S.A.C.
# - 4JS
# - 4LW CAFE
# - 4PLUS1
# - 5 BOROUGHS PIZZA & SUBS
# - 5 BROTHERS MARKET
# - 5 Boroughs Pizza Company
# - 5 GUYS MARKET, INC.
# - 5 LOAVES EATERY
# - 5 PEA'S IN A POD LEARNING ACADEMY LLC.
# - 5 RABANITOS
# - 5 RABANITOS HYDE PARK
# - 5 STAR CHICKEN & FISH
# - 5 STAR CHILDCARE DEVELOPMENT CENTER INC.
# - 5 STAR GRILL, INC.
# - 5 STAR INDIA
# - 5 STARS FOOD & TOBACCO INC.
# - 5 STARS MINI MART INC
# - 5 STARS STEAK, FISH & CHICKEN, INC
# - 50 50 GROCERY AND BEAUTY ON MADISON
# - 50 YARD LINE
# - 50/50 FOOD MART, INC.
# - 50/50 GROCERY & BEAUTY, INC.
# - 500 DEGREE PIZZERIA
# - 500 DEGRESS SOUL FOOD RESTAURANT
# - 5000 YRS FOODS INC
# - 501 CITGO INC
# - 505 MARKET
# - 5077 KIKO MEAT MARKET
# - 510 BELMONT TOWER INC.
# - 5100 CORP.
# - 515 N STATE STREET CHICAGO, LP
# - 5159 GRILL
# - 51ST QUICK MART & CELLULAR
# - 520 BP GAS
# - 53RD CORNER MART
# - 53RD FOOD MART, INC
# - 53RD STREET BICYCLE CENTER
# - 53RD STREET MINI MART
# - 54 FOOD & LIQUOR
# - 54 IN & OUT
# - 540 CAFE
# - 5411 EMPANADAS
# - 55TH & DAN RYAN SHELL
# - 55TH & PULASKI SHELL
# - 55TH GAS STATION
# - 55TH GAS STATION INC.
# - 55TH MAXWELL
# - 55TH SHELL MART
# - 55TH ST HAROLD'S & FRESH LEMONADE
# - 5659 W. DIVERSEY
# - 56TH STREET FAMILY KITCHEN
# - 56TH STREET HAROLD'S GRILL AND WAFFLES
# - 57 RIB HOUSE
# - 5747 FOOD AND DELI
# - 57TH FINEST
# - 57TH FOOD MART
# - 57TH STREET WINES
# - 57TH SUPERMARKET, INC.
# - 5800 NORTH CAFE
# - 5826 DIVISION FOOD
# - 59TH FISH & CHICKEN, INC.
# - A.SWEETS GIRL
# - A1 FOOD MART
# - A1 Food Mart
# - A1 GROCERY
# - A10
# - AA MINI MART
# - AAA  GROCERY STORE
# - AAA CATERING SERVICE
# - AAA CATERING SERVICES
# - AAA FOOD MARKET
# - AAA FOOD MART, INC.
# - AAA Food
# - AAA GROCERY
# - AAA GROCERY STORE
# - AAA MAXWELL STREET EXPRESS
# - AAA WHOLESALE INC
# - AADHYA GROCERY STORE
# - AAH YUMMI
# - AARONS F.O.F. BBQ & CATERING
# - AASHIRVAAD GROCERS
# - AASJM INC.
# - AB FOOD AND LIQUOR
# - AB STATE PETROLEUM, INC.
# - ABA/ THE DALCY
# - ABACUS 1
# - ABADIR CUSINE
# - ABARROTES EL JINETE
# - ABARROTES LUPITA, INC.
# - ABASOLO'S RESTAURANT
# - ABBASSI FOOD & LIQUOR INC
# - ABBEY PUB
# - ABBOTT  PARK GOLDEN DINER
# - ABBOTT ELEM. SCHOOL
# - ABC  ACADEMY INC
# - ABC & ME TODDLER CENTER,INC
# - ABC AND ME
# - ABC AND ME DAYCARE
# - ABC CHOICE
# - ABC CHOICE BODEGA
# - ABC DAYCARE & PRESCHOOL
# - ABC DELICIOUS INC
# - ABC DOLLAR PLUS
# - ABC DOLLAR PLUS & GROCERY, INC.
# - ABC LEARNING CENTER II
# - ABC LEARNING CENTER INC.
# - ABC Learning Tree
# - ABC PRESCHOOL, LTD.
# - ABCD ACADEMY FOR CHILDREN INC
# - ABDUL RAUF RAJPUT
# - ABE SUPERMARKET
# - ABE'S AND TOMMIE'S CARRYOUT
# - ABE'S CATERING
# - ABE'S IN & OUT
# - ABE'S SUPER DOG, INC.
# - ABEER FOOD MART
# - ABEL BRAMBLA
# - ABERDEEN
# - ABERDEEN FOOD STORE
# - ABES MARKET
# - ABH FOOD & LIQUOR INC
# - ABHIRUCHI
# - ABHIRUHHI FOOD
# - ABIGAIL'S ICE CREAM
# - ABIGAILS ICE CREAM
# - ABIHA FISH & CHICKEN SUB
# - ABIQUIU CAFE, INC
# - ABIQUIU CAFE,INC
# - ABM SUPERMARKET INC.
# - ABN AMRO SVCS - MAIN BANK
# - ABN AMRO SVCS - SVC CENTER
# - ABO NA WAS RESTAURANT
# - ABOLLA
# - ABOOD FOOD MARKET INC.
# - ABOU ANDRE LLC
# - ABOUNDANCE OF LOVE DAY CARE
# - ABOVE AND BEYOND
# - ABRAHAM LINCOLN FOOD
# - ABRAM GALE
# - ABS SUPPLIES & CATERING
# - ABSINTHE CAFE
# - ABU DAOUD
# - ABU HALAB
# - ABU HASAN GAS & MINI MART, INC.
# - ABU JENNA INC.
# - ABU NAWAS
# - ABU SHEDRAK'S RESTAURANT
# - ABUELOS TACOS
# - ABUNDANCE BAKERY
# - ABUNDANT RESTAURANT
# - ABYSSINIA RESTAURANT & FOOD MARKET
# - AC FOOD MART PLUS ,INC
# - AC MARRIOTT CHICAGO DOWNTOWN
# - ACADEMY BAKERY
# - ACADEMY FOR GLOBAL CITIZENSHIP CHARTER SCHOOL
# - AIR FORCE ACADEMY
# - AIR FRANCE
# - AIRE ANCIENT BATHS CHICAGO
# - AJ CONVENIENCE & TOBACCO
# - AJ FOOD
# - AJ LIQUOR INC
# - AJ MINI MART
# - AJ'S GRILL
# - AJ'S SPORT BAR & GRILL
# - AJAJA FOODS
# - AJAWAAH SWEETS
# - AJC VEGGIE, LLC
# - AJDIN RESTAURANT
# - AJE CAFE
# - AJI ICHIBAN STORE
# - AJIICHIBAN
# - AJK PANTRY
# - AJOYS GAS DEPOT
# - AK FOOD MART
# - AK FOOD MART & WIRELESS, INC.
# - AKA AVE 21
# - AKA ONI
# - AKAHOSHI RAMEN
# - AKARRASEL CHILD CARE CENTERS
# - AKAYTACOS
# - AKBAR BROTHERS INC
# - AKHIRAH'S PRALINE CANDIES
# - AKIBA-SCHECHTER JEWISH DAY SCHOOL
# - AL - JOUD INVESTMENT
# - AL AMIRA LLC
# - AL ANWAR FOOD MARKET
# - AL BAR B QUE
# - AL BAYAN GROCERY INC.
# - AL DENTE RESTAURANT INC
# - AL DORA COFFEE SHOP
# - AL FOOD MART, INC
# - AL HABIB RESTAURANT
# - AL HALAL ZAIQA
# - AL KABEER RESTAURANT
# - AL KHAYMEIH RESTAURANT
# - AL KHYAM RESTAURANT
# - AL KING MARKET, INC
# - AL MAIMANI FOOD
# - AL MARKAZ RESTAURANT
# - AL MEDINA RESTAURANT
# - AL MEDINA RESTAURANT & GRILL
# - AL NOOR MEAT & GROCERY
# - AL PRIMO CANTO
# - AL PRINCE DOLLAR INC
# - AL RABY HIGH SCHOOL
# - AL RAFEDAIN MEAT MARKET INC.,
# - AL SAFA
# - AL SAFA RESTAURANT LLC
# - AL SON DE MI TIERRA RESTAURANT INC.
# - AL SULTAN LIMITED
# - AL WALEEMA
# - AL WALI CONVENIENT STORE
# - AL'S
# - AL'S  FOOD & DELI
# - AL'S BEEF
# - AL'S BEEF RESTAURANT
# - AL'S FOOD MART
# - AL'S ITALIAN BEEF INC
# - AL'S MARKET STORE
# - AL'S PIZZA
# - AL'S PIZZA CHICAGO
# - AL'S PLACE
# - AL'S RIBS N THINGS
# - AL'S UNDER THE L
# - AL- RASHID-RESTAURANT & GRILL
# - AL-AMIN GROCERY
# - AL-ANDALUS GRILL
# - AL-DIAR RESTAURANT
# - AL-EMAAN GROCERS
# - AL-HAMD SWEET INC.
# - AL-KHYAM BAKERY
# - AL-NOOR DARBAR RESTAURANT
# - AL-WALY CONVENIENCE STORE
# - AL-ZAHRAA BAKERY
# - ALA ALABAD GROCERY STORE
# - ALA TOO CENTRAL ASIAN AND TURKISH RESTAURANT
# - ALABAMA & 4 SISTERS
# - ALABAMA KITCHEN INC.
# - ALABAMA'S
# - ALADDIN CLUB
# - ALADDIN FALAFEL HOUSE
# - ALADDIN'S EATERY
# - ALADDIN'S FOOD
# - ALAIN LOCKE CHARTER ACADEMY
# - ALAIN'S RESTAURANT
# - ALAMANA SUPER MARKET
# - ALAMO DRAFTHOUSE CINEMAS
# - ALAN'S GROCERY
# - ALANWAR FOOD MART
# - ALARMIST BREWING
# - ALASKA PALETERIA Y NEVENA 2
# - ALASKA PALETERIA Y NEVERIA
# - ALAWDA GROCERY INC
# - ALBA'S RESTAURANT
# - ALBANY  FOOD  MARKET
# - ALBANY CHILD CARE CENTER
# - ALBANY FOOD & LIQUORS
# - ALBANY LIQUORS AND FOOD
# - ALBANY MART & GRILL
# - ALBANY PARK CAMPUS/EDISON REGIONAL GIFTED CTR.
# - ALBANY PARK COMMUNITY CENTER
# - ALBANY PARK COMMUNITY CENTER,INCORPORATED
# - ALBANY PARK COMMUNITY CENTER-HEADSTART
# - ALBANY PARK FRESH MARKET INC
# - ALBANY PARK GROCERY, INC.
# - ALBANY PARK MEAT & GROCERY, INC.
# - ALBANY PLACE BAR & GRILL
# - ALBARAKA ICE CREAM
# - ALBATROSS WINE COMPANY
# - ALBAWRA FOOD & LIQUOR, INC.
# - ALBERT'S PLACE
# - ALBERTO'S PIZZA
# - ALBET INVESTMENTS
# - ALBET INVESTMENTS LTD
# - ALBOES
# - ALBUX MARKET
# - ALCATRACES
# - ALCATRAZ INCORPORATED
# - ALCOCER'S LOCAL SHOP
# - ALCOCK'S
# - ALCOCK'S INN
# - ALCOIRIS INC
# - ALCOOL MANAGEMENT LLC
# - ALCOTT EARLY LEARNING BRANCH
# - ALCOTT HIGH SCHOOL
# - ALDEN LINCOLN PK REHAB HLTH CT
# - ALDEN NORTHMOOR REHAB & HLTH
# - ALDEN NURSING CENTER
# - ALDEN NURSING CENTER PRINCETON
# - ALDEN NURSING CENTER WENTWORTH
# - ALDEN VILLAGE NORTH, INC.
# - ALDI
# - ALDI # 70
# - ALDI #28
# - ALDI #30
# - ALDI #79
# - ALDI #88
# - ALDI 16
# - ALDI CLYBOURN
# - ALDI FOODS #91
# - ALDI FOODS -STORE #04
# - ALDI FOODS STORE #2
# - ALDI FOODS STORE #26
# - ALDI FOODS STORE #30
# - ALDI FOODS STORE #90B
# - ALDI FOODS-STORE #27
# - ALDI INC # 62
# - ALDI INC #03
# - ALDI INC #06
# - ALDI INC #10
# - ALDI INC #53
# - ALDI INC #58
# - ALDI INC #64
# - ALDI INC #83
# - ALDI INC #92
# - ALDI INC STORE #62
# - ALDI INC STORE #90
# - ALDI INC STORE #95
# - ALDI INC STORE 14
# - ALDI INC. #96
# - ALDI INC.#94
# - ALDI STORE #13
# - ALDI STORE #32
# - ALDI'S
# - ALDI'S # 26
# - ALDI'S #08
# - ALDI'S #47
# - ALDI'S #93
# - ALDI'S FOODS BELMONT
# - ALDRIDGE
# - ALEBRIJES CAFE
# - ALEEN FOOD MART INC
# - ALEGRA
# - ALEGRE BAKERY, INC
# - ALEGRE RESTAURANT
# - ALEGRE RESTAURANT & BAR
# - ALEGRIA'S SEAFOOD
# - ALEISAWI FOOD MARKET
# - ALEJANDRA MEXICAN RESTAURANT
# - ALEJO'S BOATHOUSE CAFE
# - ALESSANDRO VOLTA ELEMENTARY
# - ALETEIA, INC.
# - ALEX 75 FOOD
# - ALEX 88 FOOD
# - ARAMARK@ LOYOLA SIMPSON  RESIDENTIAL
# - ARAMARK@LOYOLA HALAS CAFE
# - ARAMARL-FRESHII
# - ARAMI
# - ARAMI GO!
# - ARAMI/WOODGRAIN
# - ARANDA MEXICAN RESTAURANT
# - ARBELA RESTAURANT
# - ARBELLA
# - ARBOR
# - ARBOR INN INC
# - ARBOUR HEALTH CARE CENTER LTD
# - ARBRE NAIL SALON
# - ARBY'S ROAST BEEF
# - ARBY'S ROAST BEEF RESTAURANT
# - ARBYS
# - ARCADIA FOOD WINE & SPIRITS
# - ARCADIAN SUSHI, INC
# - ARCH VIEW RESTAURANT
# - ARCHDIOCESE OF CHICAGO FOOD SERVICE
# - ARCHER AMOCO
# - ARCHER AVENUE LEARNING STATION, INC
# - ARCHER B. P.
# - ARCHER BP
# - ARCHER C INC
# - ARCHER CAFE
# - ARCHER DISCOUNT STORE
# - ARCHER FUEL & MINI MART, INC.
# - ARCHER HEIGHTS HEALTHCARE LLC
# - ARCHER RESTAURANT
# - ARCHER SNACKS & TOBACCO
# - ARCHER TOBACCO & FOOD, INC.
# - ARCHER-NAGLE CITGO
# - ARCHI
# - ARCHIES
# - ARCHITECTURAL ARTIFACTS
# - ARCHWAY AMOCO
# - ARCLIGHT CINEMAS
# - ARCO
# - ARCO DE CUCHILLEROS INC
# - ARCO IRIS
# - ARCOIRIS ICE CREMA
# - ARDEN RESTAURANT
# - AREPA GEORGE
# - AREPA GEORGE CANTINA
# - AREPA PA LOS PANA, INC.
# - ARETHA'S DREAM
# - ARGENTINA FOODS
# - ARGO FOOD MARKET INC.
# - ARGO FOOD MART INC
# - ARGO TEA
# - ARGO TEA CAFE
# - ARGO TEA CAFE-OHARE T2
# - ARGO TEA CAFE-TRIBUNE TOWER
# - ARGO TEA UCH, LLC
# - ARGYLE EL BAKERY & DEL
# - ARGYLE EL BAKERY AND DELI
# - ARGYLE GROCERY, INC
# - ARIEL ACADEMY/NORTH KENWOOD OAKLAND SCHOOL
# - ARIGATO MARKET
# - ARISTA FOODS
# - ARISTO FOOD & LIQUOR
# - ARIZONA DOLLAR PLUS INC
# - ARKADASH CAFE
# - ARLO CHICAGO
# - ARMAN DOLLAR DISCOUNT MART
# - ARMAN'S PIIZZERIA
# - ARMAND'S PIZZA
# - ARMAND'S PIZZERIA
# - ARMAND'S VICTORY TAP
# - ARMANDO J DIAZ/TONY'S FOOD
# - ARMANDO'S
# - ARMANDO'S FINDER FOODS INC
# - ARMANDO'S Y SANTA BARBARA, INC
# - ARMANDOS EXPRESS
# - ARMANDS PIZZERIA
# - ARMANETTI DEPOT 11
# - ARMANETTI EXPRESS WINE- SPIRITS-FOOD
# - ARMANETTI WINE SHOPPE
# - ARMANI CAFFE' INC
# - ARMANI CORP
# - ARMED FORCES POST 8322
# - ARMITAGE & CALIFORNIA BP
# - ARMITAGE ALE HOUSE
# - ARMITAGE BAR & LIQUOR, INC
# - ARMITAGE COURTYARD CAFE
# - ARMITAGE FOOD
# - ARMITAGE FOOD MARKET
# - West Town Academy
# - West Town Bakery & Diner
# - West Town Deli
# - West Town Tavern
# - Weston's Coffee & Tap
# - Westside Health Authority
# - Westside Youth Tech ENTREPRENEUR
# - Westwood Village
# - What's Your Budget
# - Whipple Food & Grocery Store Inc.
# - Whirlyball
# - Whistler
# - White
# - White Hen Pantry
# - Whole Foods Market
# - Wild Goose Bar and Grill
# - Wildwood
# - Willow Cafe and Bistro
# - Wing Wah Lau
# - WingStop
# - Wingers
# - Wingstop
# - Winston's Sausage, Inc.
# - Woods
# - Woodson CPC
# - World's Finest Chocolate Inc.
# - Wrigleyville Rooftops
# - X POT
# - X-GOLF SOUTHLOOP
# - X-GOLF WRIGLEYVILLE
# - XANDO COFFEE & BAR / COSI SANDWICH BAR
# - XAVIER'S CLUB
# - XEL - HA'
# - XI'AN CUISINE WEST LOOP
# - XIAN DYNASTY CUISINE, LLC
# - XIANGLI XIANGQIN
# - XIAO MEI
# - XIAO MEI XING RESTAURANT
# - XIAOLONGKAN
# - XILIN ASSOCIATION
# - XIN XIN RESTAURANT
# - XL WIRELESS
# - XLIN ADULT DAYCARE CENTER
# - XMARKET
# - XO MARSHMALLOW
# - XOCHIMILCO MEXICAN RESTAURANT
# - XOCHIMILO
# - XOCHITL'S MEXICAN RESTAURANT
# - XOCO
# - XOCOME ANTOJERIA
# - XOCTLI MEXICAN RESTAURANT
# - XONG XONG EXPRESS
# - XPRESS FOOD MARKET, INC.
# - XPRESS FOOD MART
# - XS TENNIS & EDUCATION FOUNDATION
# - XSPORT FITNESS
# - XTRA HEALTH
# - XTREME BLENDS
# - XTREME RESTAURANT
# - XTY'S RESTAURANT
# - XUAN TEA
# - XURRO
# - Y & H FOOD MARKET,LTD.
# - Y & H FOODS INC
# - Y & K CONVENIENT STORE
# - Y & K LAUNDRY & CLEANERS. INC.
# - Y & S MARKET
# - Y B MIDWAY INC.
# - Y.Y HOT POT INC.
# - YA HWA RESTAURANT
# - YA KWANG
# - YA MBERRY'S KITCHEN INC.
# - YA YA MAS
# - YA YA MINI MART
# - YAAZ MINI MART
# - YABA'S FOOD AND GRILL
# - YABA'S QUICK MART
# - YACHT *57* FISH-WINGS-BURGER
# - YADA'S FLOWERS & GIFTS
# - YADO AFRICAN & CARIBBEAN MARKET
# - YADO AFRICAN AND CARRIBEAN MARKET
# - YAFAY FOOD MARKET, INC
# - YAK THAI CUISINE
# - YAK-ZIES BAR AND GRILL
# - YAKISOBA MISOYA
# - YAKUP BEY URI
# - YAKZIE'S BAR & GRILL
# - YALE APARTMENT
# - YALE FOOD MART
# - YAMATO FOOT MASSAGE
# - YAMBO
# - YAN BANG CAI
# - YANBANG CAI SICHUAN RESTAURANT
# - YANGOS GRILL FAMILY OWNED SINCE 1986
# - YANNI'S DOG
# - YANQUI LEON LLC
# - YAO
# - YAO'S CAFE
# - YAQUIDIOS RESTAURANT
# - YARD HOUSE
# - YARDBIRD SOUTHERN TABLE & BAR
# - YARITZA'S GROCERIES
# - YASEEN ZABIHA HALAL MEAT AND GROCERS
# - ZONA BURRITO
# - ZONA TIPICA LLC
# - ZOOM PIZZA FACTORY, INC.
# - ZOOTS
# - ZORA RESTAURANT
# - ZORBAS PASTRY SHOP
# - ZORIANA CANDY STORE INC.
# - ZORIN,INC.
# - ZOU ZOU
# - ZOUP
# - ZOUP!
# - ZOZO
# - ZU'S QUICK MART
# - ZUBAIR'S BP
# - ZUCCI'S EVENTS & DINING INC.
# - ZULLO'S INC.
# - ZULLO'S MARKETS, LLC
# - ZUZU WRAPS INC
# - ZYMI BAKERY INC
# - Zaqorta
# - Zaytune Mediterranean Grill
# - Zen Wine & Spirits
# - Zen rice and noodle,inc.
# - Zia's Social
# - Zia's Trattoria
# - Zip Z Express
# - Zoku Sushi
# - Zyggyz Grill
# - bbox
# - becks book store inc
# - ben tre cafe
# - bopNgrill
# - cafe  03  inc
# - caffe baci
# - cardona's 2
# - de - li - cious cafe
# - desert rose cafe
# - dolce casa cafe
# - e.a.t. spots
# - elinas cafe
# - food & paper supply co
# - goPuff
# - healthy life nutrition
# - howard groceries & plus
# - iCREAM
# - iO Theater
# - isla tropical
# - jaihind restaurant
# - k&a sweet tooth
# - lakeview food mart
# - landmark bagels
# - luna empanada shop
# - m. henry  LLC
# - mEAT ON CHESTNUT
# - markos tacos&cafe
# - mcdonalds
# - mi tortilla
# - morrison authentic southern cooking and pizzeria
# - mr.daniel's
# - ochoa grocery & liquors inc.
# - pars-persian store
# - payless food mart, inc
# - rendezvous bistro
# - ropa restaurant & wine bar
# - stockton
# - subway restaurant 1
# - tien giang restaurant
# - unknown
# - vitino pizzeria
# 🔸 Missing Facility Type values: 0

# %% [markdown]
# change all column capital?
# same DBA name should have same location? License #? Facility Type? address?City?	State?	Zip?

# %%
import pandas as pd
from fuzzywuzzy import process

# Load dataset
df = pd.read_csv("Food_Inspections_20250216.csv")

# Columns to clean
columns_to_clean = ['Facility Type', 'City', 'Address', 'Inspection Type']

# Dictionary to store grouped labels for display
all_grouped_labels = {}

# Function to clean one column
def clean_column_fuzzy(df, column_name):
    print(f"\n🔍 Processing column: {column_name}")
    
    # Step 1: Capitalize everything
    df[column_name] = df[column_name].astype(str).str.strip().str.upper()

    # Step 2: Get unique values
    unique_values = df[column_name].dropna().unique().tolist()

    # Step 3: Fuzzy group similar values
    grouped_map = {}     # raw -> cleaned
    grouped_labels = {}  # cleaned -> [originals]

    for value in unique_values:
        if value in grouped_map:
            continue  # Already grouped

        # Fuzzy match: similarity >= 85
        matches = process.extract(value, unique_values, limit=None)
        close_matches = [m for m, score in matches if score >= 85]

        canonical = close_matches[0]

        for match in close_matches:
            grouped_map[match] = canonical

        grouped_labels[canonical] = close_matches

    # Step 4: Create new cleaned column
    cleaned_col = f"{column_name} Cleaned"
    df[cleaned_col] = df[column_name].map(grouped_map)

    # Save grouping for display
    all_grouped_labels[column_name] = grouped_labels

    return df

# Apply to each target column
for col in columns_to_clean:
    df = clean_column_fuzzy(df, col)

# Save new CSV
df.to_csv("Food_Inspections_Cleaned.csv", index=False)
print("\n✅ Cleaned data saved as: Food_Inspections_Cleaned.csv")

# Show grouping results
for col, group_map in all_grouped_labels.items():
    print(f"\n📦 Grouped values for '{col}':")
    for canonical, group in group_map.items():
        if len(group) > 1:
            print(f"\n  → {canonical}:")
            for g in group:
                print(f"     - {g}")
# Out:
# C:\Users\A102730\AppData\Local\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 🔍 Processing column: Facility Type
#
# 🔍 Processing column: City
#
# 🔍 Processing column: Address

# %%
#pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from fuzzywuzzy import process

# Load dataset
df = pd.read_csv("Food_Inspections_20250216.csv")

# Columns to clean
columns_to_clean = ['Facility Type', 'City', 'Inspection Type']

# Dictionary to store grouped labels for display
all_grouped_labels = {}

# Function to clean one column
def clean_column_fuzzy(df, column_name):
    print(f"\n🔍 Processing column: {column_name}")
    
    # Step 1: Capitalize everything
    df[column_name] = df[column_name].astype(str).str.strip().str.upper()

    # Step 2: Get unique values
    unique_values = df[column_name].dropna().unique().tolist()

    # Step 3: Fuzzy group similar values
    grouped_map = {}     # raw -> cleaned
    grouped_labels = {}  # cleaned -> [originals]

    for value in unique_values:
        if value in grouped_map:
            continue  # Already grouped

        # Fuzzy match: similarity >= 85
        matches = process.extract(value, unique_values, limit=None)
        close_matches = [m for m, score in matches if score >= 85]

        canonical = close_matches[0]

        for match in close_matches:
            grouped_map[match] = canonical

        grouped_labels[canonical] = close_matches

    # Step 4: Create new cleaned column
    cleaned_col = f"{column_name} Cleaned"
    df[cleaned_col] = df[column_name].map(grouped_map)

    # Save grouping for display
    all_grouped_labels[column_name] = grouped_labels

    return df

# Apply to each target column
for col in columns_to_clean:
    df = clean_column_fuzzy(df, col)

# Save new CSV
df.to_csv("Food_Inspections_Cleaned.csv", index=False)
print("\n✅ Cleaned data saved as: Food_Inspections_Cleaned.csv")

# Show grouping results
for col, group_map in all_grouped_labels.items():
    print(f"\n📦 Grouped values for '{col}':")
    for canonical, group in group_map.items():
        if len(group) > 1:
            print(f"\n  → {canonical}:")
            for g in group:
                print(f"     - {g}")
# Out:
# C:\Users\A102730\AppData\Local\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 🔍 Processing column: Facility Type
#
# 🔍 Processing column: City
#
# 🔍 Processing column: Inspection Type
#
# ✅ Cleaned data saved as: Food_Inspections_Cleaned.csv
#
# 📦 Grouped values for 'Facility Type':
#
#   → DAYCARE COMBO 1586:
#      - DAYCARE COMBO 1586
#      - DAYCARE COMBO
#      - DAY CARE COMBO (1586)
#      - DAYCARE
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - DAYCARE 1586
#
#   → RESTAURANT:
#      - RESTAURANT
#      - RESTAURANT/BAR
#      - GROCERY & RESTAURANT
#      - GROCERY/RESTAURANT
#      - RESTAURANT/HOSPITAL
#      - RESTAURANT/GROCERY STORE
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - GAS STATION/RESTAURANT
#      - RESTAURANT/LIQUOR
#      - TAVERN/RESTAURANT
#      - GROCERY STORE/RESTAURANT
#      - RESTAURANT.BANQUET HALLS
#      - RESTAURANT AND LIQUOR
#      - RESTAURANT/BAR/THEATER
#      - GROCERY/ RESTAURANT
#      - GROCERY STORE/ RESTAURANT
#      - RESTAURANT/BAKERY
#      - RESTAURANT/GROCERY
#      - BAKERY/ RESTAURANT
#      - BAKERY/RESTAURANT
#
#   → GROCERY STORE:
#      - GROCERY STORE
#      - GROCERY/DRUG STORE
#      - DRUG STORE/GROCERY
#      - GROCERY STORE/DELI
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - GROCERY STORE/BAKERY
#      - STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GROCERY
#      - GROCERY STORE / GAS STATION
#      - GROCERY STORE/TAQUERIA
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR & GROCERY STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#      - SLAUGHTER HOUSE/ GROCERY
#      - GROCERY & RESTAURANT
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GAS STATION/STORE GROCERY
#      - CONVENIENCE/DRUG STORE
#      - GAS STATION /GROCERY
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - GROCERY/SERVICE GAS STATION
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY/LIQUOR STORE
#
#   → SCHOOL:
#      - SCHOOL
#      - TEACHING SCHOOL
#      - COOKING SCHOOL
#      - CHARTER SCHOOL
#      - PRIVATE SCHOOL
#      - CULINARY SCHOOL
#      - PASTRY SCHOOL
#      - HIGH SCHOOL KITCHEN
#      - GROCERY STORE/COOKING SCHOOL
#      - AFTER SCHOOL PROGRAM
#      - SCHOOL CAFETERIA
#      - CULINARY ARTS SCHOOL
#      - BEFORE AND AFTER SCHOOL PROGRAM
#      - CHARTER SCHOOL CAFETERIA
#      - PREP INSIDE SCHOOL
#      - CHARTER SCHOOL/CAFETERIA
#      - ALTERNATIVE SCHOOL
#      - CHURCH/AFTER SCHOOL PROGRAM
#      - AFTER SCHOOL CARE
#
#   → CATERING:
#      - CATERING
#      - CATERING/BANQUET
#      - CATERING/CAFE
#      - BANQUET HALL/CATERING
#      - CATERING AND WHOLESALE
#
#   → CONVENIENT STORE:
#      - CONVENIENT STORE
#      - CONVENIENCE STORE
#      - (CONVENIENCE STORE)
#      - STORE
#      - CONVNIENCE STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - DRUG STORE
#      - CAFE/STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - BOOK STORE
#      - TEA STORE
#      - WINE STORE
#      - GAS STATION/ GROCERY STORE
#      - GYM STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR STORE WITH GROCERY
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → CHILDREN'S SERVICES FACILITY:
#      - CHILDREN'S SERVICES FACILITY
#      - CHILDRENS SERVICES FACILITY
#      - 1023-CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDREN'S SERVICES FACILITY
#      - CHILDERN'S SERVICES  FACILITY
#      - 1023 CHILDERN'S SERVICES FACILITY
#      - 1023 CHILDERN'S SERVICE S FACILITY
#      - FARMER'S MARKET
#      - BANQUET FACILITY
#
#   → LONG TERM CARE:
#      - LONG TERM CARE
#      - LONG-TERM CARE
#      - LONG-TERM CARE FACILITY
#      - LONG TERM CARE FACILITY
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - ASSISTED LIVING SENIOR CARE
#      - 1584-DAY CARE ABOVE 2 YEARS
#      - DAY CARE
#      - ADULT FAMILY CARE CENTER
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → DAYCARE (2 - 6 YEARS):
#      - DAYCARE (2 - 6 YEARS)
#      - DAYCARE (2 YEARS)
#      - DAYCARE
#      - DAYCARE (UNDER 2 YEARS)
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - DAY CARE 2-14
#      - ADULT DAYCARE
#      - DAYCARE NIGHT
#      - DAYCARE COMBO
#      - DAYCARE 1586
#
#   → BAKERY:
#      - BAKERY
#      - THC INFUSED BAKERY
#      - GROCERY STORE/BAKERY
#      - DELI/BAKERY
#      - BAKERY/DELI
#      - WHOLESALE BAKERY
#      - GROCERY/BAKERY
#      - RESTAURANT/BAKERY
#      - BAKERY/GROCERY
#      - BAKERY/ RESTAURANT
#      - BAKERY/RESTAURANT
#
#   → LIQUOR:
#      - LIQUOR
#      - LIQUOR/GROCERY STORE/BAR
#      - LIQUOR/COFFEE KIOSK
#      - CATERED LIQUOR
#      - 1475 LIQUOR
#      - LIQUOR STORE
#      - CAT/LIQUOR
#      - TAVERN-LIQUOR
#      - RESTAURANT/LIQUOR
#      - GROCERY & LIQUOR STORE
#      - RESTAURANT AND LIQUOR
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY/LIQUOR STORE
#      - PACKAGED LIQUOR
#      - LIQUORE STORE/BAR
#      - LIQUOR CONSUMPTION ON PREMISES.
#      - GROCERY/LIQUOR
#      - TAVERN/LIQUOR
#
#   → MOBILE FROZEN DESSERTS VENDOR:
#      - MOBILE FROZEN DESSERTS VENDOR
#      - MOBILE FROZEN DESSERT VENDOR
#      - MOBILE DESSERTS VENDOR
#      - MOBILE FOOD DESSERTS VENDOR
#      - MOBILE FOOD
#      - MOBILE PUSH CART
#      - MOBILE FOOD TRUCK
#      - ILLEGAL VENDOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - MOBILE DESSERT CART
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - PRODUCE VENDOR
#
#   → MOBILE PREPARED FOOD VENDOR:
#      - MOBILE PREPARED FOOD VENDOR
#      - MOBILPREPARED FOOD VENDOR
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - HEALTH FOOD STORE
#      - MOBILE PUSH CART
#      - FOOD BOOTH
#      - MOBILE FOOD TRUCK
#      - ILLEGAL VENDOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - MOBIL FOOD 1315
#      - FOOD PANTRY/CHURCH
#      - FREE FOOD PANTRY
#      - FOOD HALL
#      - RETAIL FOOD
#      - GAS STATION/FOOD
#      - DRUG/FOOD STORE
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - PRODUCE VENDOR
#      - DRUG STORE/W/ FOOD
#
#   → NURSING HOME:
#      - NURSING HOME
#      - 1005 NURSING HOME
#
#   → MOBILE FOOD DISPENSER:
#      - MOBILE FOOD DISPENSER
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#      - POP-UP FOOD ESTABLISHMENT USER-TIER I
#      - FOOD BOOTH
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - FOOD HALL
#      - RETAIL FOOD
#      - MOBILE FROZEN DESSERT DISP/NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - FROZEN DESSERTS DISPENSER -NON MOTORIZED
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#
#   → DONUT SHOP:
#      - DONUT SHOP
#      - HERBAL LIFE SHOP
#      - PALETERIA /ICECREAM SHOP
#
#   → ROOF TOP:
#      - ROOF TOP
#      - ROOF TOPS
#      - ROOFTOP
#      - WRIGLEY ROOF TOP
#      - ROOFTOPS
#
#   → HOSPITAL:
#      - HOSPITAL
#      - RESTAURANT/HOSPITAL
#
#   → LIVE POULTRY:
#      - LIVE POULTRY
#      - LIVE POULTRY SLAUGHTER FACILITY
#      - LIVE POULTRY SLAUGHTER
#      - CUSTOM POULTRY SLAUGHTER
#
#   → BANQUET HALL:
#      - BANQUET HALL
#      - BANQUET
#      - LOUNGE/BANQUET HALL
#      - BANQUET HALL/CATERING
#      - RESTAURANT.BANQUET HALLS
#      - VFW HALL
#
#   → SHARED KITCHEN:
#      - SHARED KITCHEN
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - SHARED KITCHEN USER (LONG TREM)
#      - OUTREACH CULINARY KITCHEN
#      - TEST KITCHEN/ STORAGE
#
#   → COFFEE SHOP:
#      - COFFEE SHOP
#      - COFFEE  SHOP
#      - COFFEE
#      - LIQUOR/COFFEE KIOSK
#      - PALETERIA /ICECREAM SHOP
#      - COFFEE AND/OR DRINKS
#      - COFFEE VENDING MACHINE
#
#   → SHELTER:
#      - SHELTER
#      - ANIMAL SHELTER CAFE PERMIT
#
#   → GAS STATION:
#      - GAS STATION
#      - (GAS STATION)
#      - GAS STATION/FOOD
#      - GROCERY STORE/GAS STATION
#      - GAS STATION/GROCERY
#      - GAS STATION/STORE
#      - GAS STATION/CONVENIENCE STORE
#      - GAS STATION/MINI MART
#      - SERVICE GAS STATION
#      - GROCERY/GAS STATION
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - GAS STATION/RESTAURANT
#      - GAS STATION /SUBWAY MINI MART.
#      - GAS STATION /GROCERY
#      - GAS STATION/ GROCERY STORE
#      - GAS STATION STORE
#      - CONVENIENCE/GAS STATION
#      - GAS STATION FOOD STORE
#      - GROCERY/SERVICE GAS STATION
#      - GROCERY(GAS STATION)
#      - RETAIL FOOD/GAS STATION
#
#   → CAFETERIA:
#      - CAFETERIA
#      - UNIVERSITY CAFETERIA
#      - SCHOOL CAFETERIA
#      - CHARTER SCHOOL CAFETERIA
#      - CHARTER SCHOOL/CAFETERIA
#      - CAFE
#
#   → SPECIAL EVENT:
#      - SPECIAL EVENT
#      - CHURCH (SPECIAL EVENTS)
#      - CHURCH/SPECIAL EVENTS
#      - CHURCH/SPECIAL EVENT
#
#   → MOBILE FOOD PREPARER:
#      - MOBILE FOOD PREPARER
#      - MOBIL FOOD PREPARED
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#      - POP-UP FOOD ESTABLISHMENT USER-TIER I
#      - FOOD BOOTH
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - FOOD HALL
#      - RETAIL FOOD
#      - MOBILE FROZEN DESSERT DISP/NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#
#   → PALETERIA:
#      - PALETERIA
#      - PALETERIA /ICECREAM SHOP
#
#   → JUICE BAR:
#      - JUICE BAR
#      - BAR
#      - JUICE BAR/GROCERY
#      - RESTAURANT/BAR
#      - EXERCISE AND NUTRITION BAR
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - JUICE AND SALAD BAR
#      - LIQUOR/GROCERY STORE/BAR
#      - SHUFFLEBOARD CLUB WITH BAR
#      - RETAIL WINE/WINE BAR
#      - RESTUARANT AND BAR
#      - WINE TASTING BAR
#      - RESTAURANT/BAR/THEATER
#      - SERVICE BAR/THEATRE
#      - PROTEIN SHAKE BAR
#      - LIQUORE STORE/BAR
#
#   → NOT-FOR-PROFIT CLUB:
#      - NOT-FOR-PROFIT CLUB
#      - NOT FOR PROFIT
#      - NIGHT CLUB
#      - PRIVATE CLUB
#      - SOCIAL CLUB
#      - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
#      - A-NOT-FOR-PROFIT CHEF TRAINING PROGRAM
#      - HEALTH CLUB
#      - NON -PROFIT
#
#   → HOTEL:
#      - HOTEL
#      - HOSTEL
#
#   → TAVERN:
#      - TAVERN
#      - TAVERN/PACKAGED GOODS
#      - TAVERN-LIQUOR
#      - TAVERN/RESTAURANT
#      - TAVERN/BAR
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - TAVERN/1006
#      - TAVERN/LIQUOR
#
#   → NAVY PIER KIOSK:
#      - NAVY PIER KIOSK
#      - KIOSK
#      - NP-KIOSK
#
#   → EVENT CENTER:
#      - EVENT CENTER
#      - DISTRIBUTION CENTER
#      - HEALTH CENTER/NUTRITION CLASSES
#      - PRIVATE EVENT SPACE
#      - CHURCH/SPECIAL EVENT
#      - ADULT FAMILY CARE CENTER
#
#   → HERBALIFE:
#      - HERBALIFE
#      - HERABALIFE
#      - HERBALIFE/ZUMBA
#      - HERBAL LIFE
#      - HERBALIFE NUTRITION
#      - HERBALIFE STORE
#      - HERBAL
#      - NUTRITION/HERBALIFE
#
#   → GROCERY(SUSHI PREP):
#      - GROCERY(SUSHI PREP)
#      - GROCERY
#      - GROCERY STORE/COOKING SCHOOL
#      - GROCERY STORE / GAS STATION
#      - GROCERY/CAFE
#      - GROCERY/DELI
#      - GROCERY/SERVICE GAS STATION
#      - REST/GROCERY
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → SUPPORTIVE LIVING:
#      - SUPPORTIVE LIVING
#      - ASSISTED LIVING SENIOR CARE
#
#   → POULTRY SLAUGHTER:
#      - POULTRY SLAUGHTER
#      - CUSTOM POULTRY SLAUGHTER
#      - LIVE POULTRY SLAUGHTER
#      - LIVE POULTRY SLAUGHTER FACILITY
#
#   → THEATER:
#      - THEATER
#      - MOVIE THEATER
#      - RESTAURANT/BAR/THEATER
#      - THEATER/BAR
#      - THEATRE
#
#   → PACKAGED HEALTH FOODS:
#      - PACKAGED HEALTH FOODS
#      - PRE PACKAGED
#      - HEALTH CLUB
#      - HEALTH CENTER
#
#   → COMMISSARY:
#      - COMMISSARY
#      - COMMISARY
#      - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
#      - VENDING COMMISSARY
#      - COMMIASARY
#
#   → HERBAL DRINKS:
#      - HERBAL DRINKS
#      - HERBAL
#      - COFFEE AND/OR DRINKS
#
#   → POP-UP ESTABLISHMENT HOST-TIER II:
#      - POP-UP ESTABLISHMENT HOST-TIER II
#      - POP-UP ESTABLISHMENT HOST-TIER III
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#
#   → WHOLESALE:
#      - WHOLESALE
#      - WHOLESALE BAKERY
#      - WHOLESALE & RETAIL
#      - CATERING AND WHOLESALE
#
#   → BUTCHER, DELI:
#      - BUTCHER, DELI
#      - DELI
#
#   → UNLICENSED FACILITY:
#      - UNLICENSED FACILITY
#      - 1023-CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDERN'S SERVICES FACILITY
#      - LIVE POULTRY SLAUGHTER FACILITY
#      - CHILDERN'S SERVICES  FACILITY
#      - 1023 CHILDERN'S SERVICE S FACILITY
#
#   → KITCHEN DEMO:
#      - KITCHEN DEMO
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - HIGH SCHOOL KITCHEN
#      - OUTREACH CULINARY KITCHEN
#      - CHARITY AID KITCHEN
#      - TEST KITCHEN/ STORAGE
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → CHURCH:
#      - CHURCH
#      - CHURCH (SPECIAL EVENTS)
#      - CHURCH KITCHEN
#      - CHURCH/SPECIAL EVENTS
#      - FOOD PANTRY/CHURCH
#      - CHURCH (FOOD PANTRY)
#      - CHURCH/SPECIAL EVENT
#      - CHURCH/DAY CARE
#      - CHURCH/AFTER SCHOOL PROGRAM
#
#   → ASSISTED LIVING:
#      - ASSISTED LIVING
#      - ASSISSTED LIVING
#      - ASSISTED LIVING SENIOR CARE
#
#   → RIVERWALK:
#      - RIVERWALK
#      - RIVERWALK CAFE
#
#   → DINING HALL:
#      - DINING HALL
#      - LOUNGE/BANQUET HALL
#      - BANQUET HALL/CATERING
#
#   → COLLEGE:
#      - COLLEGE
#      - CITY OF CHICAGO COLLEGE
#
#   → MOVIE THEATRE:
#      - MOVIE THEATRE
#      - MOVIE THEATER
#      - THEATRE
#
#   → ENTERTAINMENT VENUE:
#      - ENTERTAINMENT VENUE
#      - MUSIC VENUE
#
#   → GAS/MINI MART:
#      - GAS/MINI MART
#      - GROCERY STORE/GAS STATION
#      - GAS STATION/CONVENIENCE STORE
#      - GAS STATION/MINI MART
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - GAS STATION/RESTAURANT
#      - GAS STATION /SUBWAY MINI MART.
#      - GAS STATION /GROCERY
#      - GAS STATION/ GROCERY STORE
#      - CONVENIENCE/GAS STATION
#      - GAS STATION FOOD STORE
#      - GROCERY/SERVICE GAS STATION
#      - RETAIL FOOD/GAS STATION
#
#   → BANQUET ROOM:
#      - BANQUET ROOM
#      - BANQUET ROOMS
#      - BANQUET
#      - LOUNGE/BANQUET HALL
#      - DISTILLERY WITH TASTING ROOM
#      - BANQUET HALL/CATERING
#      - RESTAURANT.BANQUET HALLS
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - BANQUETS/ROOM SERVICE
#
#   → REHAB CENTER:
#      - REHAB CENTER
#      - (REHAB CENTER)
#      - DISTRIBUTION CENTER
#      - HEALTH CENTER/NUTRITION CLASSES
#      - ADULT FAMILY CARE CENTER
#
#   → EVENT SPACE:
#      - EVENT SPACE
#      - SPA
#      - PRIVATE EVENT SPACE
#      - FRENCH MARKET SPACE
#      - CHURCH/SPECIAL EVENT
#
#   → COFFEE KIOSK:
#      - COFFEE KIOSK
#      - LIQUOR/COFFEE KIOSK
#      - KIOSK
#      - COFFEE
#      - NP-KIOSK
#      - COFFEE AND/OR DRINKS
#      - COFFEE VENDING MACHINE
#
#   → BUTCHER SHOP:
#      - BUTCHER SHOP
#      - PALETERIA /ICECREAM SHOP
#      - GROCERY AND BUTCHER
#
#   → WRIGLEY ROOFTOP:
#      - WRIGLEY ROOFTOP
#      - WRIGLEY ROOF TOP
#      - ROOFTOP
#
#   → CONVENIENCE:
#      - CONVENIENCE
#      - CONVENIENCE STORE
#      - GAS STATION/CONVENIENCE STORE
#      - CONVENIENCE/DRUG STORE
#      - CONVENIENCE/GAS STATION
#      - (CONVENIENCE STORE)
#
#   → CANDY STORE:
#      - CANDY STORE
#      - STORE
#      - MEXICAN CANDY STORE
#      - CANDY
#      - GROCERY STORE/GAS STATION
#      - CONVENIENCE STORE
#      - GAS STATION/STORE
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - HEALTH FOOD STORE
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - HEALTH CARE STORE
#      - GROCERY/DRUG STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - DRUG STORE/GROCERY
#      - GAS STATION STORE
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE/DELI
#      - LIQUORE STORE/BAR
#      - (CONVENIENCE STORE)
#      - DRUG STORE/W/ FOOD
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → ICE CREAM SHOP:
#      - ICE CREAM SHOP
#      - ICE CREAM
#      - NAIL SHOP
#      - PALETERIA /ICECREAM SHOP
#      - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
#      - GIFT SHOP
#
#   → DOLLAR TREE:
#      - DOLLAR TREE
#      - DOLLAR STORE
#      - DOLLAR STORE WITH GROCERY
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#
#   → FITNESS CENTER:
#      - FITNESS CENTER
#      - HEALTH CENTER/NUTRITION CLASSES
#      - ADULT FAMILY CARE CENTER
#
#   → BREWERY:
#      - BREWERY
#      - LIQOUR BREWERY TASTING
#
#   → AIRPORT LOUNGE:
#      - AIRPORT LOUNGE
#      - LOUNGE
#
#   → SMOOTHIE BAR:
#      - SMOOTHIE BAR
#      - BAR
#      - EXERCISE AND NUTRITION BAR
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - JUICE AND SALAD BAR
#      - LIQUOR/GROCERY STORE/BAR
#      - SHUFFLEBOARD CLUB WITH BAR
#      - RETAIL WINE/WINE BAR
#      - RESTUARANT AND BAR
#      - RESTAURANT/BAR/THEATER
#      - SERVICE BAR/THEATRE
#
#   → CHARTER:
#      - CHARTER
#      - CHARTER SCHOOL
#      - CPS (CHARTER)
#      - CHARTER SCHOOL CAFETERIA
#      - CHARTER SCHOOL/CAFETERIA
#
#   → TOBACCO STORE:
#      - TOBACCO STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → BEVERAGE/SILVERWARE WAREHOUSE:
#      - BEVERAGE/SILVERWARE WAREHOUSE
#      - WAREHOUSE
#
#   → VENDING MACHINE:
#      - VENDING MACHINE
#      - COFFEE VENDING MACHINE
#
#   → COFFEE CART:
#      - COFFEE CART
#      - COFFEE
#      - LIQUOR/COFFEE KIOSK
#      - COFFEE AND/OR DRINKS
#      - MOBILE DESSERT CART
#      - COFFEE VENDING MACHINE
#
#   → FURNITURE STORE:
#      - FURNITURE STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - DRUG STORE
#      - CAFE/STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - BOOK STORE
#      - TEA STORE
#      - WINE STORE
#      - GAS STATION/ GROCERY STORE
#      - GYM STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR STORE WITH GROCERY
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → CANDY SHOP:
#      - CANDY SHOP
#      - CANDY
#      - HERBAL LIFE SHOP
#      - PALETERIA /ICECREAM SHOP
#      - MEXICAN CANDY STORE
#
#   → FROZEN DESSERT PUSHCARTS:
#      - FROZEN DESSERT PUSHCARTS
#      - PUSHCART
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - PUSH CARTS
#      - MOBILE FROZEN DESSERT DISP/NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - FROZEN DESSERTS DISPENSER -NON MOTORIZED
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#
#   → MFD TRUCK:
#      - MFD TRUCK
#      - TRUCK
#      - MOBILE FOOD TRUCK
#
#   → WEIGHT LOSS PROGRAM:
#      - WEIGHT LOSS PROGRAM
#      - BEFORE AND AFTER SCHOOL PROGRAM
#      - A-NOT-FOR-PROFIT CHEF TRAINING PROGRAM
#
#   → HERBALCAL:
#      - HERBALCAL
#      - HERBAL
#
#   → DAYCARE 2 YRS TO 12 YRS:
#      - DAYCARE 2 YRS TO 12 YRS
#      - DAYCARE
#      - DAY CARE 2-14
#      - ADULT DAYCARE
#      - DAYCARE NIGHT
#      - DAYCARE COMBO
#      - DAYCARE 1586
#
#   → 1023:
#      - 1023
#      - DAY CARE 1023
#
#   → BANQUET/KITCHEN:
#      - BANQUET/KITCHEN
#      - BANQUET
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - OUTREACH CULINARY KITCHEN
#      - RESTAURANT.BANQUET HALLS
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → COFFEE ROASTER:
#      - COFFEE ROASTER
#      - COFFEE
#      - COFFEE VENDING MACHINE
#
#   → EMPLOYEE KITCHEN:
#      - EMPLOYEE KITCHEN
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - OUTREACH CULINARY KITCHEN
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → BOWLING LANES/BANQUETS:
#      - BOWLING LANES/BANQUETS
#      - BANQUET
#      - BANQUETS
#
#   → VIDEO STORE:
#      - VIDEO STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - CONVENIENCE STORE
#      - GAS STATION/STORE
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - HEALTH FOOD STORE
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - HEALTH CARE STORE
#      - GROCERY/DRUG STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - BLOCKBUSTER VIDEO
#      - MEXICAN CANDY STORE
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - DRUG STORE/GROCERY
#      - GAS STATION STORE
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE/DELI
#      - LIQUORE STORE/BAR
#      - (CONVENIENCE STORE)
#      - DRUG STORE/W/ FOOD
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → RETAIL STORE:
#      - RETAIL STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - STORE
#      - RETAIL
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GROCERY/DRUG STORE
#      - RETAIL WINE/WINE BAR
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - MEXICAN CANDY STORE
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - DRUG STORE/GROCERY
#      - PREPACKAGE MEAL DISTRIBUTOR (1006 RETAIL)
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - WHOLESALE & RETAIL
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - RETAIL FOOD/GAS STATION
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE/DELI
#      - DRUG STORE/W/ FOOD
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → REST/ROOFTOP:
#      - REST/ROOFTOP
#      - ROOFTOP
#      - REST/GYM
#
#   → BAR/GRILL:
#      - BAR/GRILL
#      - BAR
#      - RESTAURANT/BAR
#      - EXERCISE AND NUTRITION BAR
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - JUICE BAR/GROCERY
#      - JUICE AND SALAD BAR
#      - LIQUOR/GROCERY STORE/BAR
#      - SHUFFLEBOARD CLUB WITH BAR
#      - RETAIL WINE/WINE BAR
#      - RESTUARANT AND BAR
#      - WINE TASTING BAR
#      - RESTAURANT/BAR/THEATER
#      - SERVICE BAR/THEATRE
#      - PROTEIN SHAKE BAR
#      - LIQUORE STORE/BAR
#
#   → POPCORN SHOP:
#      - POPCORN SHOP
#      - PALETERIA /ICECREAM SHOP
#
#   → CATERED EVENTS:
#      - CATERED EVENTS
#      - CHURCH (SPECIAL EVENTS)
#      - CHURCH/SPECIAL EVENTS
#
#   → PACKAGED FOOD DISTRIBUTION:
#      - PACKAGED FOOD DISTRIBUTION
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - HEALTH FOOD STORE
#      - FOOD BOOTH
#      - PRE PACKAGED
#      - MOBILE FOOD TRUCK
#      - MOBIL FOOD 1315
#      - FREE FOOD PANTRY
#      - FOOD HALL
#      - RETAIL FOOD
#      - GAS STATION/FOOD
#      - DRUG/FOOD STORE
#      - PACKAGED LIQUOR
#
#   → GROCERY/TAQUERIA:
#      - GROCERY/TAQUERIA
#      - GROCERY STORE/TAQUERIA
#      - GROCERY
#      - SLAUGHTER HOUSE/ GROCERY
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR STORE WITH GROCERY
#      - GROCERY/SERVICE GAS STATION
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → FOOD VENDING MACHINES:
#      - FOOD VENDING MACHINES
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#      - POP-UP FOOD ESTABLISHMENT USER-TIER I
#      - FOOD BOOTH
#      - FOOD HALL
#      - RETAIL FOOD
#
#   → HERBAL REMEDY:
#      - HERBAL REMEDY
#      - HERBAL
#
#   → CANDY/GELATO:
#      - CANDY/GELATO
#      - CANDY
#      - MEXICAN CANDY STORE
#
#   → PHARMACY:
#      - PHARMACY
#      - GROCERY STORE /PHARMACY
#
#   → ROOM SERVICE:
#      - ROOM SERVICE
#      - BANQUETS/ROOM SERVICE
#      - DISTILLERY WITH TASTING ROOM
#      - SERVICE GAS STATION
#      - GROCERY/SERVICE GAS STATION
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - SERVICE BAR/THEATRE
#      - 1023 CHILDERN'S SERVICE S FACILITY
#
#   → MEAT MARKET:
#      - MEAT MARKET
#      - FRENCH MARKET SPACE
#
#   → KIDS CAFE:
#      - KIDS CAFE
#      - KIDS CAFE'
#      - CAFE
#      - ANIMAL SHELTER CAFE PERMIT
#      - RIVERWALK CAFE
#
#   → GENERAL STORE:
#      - GENERAL STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → PANTRY:
#      - PANTRY
#      - FOOD PANTRY
#      - FOOD PANTRY/CHURCH
#      - FREE FOOD PANTRY
#      - CHURCH (FOOD PANTRY)
#
#   → SUMMER FEEDING:
#      - SUMMER FEEDING
#      - SUMMER FEEDING PREP AREA
#
#   → PRODUCE STAND:
#      - PRODUCE STAND
#      - GOLF COURSE CONNCESSION STAND
#
#   → ICE CREAM PARLOR:
#      - ICE CREAM PARLOR
#      - ICE CREAM
#      - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
#
#   → HOOKA LOUNGE:
#      - HOOKA LOUNGE
#      - LOUNGE
#      - LOUNGE/BANQUET HALL
#
#   → COOKING CLASS:
#      - COOKING CLASS
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GROCERY STORE/COOKING SCHOOL
#      - CULINARY CLASS ROOMS
#
#   → SENIOR DAY CARE:
#      - SENIOR DAY CARE
#      - DAY CARE
#      - ASSISTED LIVING SENIOR CARE
#      - 1584-DAY CARE ABOVE 2 YEARS
#      - LONG-TERM CARE FACILITY
#      - LONG TERM CARE FACILITY
#      - ADULT FAMILY CARE CENTER
#      - DAY SPA
#
#   → ADULT DAY SERVICE:
#      - ADULT DAY SERVICE
#      - 1584-DAY CARE ABOVE 2 YEARS
#      - DAY CARE
#      - GROCERY/SERVICE GAS STATION
#      - 1023 CHILDERN'S SERVICE S FACILITY
#      - DAY SPA
#
#   → HOT DOG STATION:
#      - HOT DOG STATION
#      - GROCERY STORE/GAS STATION
#      - GAS STATION/CONVENIENCE STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - GAS STATION /SUBWAY MINI MART.
#      - GAS STATION/ GROCERY STORE
#      - CONVENIENCE/GAS STATION
#      - GROCERY/SERVICE GAS STATION
#      - RETAIL FOOD/GAS STATION
#
#   → CULINARY KITCHEN:
#      - CULINARY KITCHEN
#      - OUTREACH CULINARY KITCHEN
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → RETAIL SALES:
#      - RETAIL SALES
#      - RETAIL
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - RETAIL WINE/WINE BAR
#      - PREPACKAGE MEAL DISTRIBUTOR (1006 RETAIL)
#      - WHOLESALE & RETAIL
#      - RETAIL FOOD/GAS STATION
#
#   → NUTRITION..SMOOTHIES/SHAKES:
#      - NUTRITION..SMOOTHIES/SHAKES
#      - NUTRITION SHAKES
#      - SHAKES/TEAS
#      - NUTRITION STORE
#
#   → COLD STORAGE FACILITY:
#      - COLD STORAGE FACILITY
#      - 1023-CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDERN'S SERVICES FACILITY
#      - UNUSED STORAGE
#      - 1023 CHILDERN'S SERVICE S FACILITY
#
#   → FLEA MARKET:
#      - FLEA MARKET
#      - FRENCH MARKET SPACE
#
#   → HERBAL MEDICINE:
#      - HERBAL MEDICINE
#      - HERBAL
#
#   → ART CENTER:
#      - ART CENTER
#      - DISTRIBUTION CENTER
#      - HEALTH CENTER/NUTRITION CLASSES
#      - ADULT FAMILY CARE CENTER
#      - ART GALLERY W/WINE AND BEER
#
#   → GYM:
#      - GYM
#      - GYM STORE
#      - REST/GYM
#
#   → EVENT VENU:
#      - EVENT VENU
#      - PRIVATE EVENT SPACE
#      - CHURCH/SPECIAL EVENT
#
#   → BANQUET DINING:
#      - BANQUET DINING
#      - BANQUET
#      - BANQUET HALL/CATERING
#      - RESTAURANT.BANQUET HALLS
#
#   → CLOTHING STORE:
#      - CLOTHING STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - TEA STORE
#      - GAS STATION/ GROCERY STORE
#      - GYM STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - GAS STATION FOOD STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → INTERNET CAFE:
#      - INTERNET CAFE
#      - CAFE
#      - ANIMAL SHELTER CAFE PERMIT
#
#   → COLD/FROZEN FOOD STORAGE:
#      - COLD/FROZEN FOOD STORAGE
#      - MOBILE FOOD
#      - FOOD PANTRY
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#      - POP-UP FOOD ESTABLISHMENT USER-TIER I
#      - FOOD BOOTH
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - MOBIL FOOD 1315
#      - FREE FOOD PANTRY
#      - FOOD HALL
#      - RETAIL FOOD
#      - GAS STATION/FOOD
#      - UNUSED STORAGE
#      - DRUG/FOOD STORE
#      - MOBILE FROZEN DESSERT DISP/NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - FROZEN DESSERTS DISPENSER -NON MOTORIZED
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#
#   → FISH MARKET:
#      - FISH MARKET
#      - FRENCH MARKET SPACE
#
#   → COFFEE/TEA:
#      - COFFEE/TEA
#      - COFFEE
#      - LIQUOR/COFFEE KIOSK
#      - COFFEE AND/OR DRINKS
#      - COFFEE VENDING MACHINE
#
#   → DAYCARE 6 WKS-5YRS:
#      - DAYCARE 6 WKS-5YRS
#      - DAYCARE
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - DAYCARE 1586
#
#   → SNACK SHOP:
#      - SNACK SHOP
#      - HERBAL LIFE SHOP
#      - PALETERIA /ICECREAM SHOP
#
#   → ART GALLERY:
#      - ART GALLERY
#      - ART GALLERY W/WINE AND BEER
#
#   → DISTRIBUTOR:
#      - DISTRIBUTOR
#      - PREPACKAGE MEAL DISTRIBUTOR (1006 RETAIL)
#
#   → MUSEUM/GALLERY:
#      - MUSEUM/GALLERY
#      - ART GALLERY W/WINE AND BEER
#
#   → GELATO SHOP:
#      - GELATO SHOP
#      - PALETERIA /ICECREAM SHOP
#
#   → CELL PHONE STORE:
#      - CELL PHONE STORE
#      - STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - DRUG STORE
#      - CAFE/STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - BOOK STORE
#      - TEA STORE
#      - WINE STORE
#      - GAS STATION/ GROCERY STORE
#      - GYM STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR STORE WITH GROCERY
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → MASSAGE BAR:
#      - MASSAGE BAR
#      - BAR
#      - EXERCISE AND NUTRITION BAR
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - JUICE BAR/GROCERY
#      - JUICE AND SALAD BAR
#      - LIQUOR/GROCERY STORE/BAR
#      - SHUFFLEBOARD CLUB WITH BAR
#      - RETAIL WINE/WINE BAR
#      - RESTUARANT AND BAR
#      - RESTAURANT/BAR/THEATER
#      - SERVICE BAR/THEATRE
#      - PROTEIN SHAKE BAR
#      - LIQUORE STORE/BAR
#
#   → TEMPORARY KIOSK:
#      - TEMPORARY KIOSK
#      - KIOSK
#      - NP-KIOSK
#
#   → GOLF COURSE:
#      - GOLF COURSE
#      - GOLF COURSE CONNCESSION STAND
#
#   → HOT DOG CART:
#      - HOT DOG CART
#      - MOBILE DESSERT CART
#
#   → MAIN KITCHEN:
#      - MAIN KITCHEN
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - HIGH SCHOOL KITCHEN
#      - OUTREACH CULINARY KITCHEN
#      - CHARITY AID KITCHEN
#      - TEST KITCHEN/ STORAGE
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → CHILDERN ACTIVITY FACILITY:
#      - CHILDERN ACTIVITY FACILITY
#      - BANQUET FACILITY
#
#   → MOBILE DESSERT VENDOR:
#      - MOBILE DESSERT VENDOR
#      - MOBILE DESSERTS VENDOR
#      - MOBILE FROZEN DESSERT VENDOR
#      - MOBILE FOOD DESSERTS VENDOR
#      - MOBILE FOOD
#      - ILLEGAL VENDOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISP/NON-MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - PRODUCE VENDOR
#
#   → BOYS AND GIRLS CLUB:
#      - BOYS AND GIRLS CLUB
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - NIGHT CLUB
#      - PRIVATE CLUB
#      - SOCIAL CLUB
#      - BEFORE AND AFTER SCHOOL PROGRAM
#      - HEALTH CLUB
#
#   → HERBAL STORE:
#      - HERBAL STORE
#      - STORE
#      - HERBAL
#      - HERBALIFE STORE
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - RETAIL STORE OFFERS COOKING CLASSES
#      - GAS STATION/CONVENIENCE STORE
#      - GROCERY STORE/BAKERY
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GROCERY/DRUG STORE
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - CONVENIENCE/DRUG STORE
#      - GROCERY STORE/TAQUERIA
#      - MEXICAN CANDY STORE
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY & LIQUOR STORE
#      - DOLLAR STORE WITH GROCERY
#      - DRUG STORE/GROCERY
#      - GAS STATION FOOD STORE
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#      - TAP ROOM/TAVERN/LIQUOR STORE
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY/LIQUOR STORE
#      - GROCERY STORE/DELI
#      - DRUG STORE/W/ FOOD
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → NON-FOR PROFIT BASEMENT KIT:
#      - NON-FOR PROFIT BASEMENT KIT
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - NOT FOR PROFIT
#      - COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS
#      - NON -PROFIT
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#
#   → DAYCARE 2-6, UNDER 6:
#      - DAYCARE 2-6, UNDER 6
#      - DAYCARE
#      - DAYCARE (UNDER 2 YEARS)
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - DAY CARE 2-14
#      - ADULT DAYCARE
#      - DAYCARE NIGHT
#      - DAYCARE COMBO
#      - DAYCARE 1586
#
#   → GROCERY/BUTCHER:
#      - GROCERY/BUTCHER
#      - GROCERY AND BUTCHER
#      - GROCERY
#      - SLAUGHTER HOUSE/ GROCERY
#      - GROCERY STORE/GAS STATION
#      - RESTAURANT/GROCERY STORE
#      - GROCERY STORE/COOKING SCHOOL
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY STORE /PHARMACY
#      - GAS STATION/STORE GROCERY
#      - GROCERY STORE / GAS STATION
#      - GAS STATION/ GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - DOLLAR STORE WITH GROCERY
#      - GROCERY/SERVICE GAS STATION
#      - GROCERY STORE/ RESTAURANT
#      - GROCERY STORE PLUS WIRELESS STORE
#
#   → LIVE BUTCHER:
#      - LIVE BUTCHER
#      - LIVE POULTRY SLAUGHTER FACILITY
#      - LIVE POULTRY SLAUGHTER
#      - GROCERY AND BUTCHER
#
#   → WATERMELON HOUSE:
#      - WATERMELON HOUSE
#      - SLAUGHTER HOUSE/ GROCERY
#
#   → HOOKA BAR:
#      - HOOKA BAR
#      - BAR
#      - RESTAURANT/BAR
#      - EXERCISE AND NUTRITION BAR
#      - RESTAURANT(PROTEIN SHAKE BAR)
#      - JUICE BAR/GROCERY
#      - JUICE AND SALAD BAR
#      - LIQUOR/GROCERY STORE/BAR
#      - SHUFFLEBOARD CLUB WITH BAR
#      - RETAIL WINE/WINE BAR
#      - RESTUARANT AND BAR
#      - WINE TASTING BAR
#      - RESTAURANT/BAR/THEATER
#      - SERVICE BAR/THEATRE
#      - PROTEIN SHAKE BAR
#      - LIQUORE STORE/BAR
#
#   → CANDY MAKER:
#      - CANDY MAKER
#      - CANDY
#      - MEXICAN CANDY STORE
#
#   → SOUP KITCHEN:
#      - SOUP KITCHEN
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (SHORT TERM)
#      - HIGH SCHOOL KITCHEN
#      - OUTREACH CULINARY KITCHEN
#      - CHARITY AID KITCHEN
#      - TEST KITCHEN/ STORAGE
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → ROOFTOP PATIO:
#      - ROOFTOP PATIO
#      - ROOFTOP
#
#   → DRUG TREATMENT FACILITY:
#      - DRUG TREATMENT FACILITY
#      - DRUG STORE
#      - DRUG/FOOD STORE
#
# 📦 Grouped values for 'City':
#
#   → CHICAGO:
#      - CHICAGO
#      - CHICAGO.
#      - CCHICAGO
#      - CHICAGOO
#      - CHICAGOC
#      - CHCICAGO
#      - CHICAGOI
#      - CHICAGOBEDFORD PARK
#      - CHICAGOCHICAGO
#      - CH
#      - CHICAGO HEIGHTS
#      - CHCHICAGO
#
#   → EVERGREEN:
#      - EVERGREEN
#      - EVERGREEN PARK
#
#   → OAK PARK:
#      - OAK PARK
#      - HIGHLAND PARK
#      - EVERGREEN PARK
#      - CHICAGOBEDFORD PARK
#      - SCHILLER PARK
#
#   → SCHAUMBURG:
#      - SCHAUMBURG
#      - CH
#
#   → 312CHICAGO:
#      - 312CHICAGO
#      - CH
#
#   → LAKE ZURICH:
#      - LAKE ZURICH
#      - CH
#
#   → WORTH:
#      - WORTH
#      - WADSWORTH
#
#   → MERRILLVILLE:
#      - MERRILLVILLE
#      - MERRIVILLE
#
#   → NEW YORK:
#      - NEW YORK
#      - NEW HOLSTEIN
#
#   → PALOS PARK:
#      - PALOS PARK
#      - CHICAGOBEDFORD PARK
#
#   → CHARLES A HAYES:
#      - CHARLES A HAYES
#      - CH
#
#   → TINLEY PARK:
#      - TINLEY PARK
#      - CHICAGOBEDFORD PARK
#
#   → OOLYMPIA FIELDS:
#      - OOLYMPIA FIELDS
#      - OLYMPIA FIELDS
#
# 📦 Grouped values for 'Inspection Type':
#
#   → LICENSE:
#      - LICENSE
#      - LICENSE RE-INSPECTION
#      - LICENSE-TASK FORCE
#      - LICENSE CONSULTATION
#      - PRE-LICENSE CONSULTATION
#      - LICENSE REQUEST
#      - LICENSE CANCELED BY OWNER
#      - OWNER SUSPENDED OPERATION/LICENSE
#      - LICENSE TASK 1474
#      - 1315 LICENSE REINSPECTION
#      - LICENSE RENEWAL FOR DAYCARE
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE/NOT READY
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#      - LICENSE RENEWAL INSPECTION FOR DAYCARE
#      - LICENSE WRONG ADDRESS
#      - DAY CARE LICENSE RENEWAL
#      - LICENSE DAYCARE 1586
#
#   → COMPLAINT:
#      - COMPLAINT
#      - SFP/COMPLAINT
#      - COMPLAINT RE-INSPECTION
#      - SHORT FORM COMPLAINT
#      - COMPLAINT-FIRE
#      - COMPLAINT-FIRE RE-INSPECTION
#      - SHORT FORM FIRE-COMPLAINT
#      - FIRE COMPLAINT
#      - NO ENTRY-SHORT COMPLAINT)
#      - FINISH COMPLAINT INSPECTION FROM 5-18-10
#      - SMOKING COMPLAINT
#      - CLOSE-UP/COMPLAINT REINSPECTION
#      - COVID COMPLAINT
#
#   → CANVASS:
#      - CANVASS
#      - CANVAS
#      - CANVASS RE-INSPECTION
#      - CANVASS SCHOOL/SPECIAL EVENT
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - CANVASS SPECIAL EVENTS
#      - CANVASS/SPECIAL EVENT
#      - CANVASS FOR RIB FEST
#
#   → NON-INSPECTION:
#      - NON-INSPECTION
#      - COMPLAINT RE-INSPECTION
#      - CANVASS RE-INSPECTION
#      - LICENSE RE-INSPECTION
#      - SUSPECTED FOOD POISONING RE-INSPECTION
#      - COMPLAINT-FIRE RE-INSPECTION
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - FINISH COMPLAINT INSPECTION FROM 5-18-10
#      - LICENSE RENEWAL INSPECTION FOR DAYCARE
#      - RE-INSPECTION OF CLOSE-UP
#
#   → SUSPECTED FOOD POISONING:
#      - SUSPECTED FOOD POISONING
#      - SUSPECTED FOOD POISONING RE-INSPECTION
#
#   → RECENT INSPECTION:
#      - RECENT INSPECTION
#      - SUSPECTED FOOD POISONING RE-INSPECTION
#      - COMPLAINT-FIRE RE-INSPECTION
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - FINISH COMPLAINT INSPECTION FROM 5-18-10
#      - LICENSE RENEWAL INSPECTION FOR DAYCARE
#
#   → TASK FORCE LIQUOR 1475:
#      - TASK FORCE LIQUOR 1475
#      - TASK FORCE LIQUOR 1470
#      - TASK FORCE LIQUOR 1474
#      - TASK FORCE
#      - TASK FORCE LIQUOR (1481)
#      - TASK FORCE FOR LIQUOR 1474
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#
#   → CONSULTATION:
#      - CONSULTATION
#      - LICENSE CONSULTATION
#      - PRE-LICENSE CONSULTATION
#
#   → OUT OF BUSINESS:
#      - OUT OF BUSINESS
#      - OUT OFBUSINESS
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - RE-INSPECTION OF CLOSE-UP
#      - REINSPECTION OF 48 HOUR NOTICE
#
#   → NOT READY:
#      - NOT READY
#      - TASK FORCE NOT READY
#      - LICENSE/NOT READY
#      - LIQOUR TASK FORCE NOT READY
#      - BUSINESS NOT LOCATED
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#
#   → NO ENTRY:
#      - NO ENTRY
#      - NO ENTRY-SHORT COMPLAINT)
#
#   → PACKAGE LIQUOR 1474:
#      - PACKAGE LIQUOR 1474
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - TASK FORCE(1470) LIQUOR TAVERN
#      - TASK FORCE PACKAGE GOODS 1474
#
#   → SFP RECENTLY INSPECTED:
#      - SFP RECENTLY INSPECTED
#      - SFP
#      - SFP/COMPLAINT
#
#   → ILLEGAL OPERATION:
#      - ILLEGAL OPERATION
#      - OWNER SUSPENDED OPERATION/LICENSE
#
#   → KIDS CAFE:
#      - KIDS CAFE
#      - KIDS CAFE'
#
#   → CITATION RE-ISSUED:
#      - CITATION RE-ISSUED
#      - SUSPECTED FOOD POISONING RE-INSPECTION
#      - COMPLAINT-FIRE RE-INSPECTION
#      - CANVASS RE INSPECTION OF CLOSE UP
#
#   → FIRE:
#      - FIRE
#      - COMPLAINT-FIRE
#      - COMPLAINT-FIRE RE-INSPECTION
#      - SHORT FORM FIRE-COMPLAINT
#      - FIRE COMPLAINT
#      - FIRE/COMPLAIN
#
#   → TASK FORCE LIQUOR CATERING:
#      - TASK FORCE LIQUOR CATERING
#      - LIQUOR CATERING
#      - TASK FORCE
#      - LICENSE TASK 1474
#      - TASK FORCE NIGHT
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#
#   → TASKFORCE:
#      - TASKFORCE
#      - TASK FORCE
#
#   → TAVERN 1470:
#      - TAVERN 1470
#      - TASK FORCE LIQUOR 1470
#      - TASK FORCE(1470) LIQUOR TAVERN
#
#   → SPECIAL TASK FORCE:
#      - SPECIAL TASK FORCE
#      - TASK FORCE
#      - CANVASS SCHOOL/SPECIAL EVENT
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#      - TASK FORCE(1470) LIQUOR TAVERN
#      - LIQOUR TASK FORCE NOT READY
#      - TASK FORCE PACKAGE GOODS 1474
#
#   → RECALL INSPECTION:
#      - RECALL INSPECTION
#      - SUSPECTED FOOD POISONING RE-INSPECTION
#      - COMPLAINT-FIRE RE-INSPECTION
#      - TASK FORCE LIQUOR INSPECTION 1474
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - FINISH COMPLAINT INSPECTION FROM 5-18-10
#      - LICENSE RENEWAL INSPECTION FOR DAYCARE
#
#   → TASTE OF CHICAGO:
#      - TASTE OF CHICAGO
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - RE-INSPECTION OF CLOSE-UP
#      - REINSPECTION OF 48 HOUR NOTICE
#
#   → REINSPECTION:
#      - REINSPECTION
#      - 1315 LICENSE REINSPECTION
#      - CLOSE-UP/COMPLAINT REINSPECTION
#      - REINSPECTION OF 48 HOUR NOTICE
#
#   → TASK FORCE PACKAGE LIQUOR:
#      - TASK FORCE PACKAGE LIQUOR
#      - TASK FORCE
#      - TASK FORCE NIGHT
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#      - LIQUOR CATERING

# %%
import pandas as pd
from fuzzywuzzy import process

# Load dataset
df = pd.read_csv("Food_Inspections_20250216.csv")

# Columns to clean
columns_to_clean = ['Facility Type', 'City', 'Inspection Type']

# Dictionary to store grouped labels for display
all_grouped_labels = {}

# Function to clean one column
def clean_column_fuzzy(df, column_name):
    print(f"\n🔍 Processing column: {column_name}")
    
    # Step 1: Capitalize everything
    df[column_name] = df[column_name].astype(str).str.strip().str.upper()

    # Step 2: Get unique values
    unique_values = df[column_name].dropna().unique().tolist()

    # Step 3: Fuzzy group similar values
    grouped_map = {}     # raw -> cleaned
    grouped_labels = {}  # cleaned -> [originals]

    for value in unique_values:
        if value in grouped_map:
            continue  # Already grouped

        # Fuzzy match: similarity >= 85
        matches = process.extract(value, unique_values, limit=None)
        close_matches = [m for m, score in matches if score >= 95]

        canonical = close_matches[0]

        for match in close_matches:
            grouped_map[match] = canonical

        grouped_labels[canonical] = close_matches

    # Step 4: Create new cleaned column
    cleaned_col = f"{column_name} Cleaned"
    df[cleaned_col] = df[column_name].map(grouped_map)

    # Save grouping for display
    all_grouped_labels[column_name] = grouped_labels

    return df

# Apply to each target column
for col in columns_to_clean:
    df = clean_column_fuzzy(df, col)

# Save new CSV
df.to_csv("Food_Inspections_Cleaned.csv", index=False)
print("\n✅ Cleaned data saved as: Food_Inspections_Cleaned.csv")

# Show grouping results
for col, group_map in all_grouped_labels.items():
    print(f"\n📦 Grouped values for '{col}':")
    for canonical, group in group_map.items():
        if len(group) > 1:
            print(f"\n  → {canonical}:")
            for g in group:
                print(f"     - {g}")
# Out:
# 🔍 Processing column: Facility Type
#
# 🔍 Processing column: City
#
# 🔍 Processing column: Inspection Type
#
# ✅ Cleaned data saved as: Food_Inspections_Cleaned.csv
#
# 📦 Grouped values for 'Facility Type':
#
#   → DAYCARE COMBO 1586:
#      - DAYCARE COMBO 1586
#      - DAYCARE COMBO
#      - DAY CARE COMBO (1586)
#
#   → RESTAURANT:
#      - RESTAURANT
#      - RESTAURANT/BAR
#
#   → GROCERY STORE:
#      - GROCERY STORE
#      - GROCERY/DRUG STORE
#      - DRUG STORE/GROCERY
#      - GROCERY STORE/DELI
#
#   → CHILDREN'S SERVICES FACILITY:
#      - CHILDREN'S SERVICES FACILITY
#      - CHILDRENS SERVICES FACILITY
#      - 1023-CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDREN'S SERVICES FACILITY
#      - CHILDERN'S SERVICES  FACILITY
#
#   → DAYCARE ABOVE AND UNDER 2 YEARS:
#      - DAYCARE ABOVE AND UNDER 2 YEARS
#      - DAYCARE (UNDER 2 YEARS)
#
#   → LONG TERM CARE:
#      - LONG TERM CARE
#      - LONG-TERM CARE
#
#   → DAYCARE (2 - 6 YEARS):
#      - DAYCARE (2 - 6 YEARS)
#      - DAYCARE (2 YEARS)
#
#   → MOBILE FROZEN DESSERTS VENDOR:
#      - MOBILE FROZEN DESSERTS VENDOR
#      - MOBILE FROZEN DESSERT VENDOR
#      - MOBILE DESSERTS VENDOR
#
#   → MOBILE PREPARED FOOD VENDOR:
#      - MOBILE PREPARED FOOD VENDOR
#      - MOBILPREPARED FOOD VENDOR
#
#   → NURSING HOME:
#      - NURSING HOME
#      - 1005 NURSING HOME
#
#   → SHARED KITCHEN USER (LONG TERM):
#      - SHARED KITCHEN USER (LONG TERM)
#      - SHARED KITCHEN USER (LONG TREM)
#
#   → GROCERY & RESTAURANT:
#      - GROCERY & RESTAURANT
#      - GROCERY/ RESTAURANT
#      - GROCERY/RESTAURANT
#      - RESTAURANT/GROCERY STORE
#      - GROCERY STORE/RESTAURANT
#      - GROCERY STORE/ RESTAURANT
#      - RESTAURANT/GROCERY
#
#   → COFFEE SHOP:
#      - COFFEE SHOP
#      - COFFEE  SHOP
#
#   → CATERING/BANQUET:
#      - CATERING/BANQUET
#      - BANQUET HALL/CATERING
#
#   → GAS STATION:
#      - GAS STATION
#      - (GAS STATION)
#      - GAS STATION/FOOD
#
#   → GROCERY STORE/GAS STATION:
#      - GROCERY STORE/GAS STATION
#      - GROCERY STORE / GAS STATION
#      - GAS STATION/GROCERY
#      - GAS STATION/STORE
#      - GROCERY/GAS STATION
#      - GAS STATION/STORE GROCERY
#      - GAS STATION /GROCERY
#      - GAS STATION/ GROCERY STORE
#      - GAS STATION STORE
#      - GROCERY(GAS STATION)
#
#   → CONVENIENCE STORE:
#      - CONVENIENCE STORE
#      - (CONVENIENCE STORE)
#      - CONVNIENCE STORE
#      - CONVENIENCE/DRUG STORE
#
#   → NOT-FOR-PROFIT CLUB:
#      - NOT-FOR-PROFIT CLUB
#      - NOT FOR PROFIT
#
#   → HERBALIFE:
#      - HERBALIFE
#      - HERABALIFE
#
#   → 1023 CHILDERN'S SERVICES FACILITY:
#      - 1023 CHILDERN'S SERVICES FACILITY
#      - 1023 CHILDERN'S SERVICE S FACILITY
#      - 1023-CHILDREN'S SERVICES FACILITY
#      - 1023 CHILDREN'S SERVICES FACILITY
#      - CHILDERN'S SERVICES  FACILITY
#
#   → POULTRY SLAUGHTER:
#      - POULTRY SLAUGHTER
#      - CUSTOM POULTRY SLAUGHTER
#      - LIVE POULTRY SLAUGHTER
#
#   → CULINARY SCHOOL:
#      - CULINARY SCHOOL
#      - CULINARY ARTS SCHOOL
#
#   → COMMISSARY:
#      - COMMISSARY
#      - COMMISARY
#
#   → GAS STATION/CONVENIENCE STORE:
#      - GAS STATION/CONVENIENCE STORE
#      - CONVENIENCE/GAS STATION
#
#   → GAS STATION/MINI MART:
#      - GAS STATION/MINI MART
#      - GAS STATION /SUBWAY MINI MART.
#
#   → POP-UP ESTABLISHMENT HOST-TIER II:
#      - POP-UP ESTABLISHMENT HOST-TIER II
#      - POP-UP ESTABLISHMENT HOST-TIER III
#
#   → ASSISTED LIVING:
#      - ASSISTED LIVING
#      - ASSISSTED LIVING
#
#   → GROCERY STORE/BAKERY:
#      - GROCERY STORE/BAKERY
#      - GROCERY/BAKERY
#      - BAKERY/GROCERY
#
#   → FOOD PANTRY:
#      - FOOD PANTRY
#      - FREE FOOD PANTRY
#
#   → LIVE POULTRY SLAUGHTER FACILITY:
#      - LIVE POULTRY SLAUGHTER FACILITY
#      - LIVE POULTRY SLAUGHTER
#
#   → POP-UP FOOD ESTABLISHMENT USER-TIER II:
#      - POP-UP FOOD ESTABLISHMENT USER-TIER II
#      - POP-UP FOOD ESTABLISHMENT USER-TIER I
#
#   → BANQUET ROOM:
#      - BANQUET ROOM
#      - BANQUET ROOMS
#
#   → REHAB CENTER:
#      - REHAB CENTER
#      - (REHAB CENTER)
#
#   → DELI/BAKERY:
#      - DELI/BAKERY
#      - BAKERY/DELI
#
#   → HERBAL LIFE SHOP:
#      - HERBAL LIFE SHOP
#      - HERBAL LIFE
#
#   → LIQUOR/GROCERY STORE/BAR:
#      - LIQUOR/GROCERY STORE/BAR
#      - GROCERY & LIQUOR STORE
#      - GROCERY/LIQUOR STORE
#
#   → WRIGLEY ROOFTOP:
#      - WRIGLEY ROOFTOP
#      - WRIGLEY ROOF TOP
#
#   → SERVICE GAS STATION:
#      - SERVICE GAS STATION
#      - GROCERY/SERVICE GAS STATION
#
#   → VENDING MACHINE:
#      - VENDING MACHINE
#      - COFFEE VENDING MACHINE
#
#   → AFTER SCHOOL PROGRAM:
#      - AFTER SCHOOL PROGRAM
#      - CHURCH/AFTER SCHOOL PROGRAM
#
#   → CHURCH (SPECIAL EVENTS):
#      - CHURCH (SPECIAL EVENTS)
#      - CHURCH/SPECIAL EVENTS
#      - CHURCH/SPECIAL EVENT
#
#   → MOBILE FOOD DESSERTS VENDOR:
#      - MOBILE FOOD DESSERTS VENDOR
#      - MOBILE DESSERTS VENDOR
#
#   → GROCERY/TAQUERIA:
#      - GROCERY/TAQUERIA
#      - GROCERY STORE/TAQUERIA
#
#   → TAVERN-LIQUOR:
#      - TAVERN-LIQUOR
#      - TAVERN/LIQUOR
#
#   → LONG-TERM CARE FACILITY:
#      - LONG-TERM CARE FACILITY
#      - LONG TERM CARE FACILITY
#
#   → MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED:
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#      - MOBILE FROZEN DESSERTS DISPENSER-NON- MOTORIZED
#      - MOBILE FROZEN DESSERT DISPENSER_NON  MOTORIZED.
#      - FROZEN DESSERTS DISPENSER -NON MOTORIZED
#      - MOBILE FROZEN DESSERTS DISPENSER-NON-MOTOR
#      - FROZEN DESSERTS DISPENSER-NON-MOTORIZED
#
#   → RESTAURANT/LIQUOR:
#      - RESTAURANT/LIQUOR
#      - RESTAURANT AND LIQUOR
#
#   → FOOD PANTRY/CHURCH:
#      - FOOD PANTRY/CHURCH
#      - CHURCH (FOOD PANTRY)
#
#   → KIDS CAFE:
#      - KIDS CAFE
#      - KIDS CAFE'
#
#   → COMMIASARY:
#      - COMMIASARY
#      - COMMISARY
#
#   → CHARTER SCHOOL CAFETERIA:
#      - CHARTER SCHOOL CAFETERIA
#      - CHARTER SCHOOL/CAFETERIA
#
#   → DOLLAR STORE WITH GROCERY:
#      - DOLLAR STORE WITH GROCERY
#      - GROCERY/DOLLAR STORE
#      - DOLLAR & GROCERY STORE
#
#   → HERBALIFE NUTRITION:
#      - HERBALIFE NUTRITION
#      - NUTRITION/HERBALIFE
#
#   → GAS STATION FOOD STORE:
#      - GAS STATION FOOD STORE
#      - GAS STATION/STORE
#      - GAS STATION/FOOD
#      - GAS STATION STORE
#
#   → GROCERY AND BUTCHER:
#      - GROCERY AND BUTCHER
#      - GROCERY/BUTCHER
#
#   → RETAIL FOOD/GAS STATION:
#      - RETAIL FOOD/GAS STATION
#      - GAS STATION/FOOD
#
#   → DRUG/FOOD STORE:
#      - DRUG/FOOD STORE
#      - DRUG STORE/W/ FOOD
#
#   → RESTAURANT/BAKERY:
#      - RESTAURANT/BAKERY
#      - BAKERY/ RESTAURANT
#      - BAKERY/RESTAURANT
#
#   → MOBILE DESSERT VENDOR:
#      - MOBILE DESSERT VENDOR
#      - MOBILE DESSERTS VENDOR
#      - MOBILE FROZEN DESSERT VENDOR
#
#   → GROCERY/LIQUOR:
#      - GROCERY/LIQUOR
#      - GROCERY/LIQUOR STORE
#
# 📦 Grouped values for 'City':
#
#   → CHICAGO:
#      - CHICAGO
#      - CHICAGO.
#
#   → OOLYMPIA FIELDS:
#      - OOLYMPIA FIELDS
#      - OLYMPIA FIELDS
#
# 📦 Grouped values for 'Inspection Type':
#
#   → COMPLAINT:
#      - COMPLAINT
#      - SFP/COMPLAINT
#
#   → COMPLAINT RE-INSPECTION:
#      - COMPLAINT RE-INSPECTION
#      - COMPLAINT-FIRE RE-INSPECTION
#
#   → SHORT FORM COMPLAINT:
#      - SHORT FORM COMPLAINT
#      - SHORT FORM FIRE-COMPLAINT
#
#   → TASK FORCE LIQUOR 1475:
#      - TASK FORCE LIQUOR 1475
#      - TASK FORCE LIQUOR 1470
#      - TASK FORCE LIQUOR 1474
#
#   → COMPLAINT-FIRE:
#      - COMPLAINT-FIRE
#      - FIRE COMPLAINT
#
#   → OUT OF BUSINESS:
#      - OUT OF BUSINESS
#      - OUT OFBUSINESS
#
#   → LICENSE CONSULTATION:
#      - LICENSE CONSULTATION
#      - PRE-LICENSE CONSULTATION
#
#   → CANVASS SCHOOL/SPECIAL EVENT:
#      - CANVASS SCHOOL/SPECIAL EVENT
#      - CANVASS/SPECIAL EVENT
#
#   → TASK FORCE FOR LIQUOR 1474:
#      - TASK FORCE FOR LIQUOR 1474
#      - TASK FORCE LIQUOR 1474
#
#   → CANVASS RE INSPECTION OF CLOSE UP:
#      - CANVASS RE INSPECTION OF CLOSE UP
#      - RE-INSPECTION OF CLOSE-UP
#
#   → KIDS CAFE:
#      - KIDS CAFE
#      - KIDS CAFE'
#
#   → TASK FORCE NOT READY:
#      - TASK FORCE NOT READY
#      - LIQOUR TASK FORCE NOT READY
#
#   → CANVASS SPECIAL EVENTS:
#      - CANVASS SPECIAL EVENTS
#      - CANVASS/SPECIAL EVENT
#
#   → FIRE/COMPLAIN:
#      - FIRE/COMPLAIN
#      - FIRE COMPLAINT
#
#   → TASKFORCE:
#      - TASKFORCE
#      - TASK FORCE
#
#   → LICENSE RENEWAL FOR DAYCARE:
#      - LICENSE RENEWAL FOR DAYCARE
#      - LICENSE RENEWAL INSPECTION FOR DAYCARE
#
#   → LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB:
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLUB
#      - LICENSE TASK FORCE / NOT -FOR-PROFIT CLU
#
#   → TASK FORCE(1470) LIQUOR TAVERN:
#      - TASK FORCE(1470) LIQUOR TAVERN
#      - TASK FORCE LIQUOR 1470

# %%
import pandas as pd
import re

# Load your CSV
df = pd.read_csv("Food_Inspections_Cleaned.csv")  # Adjust filename if needed

# Function to extract and analyze violations
def extract_violations(row):
    violation_text = row.get('Violations', '')
    row_index = row.name

    if pd.isna(violation_text):
        return []

    parts = [v.strip() for v in violation_text.split('|') if v.strip()]
    pattern = r"(?P<number>\d+)\.\s+(?P<text>.+?)\s+-\s+Comments:\s+(?P<comment>.+)"

    extracted = []
    for part in parts:
        match = re.match(pattern, part)
        combined = row.drop(labels=['Violations']).to_dict()
        combined['raw_violation'] = part

        if match:
            v = match.groupdict()
            combined['violation_number'] = v['number']
            combined['violation_text'] = v['text']
            combined['violation_comment'] = v['comment']
            combined['parse_error'] = False
            combined['error_reason'] = ""
        else:
            # Attempt to detect error reason
            if not re.search(r"\d+\.", part):
                reason = "missing violation number"
            elif "Comments:" not in part:
                reason = "missing 'Comments:'"
            else:
                reason = "general format mismatch"
            
            combined['violation_number'] = None
            combined['violation_text'] = None
            combined['violation_comment'] = None
            combined['parse_error'] = True
            combined['error_reason'] = reason

        extracted.append(combined)
    return extracted

# Process each row
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(extract_violations(row))

# Create the final DataFrame
violations_expanded_df = pd.DataFrame(expanded_rows)

# Save to CSV
violations_expanded_df.to_csv("Food_Inspections_Violations_Expanded_with_cleandata.csv", index=False)

print("✅ Done! File saved as: Food_Inspections_Violations_Expanded.csv")
# Out:
# ✅ Done! File saved as: Food_Inspections_Violations_Expanded.csv

# %%
import pandas as pd
import itertools

# === Step 1: Load your data ===
# Replace with your actual filename
file_path = "Food_Inspections_Violations_Expanded_with_cleandata.csv"
df = pd.read_csv(file_path)

# Drop columns that are entirely empty
df = df.dropna(axis=1, how='all')

# === Step 2: Set up ===
columns = df.columns.tolist()
max_comb_size = 2  # We’ll check 1 or 2 column combos
valid_fds = []
violated_fds = {}

# === Step 3: FD Check Function ===
def check_fd(data, A, B):
    grouped = data.groupby(A)[B].nunique()
    violations = grouped[(grouped > 1).any(axis=1)]
    return violations.empty, violations

# === Step 4: Try all combinations ===
for a_len in range(1, max_comb_size + 1):
    for A in itertools.combinations(columns, a_len):
        remaining_cols = [col for col in columns if col not in A]
        for b_len in range(1, max_comb_size + 1):
            for B in itertools.combinations(remaining_cols, b_len):
                is_valid, sample_violations = check_fd(df, list(A), list(B))
                fd_str = f"{list(A)} → {list(B)}"
                if is_valid:
                    valid_fds.append(fd_str)
                elif not sample_violations.empty:
                    violated_fds[fd_str] = sample_violations.head(3)

# === Step 5: Save results ===
# Save valid FDs
valid_fds_df = pd.DataFrame(valid_fds, columns=["Functional Dependency"])
valid_fds_df.to_csv("valid_functional_dependencies.csv", index=False)

# Save violations summary
violated_summary_df = pd.DataFrame([
    {"FD": fd, "Sample Violations": v.reset_index().to_dict(orient='records')}
    for fd, v in violated_fds.items()
])
violated_summary_df.to_csv("violated_functional_dependencies_samples.csv", index=False)

print("✅ FD discovery complete.")
print("📄 Saved: valid_functional_dependencies.csv")
print("📄 Saved: violated_functional_dependencies_samples.csv")

# %%
import pandas as pd
from fuzzywuzzy import process

# Load dataset
df = pd.read_csv("Food_Inspections_Violations_Expanded_with_cleandata.csv")

# Columns to clean
columns_to_clean = ['Address']

# Dictionary to store grouped labels for display
all_grouped_labels = {}

# Function to clean one column
def clean_column_fuzzy(df, column_name):
    print(f"\n🔍 Processing column: {column_name}")
    
    # Step 1: Capitalize everything
    df[column_name] = df[column_name].astype(str).str.strip().str.upper()

    # Step 2: Get unique values
    unique_values = df[column_name].dropna().unique().tolist()

    # Step 3: Fuzzy group similar values
    grouped_map = {}     # raw -> cleaned
    grouped_labels = {}  # cleaned -> [originals]

    for value in unique_values:
        if value in grouped_map:
            continue  # Already grouped

        # Fuzzy match: similarity >= 85
        matches = process.extract(value, unique_values, limit=None)
        close_matches = [m for m, score in matches if score >= 95]

        canonical = close_matches[0]

        for match in close_matches:
            grouped_map[match] = canonical

        grouped_labels[canonical] = close_matches

    # Step 4: Create new cleaned column
    cleaned_col = f"{column_name} Cleaned"
    df[cleaned_col] = df[column_name].map(grouped_map)

    # Save grouping for display
    all_grouped_labels[column_name] = grouped_labels

    return df

# Apply to each target column
for col in columns_to_clean:
    df = clean_column_fuzzy(df, col)

# Save new CSV
df.to_csv("Food_Inspections_Violations_Expanded_with_cleandata_address.csv", index=False)
print("\n✅ Cleaned data saved as: Food_Inspections_Cleaned.csv")

'''
# Show grouping results
for col, group_map in all_grouped_labels.items():
    print(f"\n📦 Grouped values for '{col}':")
    for canonical, group in group_map.items():
        if len(group) > 1:
            print(f"\n  → {canonical}:")
            for g in group:
                print(f"     - {g}")
'''
# Out:
# C:\Users\A102730\AppData\Local\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 🔍 Processing column: Address

# %%
import pandas as pd
from thefuzz import process, fuzz
from collections import defaultdict

def fuzzy_normalize_column(df, column_name, threshold=80):
    """
    Normalize text values in a DataFrame column using fuzzy matching.
    
    Args:
    - df (pd.DataFrame): Input DataFrame.
    - column_name (str): Column name to normalize.
    - threshold (int): Similarity threshold for fuzzy matching (default is 80).
    
    Returns:
    - pd.DataFrame: DataFrame with a new normalized column.
    """
    df[column_name] = df[column_name].astype(str).fillna('')  # Convert to string

    unique_values = list(set(df[column_name].str.lower()))  # Unique values in lowercase

    # Reference mapping for normalization
    reference_mapping = {}
    groups = defaultdict(list)  # To store word clusters

    for value in unique_values:
        # Check if it's already in a group
        if value in reference_mapping:
            continue
        
        # Find similar words
        matches = process.extract(value, unique_values, limit=10, scorer=fuzz.ratio)
        matches = [(match, score) for match, score in matches if score >= threshold]
        
        if matches:
            best_match = max(matches, key=lambda x: x[1])[0]  # Pick the best-scoring match
        else:
            best_match = value  # Keep original if no good match found

        # Assign all similar words to the best match
        for match, score in matches:
            reference_mapping[match] = best_match
            groups[best_match].append(match)

    # Apply normalization mapping
    df[f'{column_name}_normalised'] = df[column_name].str.lower().map(reference_mapping)
    
    return df

# %%
pip install thefuzz
# Out:
# Collecting thefuzzNote: you may need to restart the kernel to use updated packages.
#
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz)
#   Downloading rapidfuzz-3.12.2-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading rapidfuzz-3.12.2-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, thefuzz
# Successfully installed rapidfuzz-3.12.2 thefuzz-0.22.1

# %%
# Load dataset
df = pd.read_csv("Food_Inspections_Violations_Expanded_with_cleandata.csv")

# %%
fuzzy_normalize_column(df, 'Address', 95)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
#         Inspection ID                            DBA Name  \
# 0             1106427                BLOOMING BUD DAYCARE
# 1             1106427                BLOOMING BUD DAYCARE
# 2             1106427                BLOOMING BUD DAYCARE
# 3             1106427                BLOOMING BUD DAYCARE
# 4             2608378                         Babas Halal
# ...               ...                                 ...
# 939275        2610409            ACE SUSHI @POTASH MARKET
# 939276        2610409            ACE SUSHI @POTASH MARKET
# 939277        2610823                Kitchen Chicago, LLC
# 939278        2610823                Kitchen Chicago, LLC
# 939279        2610068  HANNAH'S BRETZEL 227 W. MONROE LLC
#
#                     AKA Name  License #       Facility Type           Risk  \
# 0       BLOOMING BUD DAYCARE  2215789.0  DAYCARE COMBO 1586  Risk 1 (High)
# 1       BLOOMING BUD DAYCARE  2215789.0  DAYCARE COMBO 1586  Risk 1 (High)
# 2       BLOOMING BUD DAYCARE  2215789.0  DAYCARE COMBO 1586  Risk 1 (High)
# 3       BLOOMING BUD DAYCARE  2215789.0  DAYCARE COMBO 1586  Risk 1 (High)
# 4                Babas Halal  2684170.0          RESTAURANT  Risk 1 (High)
# ...                      ...        ...                 ...            ...
# 939275             ACE SUSHI  2808766.0          RESTAURANT  Risk 1 (High)
# 939276             ACE SUSHI  2808766.0          RESTAURANT  Risk 1 (High)
# 939277  Kitchen Chicago, LLC  2119905.0      SHARED KITCHEN  Risk 1 (High)
# 939278  Kitchen Chicago, LLC  2119905.0      SHARED KITCHEN  Risk 1 (High)
# 939279      HANNAH'S BRETZEL  2428372.0          RESTAURANT  Risk 1 (High)
#
#                    Address     City State      Zip  ... Facility Type Cleaned  \
# 0       5715 N LINCOLN AVE  CHICAGO    IL  60659.0  ...    DAYCARE COMBO 1586
# 1       5715 N LINCOLN AVE  CHICAGO    IL  60659.0  ...    DAYCARE COMBO 1586
# 2       5715 N LINCOLN AVE  CHICAGO    IL  60659.0  ...    DAYCARE COMBO 1586
# 3       5715 N LINCOLN AVE  CHICAGO    IL  60659.0  ...    DAYCARE COMBO 1586
# 4         7901 S DAMEN AVE  CHICAGO    IL  60620.0  ...            RESTAURANT
# ...                    ...      ...   ...      ...  ...                   ...
# 939275      875 N STATE ST  CHICAGO    IL  60610.0  ...            RESTAURANT
# 939276      875 N STATE ST  CHICAGO    IL  60610.0  ...            RESTAURANT
# 939277    324 N LEAVITT ST  CHICAGO    IL  60612.0  ...        SHARED KITCHEN
# 939278    324 N LEAVITT ST  CHICAGO    IL  60612.0  ...        SHARED KITCHEN
# 939279     227 W MONROE ST  CHICAGO    IL  60606.0  ...            RESTAURANT
#
#        City Cleaned Inspection Type Cleaned  \
# 0           CHICAGO                 LICENSE
# 1           CHICAGO                 LICENSE
# 2           CHICAGO                 LICENSE
# 3           CHICAGO                 LICENSE
# 4           CHICAGO               COMPLAINT
# ...             ...                     ...
# 939275      CHICAGO                 CANVASS
# 939276      CHICAGO                 CANVASS
# 939277      CHICAGO                 CANVASS
# 939278      CHICAGO                 CANVASS
# 939279      CHICAGO                 CANVASS
#
#                                             raw_violation  violation_number  \
# 0       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...              32.0
# 1       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...              32.0
# 2       34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...              34.0
# 3       35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...              35.0
# 4       1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...               1.0
# ...                                                   ...               ...
# 939275  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...              55.0
# 939276  58. ALLERGEN TRAINING AS REQUIRED - Comments: ...              58.0
# 939277  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...              49.0
# 939278  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...              55.0
# 939279  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...              37.0
#
#                                            violation_text  \
# 0       FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 1       FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 2       FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 3       WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4       PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLED...
# ...                                                   ...
# 939275  PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN
# 939276                      ALLERGEN TRAINING AS REQUIRED
# 939277               NON-FOOD/FOOD CONTACT SURFACES CLEAN
# 939278  PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN
# 939279          FOOD PROPERLY LABELED; ORIGINAL CONTAINER
#
#                                         violation_comment parse_error  \
# 0        PROVIDE A DRAIN BOARD AT THREE COMPARTMENT SINK.       False
# 1       OBSERVED RUSTY GREASE TRAP UNDER THE THREE COM...       False
# 2       INSTRUCTED TO SWEEP FLOOR INSIDE THE FURNACE A...       False
# 3       OBSERVED DEAD BULB IN THE KITCHEN, INSTRUCTED ...       False
# 4       PIC DOESN'T HAVE A CERTIFIED FOOD MANAGERS CER...       False
# ...                                                   ...         ...
# 939275  OBSERVED SMALL DEBRIS ON FLOOR IN PREP AREA.  ...       False
# 939276  OBSERVED NOT ALLERGEN TRAINING CERTIFICATE ON ...       False
# 939277  CLEAN THE STORAGE SHELVES IN ZELLA'S STORAGE C...       False
# 939278  CLEAN THE FLOOR IN ZELLA'S STORAGE CLOSET.  CL...       False
# 939279  Water spray bottles not labeled, Instructed to...       False
#
#        error_reason   Address_normalised
# 0               NaN  5715 n lincoln ave
# 1               NaN  5715 n lincoln ave
# 2               NaN  5715 n lincoln ave
# 3               NaN  5715 n lincoln ave
# 4               NaN     7901 s damen ave
# ...             ...                  ...
# 939275          NaN      875 n state st
# 939276          NaN      875 n state st
# 939277          NaN    324 n leavitt st
# 939278          NaN    324 n leavitt st
# 939279          NaN      22 w monroe st
#
# [939280 rows x 26 columns]

# %%
df.to_csv("Food_Inspections_Violations_Expanded_with_cleandata_address.csv", index=False)

# %%
# !git clone https://github.com/leonswl/ntu-msds-sd6104
# Out:
# Cloning into 'ntu-msds-sd6104'...
# Updating files:  70% (17/24)
# Updating files:  75% (18/24)
# Updating files:  79% (19/24)
# Updating files:  83% (20/24)
# Updating files:  87% (21/24)
# Updating files:  91% (22/24)
# Updating files:  95% (23/24)
# Updating files: 100% (24/24)
# Updating files: 100% (24/24), done.

# %%
# %cd ntu-msds-sd6104\notebooks\wangyu
# Out:
# C:\Users\A102730\Data preparation\ntu-msds-sd6104\notebooks\wangyu

# %%
# !git add .

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git add project_v5.ipynb
# Out:
# fatal: pathspec 'project_v5.ipynb' did not match any files

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 58C0-E456
#
#  Directory of C:\Users\A102730\Data preparation\ntu-msds-sd6104\notebooks\wangyu
#
# 04/05/2025  03:37 PM    <DIR>          .
# 04/05/2025  03:37 PM    <DIR>          ..
#                0 File(s)              0 bytes
#                2 Dir(s)  103,830,765,568 bytes free
