# %% [markdown]
# ## Functional Dependencies
#
# Discovery functional dependencies from the columns.
#
# - Functional Dependencies
# - Approximate Functional Dependencies
# - Pruning
# -

# %%
from rich.console import Console, inspect

# %%
console = Console()

# %%
import pandas as pd
import desbordante

# %%
file_path = "../data/Food_Inspections_20250216.csv"
df = pd.read_csv(file_path, header=[0])
df.head()
# Out:
#    Inspection ID                    DBA Name                    AKA Name  \
# 0        1106427        BLOOMING BUD DAYCARE        BLOOMING BUD DAYCARE
# 1        2608378                 Babas Halal                 Babas Halal
# 2        1106406    FIRST ZABIHA MEAT BAZAAR    FIRST ZABIHA MEAT BAZAAR
# 3        2609909                HAPPY MARKET                HAPPY MARKET
# 4        2609927  SAT KAIVAL FOOD INC/SUBWAY  SAT KAIVAL FOOD INC/SUBWAY
#
#    License #       Facility Type             Risk               Address  \
# 0  2215789.0  Daycare Combo 1586    Risk 1 (High)    5715 N LINCOLN AVE
# 1  2684170.0          Restaurant    Risk 1 (High)      7901 S DAMEN AVE
# 2  2232559.0       Grocery Store  Risk 2 (Medium)      2907 W DEVON AVE
# 3  2912802.0       Grocery Store  Risk 2 (Medium)  2334 S WENTWORTH AVE
# 4  2728400.0          Restaurant    Risk 1 (High)       1916 S STATE ST
#
#       City State      Zip Inspection Date Inspection Type             Results  \
# 0  CHICAGO    IL  60659.0      03/07/2013         License                Pass
# 1  CHICAGO    IL  60620.0      12/03/2024       Complaint                Fail
# 2  CHICAGO    IL  60659.0      02/20/2013         License                Fail
# 3  CHICAGO    IL  60616.0      01/02/2025         Canvass  Pass w/ Conditions
# 4  CHICAGO    IL  60616.0      01/02/2025         Canvass                Pass
#
#                                           Violations   Latitude  Longitude  \
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.985390 -87.698734
# 1  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.750189 -87.672986
# 2  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  41.997401 -87.702385
# 3  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.849954 -87.632094
# 4  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.856053 -87.627311
#
#                                    Location
# 0   (41.98538950526786, -87.69873407149943)
# 1  (41.750189342293375, -87.67298583977204)
# 2   (41.99740137039031, -87.70238538227812)
# 3   (41.84995400192252, -87.63209419559098)
# 4   (41.85605269621059, -87.62731125804903)

# %% [markdown]
# ### Functional Dependencies

# %%
import desbordante.fd.algorithms as fd_algorithms

# %%
def find_fds(df, algorithm_name='Default'):
    """
    Finds functional dependencies in a given DataFrame using a specified algorithm.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        algorithm_name (str): The name of the FD algorithm to use. Defaults to 'Default'. Options are 
    
    Returns:
        list: A list of discovered functional dependencies.
    """
    try:
        # Get the algorithm class dynamically from desbordante.fd.algorithms
        algo_class = getattr(fd_algorithms, algorithm_name, fd_algorithms.Default)

        print(f"Algorthm: {algo_class}")
        
        algo = algo_class()
        algo.load_data(table=df)
        algo.execute()
        return algo.get_fds()
    except AttributeError:
        raise ValueError(f"Algorithm '{algorithm_name}' not found. Available algorithms: {dir(fd_algorithms)}")

# %%
dir(fd_algorithms)
# Out:
# ['Aid',
#  'DFD',
#  'Default',
#  'Depminer',
#  'EulerFD',
#  'FDep',
#  'FUN',
#  'FastFDs',
#  'FdMine',
#  'HyFD',
#  'PFDTane',
#  'Pyro',
#  'Tane',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %% [markdown]
# **Using the default FD algorithm**

# %%
default_results = find_fds(df)

print(f"There are {len(default_results)} functional dependencies using Default algorithm.")

for fd in default_results:
    print(fd)
# Out:
# Algorthm: <class 'desbordante.fd.algorithms.HyFD'>
# There are 235 functional dependencies using Default algorithm.
# [Inspection ID] -> Violations
# [Inspection ID] -> License #
# [Inspection ID] -> DBA Name
# [Inspection ID] -> AKA Name
# [Inspection ID] -> Address
# [Inspection ID] -> Latitude
# [Inspection ID] -> Longitude
# [Inspection ID] -> Location
# [Inspection ID] -> Inspection Date
# [Inspection ID] -> Facility Type
# [Inspection ID] -> Zip
# [Inspection ID] -> Inspection Type
# [Inspection ID] -> City
# [Inspection ID] -> State
# [Inspection ID] -> Results
# [Inspection ID] -> Risk
# [DBA Name AKA Name License # Violations Latitude] -> Zip
# [DBA Name AKA Name License # Violations Longitude] -> Zip
# [DBA Name AKA Name License # Violations Location] -> Zip
# [DBA Name AKA Name License # Zip Violations] -> City
# [DBA Name License # Address City Violations] -> Zip
# [DBA Name License # City Violations Latitude] -> Zip
# [DBA Name License # City Violations Longitude] -> Zip
# [DBA Name License # City Violations Location] -> Zip
# [DBA Name License # Facility Type City Inspection Date Results Violations] -> Zip
# [DBA Name License # Zip Inspection Type Violations] -> City
# [AKA Name License # Address Violations] -> Zip
# [AKA Name License # Inspection Date Violations Latitude] -> Zip
# [AKA Name License # Facility Type Risk Violations Latitude] -> Zip
# [AKA Name License # Risk Inspection Type Violations Latitude] -> Zip
# [AKA Name License # Risk Results Violations Latitude] -> Zip
# [AKA Name License # Inspection Date Violations Longitude] -> Zip
# [AKA Name License # Facility Type Risk Violations Longitude] -> Zip
# [AKA Name License # Risk Inspection Type Violations Longitude] -> Zip
# [AKA Name License # Risk Results Violations Longitude] -> Zip
# [AKA Name License # Inspection Date Violations Location] -> Zip
# [AKA Name License # Facility Type Risk Violations Location] -> Zip
# [AKA Name License # Risk Inspection Type Violations Location] -> Zip
# [AKA Name License # Risk Results Violations Location] -> Zip
# [AKA Name License # City Inspection Date Results Violations] -> Zip
# [AKA Name License # Zip Inspection Type Violations] -> City
# [AKA Name License # Risk Zip Violations] -> City
# [License # Address Zip Inspection Date Violations] -> City
# [License # Facility Type Address City Violations] -> Zip
# [License # Risk Address City Violations] -> Zip
# [License # City Inspection Date Violations Latitude] -> Zip
# [License # Facility Type Risk City Violations Latitude] -> Zip
# [License # Risk City Inspection Type Violations Latitude] -> Zip
# [License # Risk City Results Violations Latitude] -> Zip
# [License # City Inspection Date Violations Longitude] -> Zip
# [License # Facility Type Risk City Violations Longitude] -> Zip
# [License # Risk City Inspection Type Violations Longitude] -> Zip
# [License # Risk City Results Violations Longitude] -> Zip
# [License # City Inspection Date Violations Location] -> Zip
# [License # Facility Type Risk City Violations Location] -> Zip
# [License # Risk City Inspection Type Violations Location] -> Zip
# [License # Risk City Results Violations Location] -> Zip
# [License # Zip Inspection Date Inspection Type Violations] -> City
# [DBA Name AKA Name Facility Type Address Violations] -> Zip
# [DBA Name AKA Name Address Results Violations] -> Zip
# [DBA Name AKA Name Zip Inspection Date Violations] -> City
# [DBA Name AKA Name Zip Inspection Type Results Violations] -> City
# [DBA Name AKA Name Risk Zip Inspection Type Violations] -> City
# [DBA Name Facility Type Address City Violations] -> Zip
# [DBA Name Address City Results Violations] -> Zip
# [DBA Name Facility Type Risk Zip Inspection Type Violations Latitude] -> City
# [DBA Name Inspection Type Violations Latitude] -> State
# [DBA Name Results Violations Latitude] -> State
# [DBA Name Facility Type Risk Zip Inspection Type Violations Longitude] -> City
# [DBA Name Inspection Type Violations Longitude] -> State
# [DBA Name Results Violations Longitude] -> State
# [DBA Name Facility Type Risk Zip Inspection Type Violations Location] -> City
# [DBA Name Inspection Type Violations Location] -> State
# [DBA Name Results Violations Location] -> State
# [DBA Name Inspection Date Violations] -> State
# [DBA Name Facility Type Zip Inspection Date Inspection Type Violations] -> City
# [DBA Name Facility Type Zip Inspection Type Results Violations] -> City
# [DBA Name Zip Violations] -> State
# [AKA Name Address Violations] -> City
# [AKA Name Address Inspection Date Violations] -> Zip
# [AKA Name Zip Inspection Type Results Violations Latitude] -> City
# [AKA Name Risk Zip Inspection Type Violations Latitude] -> City
# [AKA Name Inspection Type Violations Latitude] -> State
# [AKA Name Results Violations Latitude] -> State
# [AKA Name Zip Inspection Type Results Violations Longitude] -> City
# [AKA Name Risk Zip Inspection Type Violations Longitude] -> City
# [AKA Name Inspection Type Violations Longitude] -> State
# [AKA Name Results Violations Longitude] -> State
# [AKA Name Zip Inspection Type Results Violations Location] -> City
# [AKA Name Risk Zip Inspection Type Violations Location] -> City
# [AKA Name Inspection Type Violations Location] -> State
# [AKA Name Results Violations Location] -> State
# [AKA Name Inspection Date Violations] -> State
# [AKA Name Zip Violations] -> State
# [Inspection Date Violations Latitude] -> State
# [City Inspection Type Violations Latitude] -> State
# [City Results Violations Latitude] -> State
# [Inspection Date Violations Longitude] -> State
# [City Inspection Type Violations Longitude] -> State
# [City Results Violations Longitude] -> State
# [Inspection Date Violations Location] -> State
# [City Inspection Type Violations Location] -> State
# [City Results Violations Location] -> State
# [Risk City Zip Inspection Date Results Violations] -> State
# [License #] -> State
# [DBA Name AKA Name License # Facility Type Address] -> Zip
# [DBA Name AKA Name License # Address Results] -> Zip
# [DBA Name AKA Name License # Inspection Date Latitude] -> Zip
# [DBA Name AKA Name License # Facility Type Latitude] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Latitude] -> Zip
# [DBA Name AKA Name License # Risk Results Latitude] -> Zip
# [DBA Name AKA Name License # Inspection Date Longitude] -> Zip
# [DBA Name AKA Name License # Facility Type Longitude] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Longitude] -> Zip
# [DBA Name AKA Name License # Risk Results Longitude] -> Zip
# [DBA Name AKA Name License # Inspection Date Location] -> Zip
# [DBA Name AKA Name License # Facility Type Location] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Location] -> Zip
# [DBA Name AKA Name License # Risk Results Location] -> Zip
# [DBA Name License # City Inspection Date Latitude] -> Zip
# [DBA Name License # City Inspection Date Longitude] -> Zip
# [DBA Name License # City Inspection Date Location] -> Zip
# [DBA Name License # Zip Inspection Date Inspection Type] -> City
# [DBA Name License # Facility Type Zip Inspection Type] -> City
# [DBA Name License # Zip Results] -> City
# [AKA Name License # Address] -> City
# [AKA Name License # Address Inspection Date] -> Zip
# [AKA Name License # Address Inspection Type Results] -> Zip
# [AKA Name License # Latitude] -> City
# [AKA Name License # Inspection Date Results Latitude] -> Zip
# [AKA Name License # Risk Inspection Type Results Latitude] -> Zip
# [AKA Name License # Longitude] -> City
# [AKA Name License # Inspection Date Results Longitude] -> Zip
# [AKA Name License # Risk Inspection Type Results Longitude] -> Zip
# [AKA Name License # Location] -> City
# [AKA Name License # Inspection Date Results Location] -> Zip
# [AKA Name License # Risk Inspection Type Results Location] -> Zip
# [AKA Name License # Zip Inspection Date] -> City
# [AKA Name License # Facility Type Zip] -> City
# [AKA Name License # Zip Results] -> City
# [License # Address City Inspection Date] -> Zip
# [License # Facility Type Address Zip] -> City
# [License # City Inspection Date Results Latitude] -> Zip
# [License # Facility Type Zip Inspection Type Latitude] -> City
# [License # Facility Type Zip Results Latitude] -> City
# [License # City Inspection Date Results Longitude] -> Zip
# [License # Facility Type Zip Inspection Type Longitude] -> City
# [License # Facility Type Zip Results Longitude] -> City
# [License # City Inspection Date Results Location] -> Zip
# [License # Facility Type Zip Inspection Type Location] -> City
# [License # Facility Type Zip Results Location] -> City
# [License # Facility Type Zip Inspection Date Inspection Type] -> City
# [License # Zip Inspection Date Results] -> City
# [DBA Name AKA Name Risk Address] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Latitude] -> City
# [DBA Name AKA Name Inspection Date Results Latitude] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Longitude] -> City
# [DBA Name AKA Name Inspection Date Results Longitude] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Location] -> City
# [DBA Name AKA Name Inspection Date Results Location] -> City
# [DBA Name AKA Name Zip Inspection Date Inspection Type] -> City
# [DBA Name AKA Name Zip Inspection Date Results] -> City
# [DBA Name Address] -> State
# [DBA Name Address Inspection Date] -> Zip
# [DBA Name Address Inspection Date] -> City
# [DBA Name Address Zip] -> City
# [DBA Name Facility Type Zip Inspection Date Inspection Type Latitude] -> City
# [DBA Name Facility Type Latitude] -> State
# [DBA Name Zip Latitude] -> State
# [DBA Name Facility Type Zip Inspection Date Inspection Type Longitude] -> City
# [DBA Name Facility Type Longitude] -> State
# [DBA Name Zip Longitude] -> State
# [DBA Name Facility Type Zip Inspection Date Inspection Type Location] -> City
# [DBA Name Facility Type Location] -> State
# [DBA Name Zip Location] -> State
# [DBA Name Facility Type Inspection Date] -> State
# [DBA Name Facility Type Zip Inspection Date Results] -> City
# [DBA Name Zip Inspection Date] -> State
# [DBA Name Inspection Date Inspection Type] -> State
# [DBA Name Inspection Date Results] -> State
# [AKA Name Address] -> State
# [AKA Name Address Inspection Date] -> City
# [AKA Name Address Inspection Date Inspection Type] -> Zip
# [AKA Name Address Inspection Date Results] -> Zip
# [AKA Name Address Zip] -> City
# [AKA Name Address Inspection Type] -> City
# [AKA Name Risk Address Results] -> City
# [AKA Name Zip Inspection Date Latitude] -> City
# [AKA Name Risk Inspection Date Inspection Type Latitude] -> City
# [AKA Name Risk Inspection Date Results Latitude] -> City
# [AKA Name Facility Type Latitude] -> State
# [AKA Name Zip Latitude] -> State
# [AKA Name Zip Inspection Date Longitude] -> City
# [AKA Name Risk Inspection Date Inspection Type Longitude] -> City
# [AKA Name Risk Inspection Date Results Longitude] -> City
# [AKA Name Facility Type Longitude] -> State
# [AKA Name Zip Longitude] -> State
# [AKA Name Zip Inspection Date Location] -> City
# [AKA Name Risk Inspection Date Inspection Type Location] -> City
# [AKA Name Risk Inspection Date Results Location] -> City
# [AKA Name Facility Type Location] -> State
# [AKA Name Zip Location] -> State
# [AKA Name Facility Type Inspection Date] -> State
# [AKA Name Zip Inspection Date] -> State
# [AKA Name Inspection Date Inspection Type] -> State
# [AKA Name Inspection Date Results] -> State
# [Address] -> Latitude
# [Address] -> Longitude
# [Address] -> Location
# [Address Inspection Date] -> State
# [Address City] -> State
# [Latitude] -> Longitude
# [Latitude] -> Location
# [Facility Type Risk Inspection Date Latitude] -> State
# [Zip Inspection Date Latitude] -> State
# [City Inspection Date Inspection Type Latitude] -> State
# [City Inspection Date Results Latitude] -> State
# [Facility Type City Latitude] -> State
# [City Zip Latitude] -> State
# [Longitude] -> Latitude
# [Longitude] -> Location
# [Facility Type Risk Inspection Date Longitude] -> State
# [Zip Inspection Date Longitude] -> State
# [City Inspection Date Inspection Type Longitude] -> State
# [City Inspection Date Results Longitude] -> State
# [Facility Type City Longitude] -> State
# [City Zip Longitude] -> State
# [Location] -> Latitude
# [Location] -> Longitude
# [Facility Type Risk Inspection Date Location] -> State
# [Zip Inspection Date Location] -> State
# [City Inspection Date Inspection Type Location] -> State
# [City Inspection Date Results Location] -> State
# [Facility Type City Location] -> State
# [City Zip Location] -> State

# %% [markdown]
# **Using TANE algorithm**

# %%
tane_results = find_fds(df, "Tane")

print(f"There are {len(tane_results)} functional dependencies using TANE algorithm.")
for fd in tane_results:
    print(fd)
# Out:
# Algorthm: <class 'desbordante.fd.algorithms.Tane'>
# There are 235 functional dependencies using TANE algorithm.
# [Inspection ID] -> DBA Name
# [Inspection ID] -> AKA Name
# [Inspection ID] -> License #
# [Inspection ID] -> Facility Type
# [Inspection ID] -> Risk
# [Inspection ID] -> Address
# [Inspection ID] -> City
# [Inspection ID] -> State
# [Inspection ID] -> Zip
# [Inspection ID] -> Inspection Date
# [Inspection ID] -> Inspection Type
# [Inspection ID] -> Results
# [Inspection ID] -> Violations
# [Inspection ID] -> Latitude
# [Inspection ID] -> Longitude
# [Inspection ID] -> Location
# [License #] -> State
# [Address] -> Latitude
# [Address] -> Longitude
# [Latitude] -> Longitude
# [Longitude] -> Latitude
# [Address] -> Location
# [Latitude] -> Location
# [Location] -> Latitude
# [Longitude] -> Location
# [Location] -> Longitude
# [DBA Name Address] -> State
# [AKA Name Address] -> State
# [Address City] -> State
# [Address Inspection Date] -> State
# [AKA Name License # Address] -> City
# [DBA Name Address Zip] -> City
# [AKA Name Address Zip] -> City
# [DBA Name Address Inspection Date] -> City
# [AKA Name Address Inspection Date] -> City
# [DBA Name Facility Type Inspection Date] -> State
# [AKA Name Facility Type Inspection Date] -> State
# [DBA Name Address Inspection Date] -> Zip
# [DBA Name Zip Inspection Date] -> State
# [AKA Name Zip Inspection Date] -> State
# [AKA Name Address Inspection Type] -> City
# [DBA Name Inspection Date Inspection Type] -> State
# [AKA Name Inspection Date Inspection Type] -> State
# [DBA Name Inspection Date Results] -> State
# [AKA Name Inspection Date Results] -> State
# [AKA Name Address Violations] -> City
# [DBA Name Zip Violations] -> State
# [AKA Name Zip Violations] -> State
# [DBA Name Inspection Date Violations] -> State
# [AKA Name Inspection Date Violations] -> State
# [AKA Name License # Latitude] -> City
# [DBA Name Facility Type Latitude] -> State
# [AKA Name Facility Type Latitude] -> State
# [Facility Type City Latitude] -> State
# [DBA Name Zip Latitude] -> State
# [AKA Name Zip Latitude] -> State
# [City Zip Latitude] -> State
# [Zip Inspection Date Latitude] -> State
# [Inspection Date Violations Latitude] -> State
# [AKA Name License # Longitude] -> City
# [DBA Name Facility Type Longitude] -> State
# [AKA Name Facility Type Longitude] -> State
# [Facility Type City Longitude] -> State
# [DBA Name Zip Longitude] -> State
# [AKA Name Zip Longitude] -> State
# [City Zip Longitude] -> State
# [Zip Inspection Date Longitude] -> State
# [Inspection Date Violations Longitude] -> State
# [AKA Name License # Location] -> City
# [DBA Name Facility Type Location] -> State
# [AKA Name Facility Type Location] -> State
# [Facility Type City Location] -> State
# [DBA Name Zip Location] -> State
# [AKA Name Zip Location] -> State
# [City Zip Location] -> State
# [Zip Inspection Date Location] -> State
# [Inspection Date Violations Location] -> State
# [DBA Name AKA Name Risk Address] -> City
# [AKA Name License # Facility Type Zip] -> City
# [License # Facility Type Address Zip] -> City
# [AKA Name License # Address Inspection Date] -> Zip
# [AKA Name License # Zip Inspection Date] -> City
# [License # Address City Inspection Date] -> Zip
# [AKA Name Address Inspection Date Inspection Type] -> Zip
# [AKA Name Risk Address Results] -> City
# [DBA Name License # Zip Results] -> City
# [AKA Name License # Zip Results] -> City
# [AKA Name Address Inspection Date Results] -> Zip
# [License # Zip Inspection Date Results] -> City
# [AKA Name License # Address Violations] -> Zip
# [AKA Name Address Inspection Date Violations] -> Zip
# [Facility Type Risk Inspection Date Latitude] -> State
# [AKA Name Zip Inspection Date Latitude] -> City
# [City Inspection Date Inspection Type Latitude] -> State
# [City Inspection Date Results Latitude] -> State
# [DBA Name Inspection Type Violations Latitude] -> State
# [AKA Name Inspection Type Violations Latitude] -> State
# [City Inspection Type Violations Latitude] -> State
# [DBA Name Results Violations Latitude] -> State
# [AKA Name Results Violations Latitude] -> State
# [City Results Violations Latitude] -> State
# [Facility Type Risk Inspection Date Longitude] -> State
# [AKA Name Zip Inspection Date Longitude] -> City
# [City Inspection Date Inspection Type Longitude] -> State
# [City Inspection Date Results Longitude] -> State
# [DBA Name Inspection Type Violations Longitude] -> State
# [AKA Name Inspection Type Violations Longitude] -> State
# [City Inspection Type Violations Longitude] -> State
# [DBA Name Results Violations Longitude] -> State
# [AKA Name Results Violations Longitude] -> State
# [City Results Violations Longitude] -> State
# [Facility Type Risk Inspection Date Location] -> State
# [AKA Name Zip Inspection Date Location] -> City
# [City Inspection Date Inspection Type Location] -> State
# [City Inspection Date Results Location] -> State
# [DBA Name Inspection Type Violations Location] -> State
# [AKA Name Inspection Type Violations Location] -> State
# [City Inspection Type Violations Location] -> State
# [DBA Name Results Violations Location] -> State
# [AKA Name Results Violations Location] -> State
# [City Results Violations Location] -> State
# [DBA Name AKA Name License # Facility Type Address] -> Zip
# [DBA Name License # Facility Type Zip Inspection Type] -> City
# [DBA Name AKA Name Zip Inspection Date Inspection Type] -> City
# [DBA Name License # Zip Inspection Date Inspection Type] -> City
# [License # Facility Type Zip Inspection Date Inspection Type] -> City
# [DBA Name AKA Name License # Address Results] -> Zip
# [DBA Name AKA Name Zip Inspection Date Results] -> City
# [DBA Name Facility Type Zip Inspection Date Results] -> City
# [AKA Name License # Address Inspection Type Results] -> Zip
# [DBA Name AKA Name Facility Type Address Violations] -> Zip
# [DBA Name AKA Name License # Zip Violations] -> City
# [AKA Name License # Risk Zip Violations] -> City
# [DBA Name License # Address City Violations] -> Zip
# [DBA Name Facility Type Address City Violations] -> Zip
# [License # Facility Type Address City Violations] -> Zip
# [License # Risk Address City Violations] -> Zip
# [DBA Name AKA Name Zip Inspection Date Violations] -> City
# [License # Address Zip Inspection Date Violations] -> City
# [DBA Name License # Zip Inspection Type Violations] -> City
# [AKA Name License # Zip Inspection Type Violations] -> City
# [License # Zip Inspection Date Inspection Type Violations] -> City
# [DBA Name AKA Name Address Results Violations] -> Zip
# [DBA Name Address City Results Violations] -> Zip
# [DBA Name AKA Name License # Facility Type Latitude] -> Zip
# [DBA Name AKA Name License # Inspection Date Latitude] -> Zip
# [DBA Name License # City Inspection Date Latitude] -> Zip
# [License # Facility Type Zip Inspection Type Latitude] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Latitude] -> City
# [AKA Name Risk Inspection Date Inspection Type Latitude] -> City
# [License # Facility Type Zip Results Latitude] -> City
# [DBA Name AKA Name Inspection Date Results Latitude] -> City
# [AKA Name Risk Inspection Date Results Latitude] -> City
# [AKA Name License # Inspection Date Results Latitude] -> Zip
# [License # City Inspection Date Results Latitude] -> Zip
# [DBA Name AKA Name License # Violations Latitude] -> Zip
# [DBA Name License # City Violations Latitude] -> Zip
# [AKA Name License # Inspection Date Violations Latitude] -> Zip
# [License # City Inspection Date Violations Latitude] -> Zip
# [DBA Name AKA Name License # Facility Type Longitude] -> Zip
# [DBA Name AKA Name License # Inspection Date Longitude] -> Zip
# [DBA Name License # City Inspection Date Longitude] -> Zip
# [License # Facility Type Zip Inspection Type Longitude] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Longitude] -> City
# [AKA Name Risk Inspection Date Inspection Type Longitude] -> City
# [License # Facility Type Zip Results Longitude] -> City
# [DBA Name AKA Name Inspection Date Results Longitude] -> City
# [AKA Name Risk Inspection Date Results Longitude] -> City
# [AKA Name License # Inspection Date Results Longitude] -> Zip
# [License # City Inspection Date Results Longitude] -> Zip
# [DBA Name AKA Name License # Violations Longitude] -> Zip
# [DBA Name License # City Violations Longitude] -> Zip
# [AKA Name License # Inspection Date Violations Longitude] -> Zip
# [License # City Inspection Date Violations Longitude] -> Zip
# [DBA Name AKA Name License # Facility Type Location] -> Zip
# [DBA Name AKA Name License # Inspection Date Location] -> Zip
# [DBA Name License # City Inspection Date Location] -> Zip
# [License # Facility Type Zip Inspection Type Location] -> City
# [DBA Name AKA Name Inspection Date Inspection Type Location] -> City
# [AKA Name Risk Inspection Date Inspection Type Location] -> City
# [License # Facility Type Zip Results Location] -> City
# [DBA Name AKA Name Inspection Date Results Location] -> City
# [AKA Name Risk Inspection Date Results Location] -> City
# [AKA Name License # Inspection Date Results Location] -> Zip
# [License # City Inspection Date Results Location] -> Zip
# [DBA Name AKA Name License # Violations Location] -> Zip
# [DBA Name License # City Violations Location] -> Zip
# [AKA Name License # Inspection Date Violations Location] -> Zip
# [License # City Inspection Date Violations Location] -> Zip
# [DBA Name AKA Name Risk Zip Inspection Type Violations] -> City
# [DBA Name Facility Type Zip Inspection Date Inspection Type Violations] -> City
# [AKA Name License # City Inspection Date Results Violations] -> Zip
# [Risk City Zip Inspection Date Results Violations] -> State
# [DBA Name AKA Name Zip Inspection Type Results Violations] -> City
# [DBA Name Facility Type Zip Inspection Type Results Violations] -> City
# [DBA Name Facility Type Zip Inspection Date Inspection Type Latitude] -> City
# [DBA Name AKA Name License # Risk Results Latitude] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Latitude] -> Zip
# [AKA Name License # Risk Inspection Type Results Latitude] -> Zip
# [AKA Name License # Facility Type Risk Violations Latitude] -> Zip
# [License # Facility Type Risk City Violations Latitude] -> Zip
# [AKA Name License # Risk Inspection Type Violations Latitude] -> Zip
# [AKA Name Risk Zip Inspection Type Violations Latitude] -> City
# [License # Risk City Inspection Type Violations Latitude] -> Zip
# [AKA Name License # Risk Results Violations Latitude] -> Zip
# [License # Risk City Results Violations Latitude] -> Zip
# [AKA Name Zip Inspection Type Results Violations Latitude] -> City
# [DBA Name Facility Type Zip Inspection Date Inspection Type Longitude] -> City
# [DBA Name AKA Name License # Risk Results Longitude] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Longitude] -> Zip
# [AKA Name License # Risk Inspection Type Results Longitude] -> Zip
# [AKA Name License # Facility Type Risk Violations Longitude] -> Zip
# [License # Facility Type Risk City Violations Longitude] -> Zip
# [AKA Name License # Risk Inspection Type Violations Longitude] -> Zip
# [AKA Name Risk Zip Inspection Type Violations Longitude] -> City
# [License # Risk City Inspection Type Violations Longitude] -> Zip
# [AKA Name License # Risk Results Violations Longitude] -> Zip
# [License # Risk City Results Violations Longitude] -> Zip
# [AKA Name Zip Inspection Type Results Violations Longitude] -> City
# [DBA Name Facility Type Zip Inspection Date Inspection Type Location] -> City
# [DBA Name AKA Name License # Risk Results Location] -> Zip
# [DBA Name AKA Name License # Inspection Type Results Location] -> Zip
# [AKA Name License # Risk Inspection Type Results Location] -> Zip
# [AKA Name License # Facility Type Risk Violations Location] -> Zip
# [License # Facility Type Risk City Violations Location] -> Zip
# [AKA Name License # Risk Inspection Type Violations Location] -> Zip
# [AKA Name Risk Zip Inspection Type Violations Location] -> City
# [License # Risk City Inspection Type Violations Location] -> Zip
# [AKA Name License # Risk Results Violations Location] -> Zip
# [License # Risk City Results Violations Location] -> Zip
# [AKA Name Zip Inspection Type Results Violations Location] -> City
# [DBA Name License # Facility Type City Inspection Date Results Violations] -> Zip
# [DBA Name Facility Type Risk Zip Inspection Type Violations Latitude] -> City
# [DBA Name Facility Type Risk Zip Inspection Type Violations Longitude] -> City
# [DBA Name Facility Type Risk Zip Inspection Type Violations Location] -> City

# %% [markdown]
# ### Approximate Functional Dependencies

# %%
import desbordante.afd.algorithms as afd_algorithms

# %%
def find_afds(df:pd.DataFrame, algorithm_name:str='Default', error:float=0.1):
    """
    Finds approximate functional dependencies in a given DataFrame using a specified algorithm.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        algorithm_name (str): The name of the FD algorithm to use. Defaults to 'Default'.
    
    Returns:
        list: A list of discovered approximate functional dependencies.
    """
    try:
        # Get the algorithm class dynamically from desbordante.fd.algorithms
        algo_class = getattr(afd_algorithms, algorithm_name, afd_algorithms.Default)

        print(f"Algorthm: {algo_class}")
        
        algo = algo_class()
        algo.load_data(table=df)
        algo.execute(error=error)
        return algo.get_fds()
    except AttributeError:
        raise ValueError(f"Algorithm '{algorithm_name}' not found. Available algorithms: {dir(afd_algorithms)}")

# %% [markdown]
# **Using Default algorithm**

# %%
default_afd_results = find_afds(df)

print(f"There are {len(default_afd_results)} functional dependencies using default algorithm.")
for fd in default_afd_results:
    print(fd)
# Out:
# Algorthm: <class 'desbordante.fd.algorithms.Pyro'>
# There are 175 functional dependencies using default algorithm.
# [] -> State
# [] -> City
# [Inspection ID] -> License #
# [Inspection ID] -> DBA Name
# [Inspection ID] -> AKA Name
# [Inspection ID] -> Inspection Type
# [Inspection ID] -> Risk
# [Inspection ID] -> Address
# [Inspection ID] -> Facility Type
# [Inspection ID] -> Zip
# [Inspection ID] -> Violations
# [Inspection ID] -> Inspection Date
# [Inspection ID] -> Results
# [License #] -> Inspection ID
# [Address] -> Inspection ID
# [Inspection Date] -> Inspection ID
# [DBA Name] -> Risk
# [Latitude] -> Inspection ID
# [License #] -> Zip
# [Longitude] -> Inspection ID
# [Location] -> Inspection ID
# [License #] -> Risk
# [DBA Name] -> Inspection ID
# [Address] -> Zip
# [AKA Name] -> Inspection ID
# [Zip] -> Inspection ID
# [Violations] -> Inspection ID
# [AKA Name] -> Risk
# [License #] -> Violations
# [Latitude] -> Zip
# [DBA Name] -> Facility Type
# [License #] -> Address
# [License #] -> DBA Name
# [DBA Name] -> AKA Name
# [License #] -> Results
# [License #] -> Inspection Type
# [Address] -> License #
# [Address] -> Violations
# [Address] -> Risk
# [Longitude] -> Zip
# [License #] -> Facility Type
# [Latitude] -> Address
# [License #] -> AKA Name
# [Address] -> Inspection Type
# [Address] -> Results
# [Inspection Date] -> Violations
# [Inspection Date] -> Risk
# [Location] -> Zip
# [Address] -> Facility Type
# [Address] -> DBA Name
# [AKA Name] -> Facility Type
# [Latitude] -> License #
# [DBA Name] -> Zip
# [Latitude] -> Violations
# [Latitude] -> Risk
# [Address] -> AKA Name
# [Longitude] -> Address
# [Longitude] -> Risk
# [Longitude] -> Violations
# [Latitude] -> Facility Type
# [Latitude] -> Results
# [Longitude] -> License #
# [Location] -> Risk
# [AKA Name] -> DBA Name
# [Latitude] -> Inspection Type
# [Location] -> Address
# [Location] -> Violations
# [Zip] -> Risk
# [Inspection Date] -> Zip
# [Violations] -> Risk
# [Location] -> License #
# [License #] -> Inspection Date
# [Latitude] -> AKA Name
# [Longitude] -> Facility Type
# [DBA Name] -> Violations
# [Longitude] -> Inspection Type
# [Location] -> Facility Type
# [Latitude] -> DBA Name
# [AKA Name] -> Zip
# [Violations] -> Zip
# [Longitude] -> Results
# [Inspection Type Results] -> Risk
# [Location] -> AKA Name
# [DBA Name] -> Address
# [Inspection Date] -> Facility Type
# [Zip] -> Facility Type
# [Inspection Type Results] -> Zip
# [Violations] -> Facility Type
# [Longitude] -> DBA Name
# [Inspection Type Results] -> Facility Type
# [Facility Type Inspection Type] -> Risk
# [DBA Name] -> License #
# [Location] -> Inspection Type
# [Longitude] -> AKA Name
# [AKA Name] -> Violations
# [Location] -> Results
# [Location] -> DBA Name
# [Inspection Date] -> Address
# [Inspection Type Results] -> Inspection ID
# [Zip] -> Violations
# [Address] -> Inspection Date
# [DBA Name] -> Inspection Type
# [DBA Name] -> Results
# [AKA Name] -> Address
# [Inspection Date] -> AKA Name
# [Inspection Date] -> License #
# [Inspection Date] -> DBA Name
# [Inspection ID] -> Latitude
# [Facility Type Results] -> Risk
# [Risk Inspection Type] -> Facility Type
# [Inspection Date] -> Inspection Type
# [Zip] -> Address
# [Inspection Date] -> Results
# [Risk Results] -> Facility Type
# [Zip] -> DBA Name
# [Address] -> Latitude
# [Zip] -> AKA Name
# [AKA Name] -> License #
# [Inspection Type Results] -> Violations
# [Inspection ID] -> Longitude
# [AKA Name] -> Results
# [AKA Name] -> Inspection Type
# [Longitude] -> Latitude
# [Latitude] -> Inspection Date
# [Zip] -> License #
# [Violations] -> Address
# [Zip] -> Results
# [Violations] -> DBA Name
# [Zip] -> Inspection Type
# [Address] -> Longitude
# [Location] -> Latitude
# [Violations] -> AKA Name
# [Inspection ID] -> Location
# [Violations] -> Results
# [Violations] -> Inspection Type
# [Latitude] -> Longitude
# [License #] -> Latitude
# [Address] -> Location
# [Latitude] -> Location
# [Location] -> Longitude
# [Facility Type Risk Results] -> Inspection Type
# [Violations] -> License #
# [Longitude] -> Location
# [DBA Name] -> Latitude
# [Facility Type Risk Inspection Type] -> Results
# [Longitude] -> Inspection Date
# [License #] -> Longitude
# [License #] -> Location
# [Inspection Type Results] -> Address
# [DBA Name] -> Longitude
# [Inspection Type Results] -> DBA Name
# [Inspection Type Results] -> AKA Name
# [DBA Name] -> Location
# [Inspection Date] -> Latitude
# [AKA Name] -> Latitude
# [Location] -> Inspection Date
# [Zip] -> Latitude
# [Inspection Date] -> Location
# [Inspection Date] -> Longitude
# [Inspection Type Results] -> License #
# [Violations] -> Latitude
# [AKA Name] -> Location
# [AKA Name] -> Longitude
# [Zip] -> Location
# [Zip] -> Longitude
# [Violations] -> Longitude
# [Violations] -> Location
# [Inspection Type Results] -> Latitude
# [DBA Name] -> Inspection Date
# [Inspection Type Results] -> Longitude
# [Inspection Type Results] -> Location
# [AKA Name] -> Inspection Date
# [Zip] -> Inspection Date
# [Violations] -> Inspection Date
# [Inspection Type Results] -> Inspection Date

# %% [markdown]
# **Using TANE algorithm**

# %%
tane_afd_results = find_afds(df, algorithm_name="Tane", error=0.3)

print(f"There are {len(tane_afd_results)} functional dependencies using default algorithm.")
for fd in tane_afd_results:
    print(fd)
# Out:
# Algorthm: <class 'desbordante.fd.algorithms.Tane'>
# There are 219 functional dependencies using default algorithm.
# [] -> City
# [] -> State
# [Inspection ID] -> DBA Name
# [Inspection ID] -> AKA Name
# [Inspection ID] -> License #
# [Inspection ID] -> Facility Type
# [Inspection ID] -> Risk
# [Inspection ID] -> Address
# [Inspection ID] -> Zip
# [Inspection ID] -> Inspection Date
# [Inspection ID] -> Inspection Type
# [Inspection ID] -> Results
# [Inspection ID] -> Violations
# [Inspection ID] -> Latitude
# [Inspection ID] -> Longitude
# [Inspection ID] -> Location
# [DBA Name] -> Inspection ID
# [AKA Name] -> Inspection ID
# [DBA Name] -> AKA Name
# [AKA Name] -> DBA Name
# [License #] -> Inspection ID
# [DBA Name] -> License #
# [License #] -> DBA Name
# [AKA Name] -> License #
# [License #] -> AKA Name
# [DBA Name] -> Facility Type
# [AKA Name] -> Facility Type
# [License #] -> Facility Type
# [DBA Name] -> Risk
# [AKA Name] -> Risk
# [License #] -> Risk
# [Facility Type] -> Risk
# [Risk] -> Facility Type
# [Address] -> Inspection ID
# [DBA Name] -> Address
# [Address] -> DBA Name
# [AKA Name] -> Address
# [Address] -> AKA Name
# [License #] -> Address
# [Address] -> License #
# [Address] -> Facility Type
# [Address] -> Risk
# [Zip] -> Inspection ID
# [DBA Name] -> Zip
# [Zip] -> DBA Name
# [AKA Name] -> Zip
# [Zip] -> AKA Name
# [License #] -> Zip
# [Zip] -> License #
# [Zip] -> Facility Type
# [Zip] -> Risk
# [Address] -> Zip
# [Zip] -> Address
# [Inspection Date] -> Inspection ID
# [DBA Name] -> Inspection Date
# [Inspection Date] -> DBA Name
# [AKA Name] -> Inspection Date
# [Inspection Date] -> AKA Name
# [License #] -> Inspection Date
# [Inspection Date] -> License #
# [Inspection Date] -> Facility Type
# [Inspection Date] -> Risk
# [Address] -> Inspection Date
# [Inspection Date] -> Address
# [Zip] -> Inspection Date
# [Inspection Date] -> Zip
# [DBA Name] -> Inspection Type
# [AKA Name] -> Inspection Type
# [License #] -> Inspection Type
# [Inspection Type] -> Facility Type
# [Inspection Type] -> Risk
# [Address] -> Inspection Type
# [Zip] -> Inspection Type
# [Inspection Date] -> Inspection Type
# [DBA Name] -> Results
# [AKA Name] -> Results
# [License #] -> Results
# [Results] -> Facility Type
# [Results] -> Risk
# [Address] -> Results
# [Zip] -> Results
# [Inspection Date] -> Results
# [Inspection Type] -> Results
# [Results] -> Inspection Type
# [Violations] -> Inspection ID
# [DBA Name] -> Violations
# [Violations] -> DBA Name
# [AKA Name] -> Violations
# [Violations] -> AKA Name
# [License #] -> Violations
# [Violations] -> License #
# [Violations] -> Facility Type
# [Violations] -> Risk
# [Address] -> Violations
# [Violations] -> Address
# [Zip] -> Violations
# [Violations] -> Zip
# [Inspection Date] -> Violations
# [Violations] -> Inspection Date
# [Inspection Type] -> Violations
# [Violations] -> Inspection Type
# [Violations] -> Results
# [Latitude] -> Inspection ID
# [DBA Name] -> Latitude
# [Latitude] -> DBA Name
# [AKA Name] -> Latitude
# [Latitude] -> AKA Name
# [License #] -> Latitude
# [Latitude] -> License #
# [Latitude] -> Facility Type
# [Latitude] -> Risk
# [Address] -> Latitude
# [Latitude] -> Address
# [Zip] -> Latitude
# [Latitude] -> Zip
# [Inspection Date] -> Latitude
# [Latitude] -> Inspection Date
# [Latitude] -> Inspection Type
# [Latitude] -> Results
# [Violations] -> Latitude
# [Latitude] -> Violations
# [Longitude] -> Inspection ID
# [DBA Name] -> Longitude
# [Longitude] -> DBA Name
# [AKA Name] -> Longitude
# [Longitude] -> AKA Name
# [License #] -> Longitude
# [Longitude] -> License #
# [Longitude] -> Facility Type
# [Longitude] -> Risk
# [Address] -> Longitude
# [Longitude] -> Address
# [Zip] -> Longitude
# [Longitude] -> Zip
# [Inspection Date] -> Longitude
# [Longitude] -> Inspection Date
# [Longitude] -> Inspection Type
# [Longitude] -> Results
# [Violations] -> Longitude
# [Longitude] -> Violations
# [Latitude] -> Longitude
# [Longitude] -> Latitude
# [Location] -> Inspection ID
# [DBA Name] -> Location
# [Location] -> DBA Name
# [AKA Name] -> Location
# [Location] -> AKA Name
# [License #] -> Location
# [Location] -> License #
# [Location] -> Facility Type
# [Location] -> Risk
# [Address] -> Location
# [Location] -> Address
# [Zip] -> Location
# [Location] -> Zip
# [Inspection Date] -> Location
# [Location] -> Inspection Date
# [Location] -> Inspection Type
# [Location] -> Results
# [Violations] -> Location
# [Location] -> Violations
# [Latitude] -> Location
# [Location] -> Latitude
# [Longitude] -> Location
# [Location] -> Longitude
# [Facility Type Inspection Type] -> Inspection ID
# [Facility Type Inspection Type] -> DBA Name
# [Facility Type Inspection Type] -> AKA Name
# [Facility Type Inspection Type] -> License #
# [Risk Inspection Type] -> Inspection ID
# [Risk Inspection Type] -> DBA Name
# [Risk Inspection Type] -> AKA Name
# [Risk Inspection Type] -> License #
# [Facility Type Risk] -> Inspection Type
# [Facility Type Inspection Type] -> Address
# [Risk Inspection Type] -> Address
# [Facility Type Inspection Type] -> Zip
# [Risk Inspection Type] -> Zip
# [Facility Type Inspection Type] -> Inspection Date
# [Risk Inspection Type] -> Inspection Date
# [Facility Type Results] -> Inspection ID
# [Facility Type Results] -> DBA Name
# [Facility Type Results] -> AKA Name
# [Facility Type Results] -> License #
# [Risk Results] -> Inspection ID
# [Risk Results] -> DBA Name
# [Risk Results] -> AKA Name
# [Risk Results] -> License #
# [Facility Type Risk] -> Results
# [Facility Type Results] -> Address
# [Risk Results] -> Address
# [Facility Type Results] -> Zip
# [Risk Results] -> Zip
# [Facility Type Results] -> Inspection Date
# [Risk Results] -> Inspection Date
# [Inspection Type Results] -> Inspection ID
# [Inspection Type Results] -> DBA Name
# [Inspection Type Results] -> AKA Name
# [Inspection Type Results] -> License #
# [Inspection Type Results] -> Address
# [Inspection Type Results] -> Zip
# [Inspection Type Results] -> Inspection Date
# [Facility Type Results] -> Violations
# [Risk Results] -> Violations
# [Facility Type Inspection Type] -> Latitude
# [Risk Inspection Type] -> Latitude
# [Facility Type Results] -> Latitude
# [Risk Results] -> Latitude
# [Inspection Type Results] -> Latitude
# [Facility Type Inspection Type] -> Longitude
# [Risk Inspection Type] -> Longitude
# [Facility Type Results] -> Longitude
# [Risk Results] -> Longitude
# [Inspection Type Results] -> Longitude
# [Facility Type Inspection Type] -> Location
# [Risk Inspection Type] -> Location
# [Facility Type Results] -> Location
# [Risk Results] -> Location
# [Inspection Type Results] -> Location
