# %% [markdown]
# ## Dataset EDA Notebook

# %%
import pandas as pd

from thefuzz import process

# %%
file_path = "../../data/Food_Inspections_20250216.csv"
df = pd.read_csv(file_path, header=[0])
df.head()
# Out:
#    Inspection ID                    DBA Name                    AKA Name  \
# 0        1106427        BLOOMING BUD DAYCARE        BLOOMING BUD DAYCARE
# 1        2608378                 Babas Halal                 Babas Halal
# 2        1106406    FIRST ZABIHA MEAT BAZAAR    FIRST ZABIHA MEAT BAZAAR
# 3        2609909                HAPPY MARKET                HAPPY MARKET
# 4        2609927  SAT KAIVAL FOOD INC/SUBWAY  SAT KAIVAL FOOD INC/SUBWAY
#
#    License #       Facility Type             Risk               Address  \
# 0  2215789.0  Daycare Combo 1586    Risk 1 (High)    5715 N LINCOLN AVE
# 1  2684170.0          Restaurant    Risk 1 (High)      7901 S DAMEN AVE
# 2  2232559.0       Grocery Store  Risk 2 (Medium)      2907 W DEVON AVE
# 3  2912802.0       Grocery Store  Risk 2 (Medium)  2334 S WENTWORTH AVE
# 4  2728400.0          Restaurant    Risk 1 (High)       1916 S STATE ST
#
#       City State      Zip Inspection Date Inspection Type             Results  \
# 0  CHICAGO    IL  60659.0      03/07/2013         License                Pass
# 1  CHICAGO    IL  60620.0      12/03/2024       Complaint                Fail
# 2  CHICAGO    IL  60659.0      02/20/2013         License                Fail
# 3  CHICAGO    IL  60616.0      01/02/2025         Canvass  Pass w/ Conditions
# 4  CHICAGO    IL  60616.0      01/02/2025         Canvass                Pass
#
#                                           Violations   Latitude  Longitude  \
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.985390 -87.698734
# 1  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.750189 -87.672986
# 2  11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  41.997401 -87.702385
# 3  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.849954 -87.632094
# 4  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.856053 -87.627311
#
#                                    Location
# 0   (41.98538950526786, -87.69873407149943)
# 1  (41.750189342293375, -87.67298583977204)
# 2   (41.99740137039031, -87.70238538227812)
# 3   (41.84995400192252, -87.63209419559098)
# 4   (41.85605269621059, -87.62731125804903)

# %%
# renaming column names to snake_case
COLUMN_NAMES = [
    'inspection_id',
    'dba_name',
    'aka_name',
    'license_',
    'facility_type',
    'risk',
    'address',
    'city',
    'state',
    'zip',
    'inspection_date',
    'inspection_type',
    'results',
    'violations',
    'latitude',
    'longitude',
    'location'
]

df.columns = COLUMN_NAMES

# %% [markdown]
# ### Summary Statistics

# %%
def calculate_summary_stats(df, column_name):


    if column_name in df.columns:
        num_records = len(df)
        num_na = df[column_name].isna().sum()
        num_unique = df[column_name].nunique()

        print(f"Summary stats for '{column_name}'")
        print(f"Missing:         {num_na} ({round(num_na/num_records,1)}%)")
        print(f"Distinct:        {num_unique} ({round(num_unique/num_records,1)}%)")
        print("\n")
    
    else:
        print(f"{column_name} is not in dataframe")

# %%
for column in COLUMN_NAMES:
    calculate_summary_stats(df, column)
# Out:
# Summary stats for 'inspection_id'
# Missing:         0 (0.0%)
# Distinct:        287237 (1.0%)
#
#
# Summary stats for 'dba_name'
# Missing:         0 (0.0%)
# Distinct:        33304 (0.1%)
#
#
# Summary stats for 'aka_name'
# Missing:         2426 (0.0%)
# Distinct:        31703 (0.1%)
#
#
# Summary stats for 'license_'
# Missing:         18 (0.0%)
# Distinct:        46274 (0.2%)
#
#
# Summary stats for 'facility_type'
# Missing:         5197 (0.0%)
# Distinct:        519 (0.0%)
#
#
# Summary stats for 'risk'
# Missing:         88 (0.0%)
# Distinct:        4 (0.0%)
#
#
# Summary stats for 'address'
# Missing:         0 (0.0%)
# Distinct:        30905 (0.1%)
#
#
# Summary stats for 'city'
# Missing:         164 (0.0%)
# Distinct:        86 (0.0%)
#
#
# Summary stats for 'state'
# Missing:         58 (0.0%)
# Distinct:        6 (0.0%)
#
#
# Summary stats for 'zip'
# Missing:         39 (0.0%)
# Distinct:        127 (0.0%)
#
#
# Summary stats for 'inspection_date'
# Missing:         0 (0.0%)
# Distinct:        3813 (0.0%)
#
#
# Summary stats for 'inspection_type'
# Missing:         1 (0.0%)
# Distinct:        110 (0.0%)
#
#
# Summary stats for 'results'
# Missing:         0 (0.0%)
# Distinct:        7 (0.0%)
#
#
# Summary stats for 'violations'
# Missing:         79652 (0.3%)
# Distinct:        206183 (0.7%)
#
#
# Summary stats for 'latitude'
# Missing:         978 (0.0%)
# Distinct:        18493 (0.1%)
#
#
# Summary stats for 'longitude'
# Missing:         978 (0.0%)
# Distinct:        18493 (0.1%)
#
#
# Summary stats for 'location'
# Missing:         978 (0.0%)
# Distinct:        18493 (0.1%)

# %% [markdown]
# ### Inspection ID

# %% [markdown]
# Check if inspection_id is a UUID

# %%
if df['inspection_id'].nunique() == len(df):
    print("Number of records matches the total distinct inspection IDs")
# Out:
# Number of records matches the total distinct inspection IDs

# %% [markdown]
# inspection_id is indeed UUID, this field is unnecessary for FDs

# %% [markdown]
# ### DBA Name and AKA Name
#
# The description for DBA is Doing Business As, and for AKA its Also Known As. Since both are essentially variations of the business name, only one of them is necessary

# %% [markdown]
# Since there are missing values for 'aka_name', lets drop this and use dba_name instead

# %% [markdown]
# ### Location Details
#
# Address, City, State, Zip

# %%
df['state'].nunique()
# Out:
# 6

# %% [markdown]
# Since the missing values for city, state and zip are less than 0.1% of the entire dataset, they can be dropped

# %% [markdown]
# zip is currently a float, it should be an integer

# %% [markdown]
# ### License

# %%
df['license_'].nunique()
# Out:
# 46274

# %%
df.groupby(by='license_')['license_'].count().reset_index(name="count")
# Out:
#         license_  count
# 0            0.0    743
# 1            1.0      1
# 2            2.0     17
# 3            9.0     15
# 4           40.0     21
# ...          ...    ...
# 46269  4080337.0      1
# 46270  4080354.0      1
# 46271  5852857.0      1
# 46272  8700606.0      3
# 46273  9999999.0      1
#
# [46274 rows x 2 columns]

# %%
import pandas as pd
from thefuzz import process, fuzz
from collections import defaultdict

def fuzzy_normalize_column(df, column_name, threshold=80):
    """
    Normalize text values in a DataFrame column using fuzzy matching.
    
    Args:
    - df (pd.DataFrame): Input DataFrame.
    - column_name (str): Column name to normalize.
    - threshold (int): Similarity threshold for fuzzy matching (default is 80).
    
    Returns:
    - pd.DataFrame: DataFrame with a new normalized column.
    """
    df[column_name] = df[column_name].astype(str).fillna('')  # Convert to string

    unique_values = list(set(df[column_name].str.lower()))  # Unique values in lowercase

    # Reference mapping for normalization
    reference_mapping = {}
    groups = defaultdict(list)  # To store word clusters

    for value in unique_values:
        # Check if it's already in a group
        if value in reference_mapping:
            continue
        
        # Find similar words
        matches = process.extract(value, unique_values, limit=10, scorer=fuzz.ratio)
        matches = [(match, score) for match, score in matches if score >= threshold]
        
        if matches:
            best_match = max(matches, key=lambda x: x[1])[0]  # Pick the best-scoring match
        else:
            best_match = value  # Keep original if no good match found

        # Assign all similar words to the best match
        for match, score in matches:
            reference_mapping[match] = best_match
            groups[best_match].append(match)

    # Apply normalization mapping
    df[f'{column_name}_normalised'] = df[column_name].str.lower().map(reference_mapping)
    
    return df

# %%
df.groupby(by='risk')['risk'].count().reset_index(name="count")
# Out:
#               risk   count
# 0              All      68
# 1    Risk 1 (High)  211761
# 2  Risk 2 (Medium)   52347
# 3     Risk 3 (Low)   22973

# %% [markdown]
# ### Facility Type

# %% [markdown]
# ### Geographic Coordinates
#
# Latitude, Longitude and Location

# %% [markdown]
# Location appears to be a tuple of latitude and longtitude values. Since most geographic systems uses lat and lon as separate values, lets drop Location.
#
# There are 978 records with missing coordinates, which is less than 0.1% of the dataset. These records can be dropped.

# %% [markdown]
# ## Performing preprocessing
#
# - Rename columns
# - Drop the following columns - inspection_id, aka_name, location
# - Drop missing records for city, state, zip, latitude, longitude
# - Fix data type
#   - license: float -> int
#   - zip: float -> int

# %%
# renaming column names to snake_case
COLUMN_NAMES = [
    'inspection_id',
    'dba_name',
    'aka_name',
    'license_',
    'facility_type',
    'risk',
    'address',
    'city',
    'state',
    'zip',
    'inspection_date',
    'inspection_type',
    'results',
    'violations',
    'latitude',
    'longitude',
    'location'
]

df.columns = COLUMN_NAMES

# drop columns
df.drop(['inspection_id', 'aka_name', 'location'], axis=1, inplace=True)

# drop missing values
df.dropna(subset=['city', 'state', 'zip', 'latitude', 'longitude'], inplace=True)

# fix data type
df = df.astype({'zip':'Int64', 'license_':'Int64'})

# consolidate redundant values using fuzzy matching
df = fuzzy_normalize_column(df, 'inspection_type', threshold=70)

# %%
df
# Out:
#                                   dba_name  license_       facility_type  \
# 0                     BLOOMING BUD DAYCARE   2215789  Daycare Combo 1586
# 1                              Babas Halal   2684170          Restaurant
# 2                 FIRST ZABIHA MEAT BAZAAR   2232559       Grocery Store
# 3                             HAPPY MARKET   2912802       Grocery Store
# 4               SAT KAIVAL FOOD INC/SUBWAY   2728400          Restaurant
# ...                                    ...       ...                 ...
# 287232            DAPPER'S EAST RESTAURANT     12540          Restaurant
# 287233                           SHARPIE'S   3002203          Restaurant
# 287234            ACE SUSHI @POTASH MARKET   2808766          Restaurant
# 287235                Kitchen Chicago, LLC   2119905      Shared Kitchen
# 287236  HANNAH'S BRETZEL 227 W. MONROE LLC   2428372          Restaurant
#
#                    risk               address     city state    zip  \
# 0         Risk 1 (High)    5715 N LINCOLN AVE  CHICAGO    IL  60659
# 1         Risk 1 (High)      7901 S DAMEN AVE  CHICAGO    IL  60620
# 2       Risk 2 (Medium)      2907 W DEVON AVE  CHICAGO    IL  60659
# 3       Risk 2 (Medium)  2334 S WENTWORTH AVE  CHICAGO    IL  60616
# 4         Risk 1 (High)       1916 S STATE ST  CHICAGO    IL  60616
# ...                 ...                   ...      ...   ...    ...
# 287232    Risk 1 (High)     2901 W ADDISON ST  CHICAGO    IL  60618
# 287233     Risk 3 (Low)     1721 N ELSTON AVE  CHICAGO    IL  60642
# 287234    Risk 1 (High)        875 N STATE ST  CHICAGO    IL  60610
# 287235    Risk 1 (High)      324 N LEAVITT ST  CHICAGO    IL  60612
# 287236    Risk 1 (High)       227 W MONROE ST  CHICAGO    IL  60606
#
#        inspection_date          inspection_type             results  \
# 0           03/07/2013                  License                Pass
# 1           12/03/2024                Complaint                Fail
# 2           02/20/2013                  License                Fail
# 3           01/02/2025                  Canvass  Pass w/ Conditions
# 4           01/02/2025                  Canvass                Pass
# ...                ...                      ...                 ...
# 287232      01/23/2025  Complaint Re-Inspection                Pass
# 287233      01/22/2025                  License           Not Ready
# 287234      01/13/2025                  Canvass                Pass
# 287235      01/22/2025                  Canvass                Pass
# 287236      01/06/2025                  Canvass                Pass
#
#                                                violations   latitude  \
# 0       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.985390
# 1       1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.750189
# 2       11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  41.997401
# 3       2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.849954
# 4       36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.856053
# ...                                                   ...        ...
# 287232  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  41.946553
# 287233                                                NaN  41.913729
# 287234  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.898878
# 287235  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  41.887434
# 287236  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.880539
#
#         longitude inspection_type_normalised
# 0      -87.698734                    license
# 1      -87.672986            covid complaint
# 2      -87.702385                    license
# 3      -87.632094                     canvas
# 4      -87.627311                     canvas
# ...           ...                        ...
# 287232 -87.700536             non-inspection
# 287233 -87.664223                    license
# 287234 -87.628111                     canvas
# 287235 -87.681849                     canvas
# 287236 -87.634592                     canvas
#
# [286054 rows x 15 columns]

# %%
violation_test = df.violations.iloc[0]
violation_test
# Out:
# '32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: PROVIDE A DRAIN BOARD AT THREE COMPARTMENT SINK. | 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: OBSERVED RUSTY GREASE TRAP UNDER THE THREE COMPARTMENT SINK, INSTRUCTED TO PAINT AND MAINTAIN.  PROVIDE SPLASH GUARD BETWEEN THE  EXPOSED HAND SINK ON BOTH SIDE AND PREP COUNTER | 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: INSTRUCTED TO SWEEP FLOOR INSIDE THE FURNACE AREA.  OBSERVED AT SECOND FLOOR UNUSED CLASSROOMS WITH ITEMS STORED ON FLOOR, INSTRUCTED TO ELEVATE 6" OFF THE FLOOR,AND ORGANIZE AREA.  RESEAL BASEBOARD UNDER THE THREE COMPARTMENT SINK IN KITCHEN. | 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: OBSERVED DEAD BULB IN THE KITCHEN, INSTRUCTED TO REPLACE AND PROVIDE LIGHT SHIELD AT SAID FIXTURE'

# %%
split_list
# Out:
# ['32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: PROVIDE A DRAIN BOARD AT THREE COMPARTMENT SINK. ',
#  ' 32. FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED - Comments: OBSERVED RUSTY GREASE TRAP UNDER THE THREE COMPARTMENT SINK, INSTRUCTED TO PAINT AND MAINTAIN.  PROVIDE SPLASH GUARD BETWEEN THE  EXPOSED HAND SINK ON BOTH SIDE AND PREP COUNTER ',
#  ' 34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED - Comments: INSTRUCTED TO SWEEP FLOOR INSIDE THE FURNACE AREA.  OBSERVED AT SECOND FLOOR UNUSED CLASSROOMS WITH ITEMS STORED ON FLOOR, INSTRUCTED TO ELEVATE 6" OFF THE FLOOR,AND ORGANIZE AREA.  RESEAL BASEBOARD UNDER THE THREE COMPARTMENT SINK IN KITCHEN. ',
#  ' 35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS - Comments: OBSERVED DEAD BULB IN THE KITCHEN, INSTRUCTED TO REPLACE AND PROVIDE LIGHT SHIELD AT SAID FIXTURE']

# %%
df.inspection_type
# Out:
# 0                         License
# 1                       Complaint
# 2                         License
# 3                         Canvass
# 4                         Canvass
#                    ...
# 287232    Complaint Re-Inspection
# 287233                    License
# 287234                    Canvass
# 287235                    Canvass
# 287236                    Canvass
# Name: inspection_type, Length: 286054, dtype: object

# %%
def extract_violation_codes(x):

    split_list = str(x).split("|")

    return set([int(violation.strip().split(" ")[0][:-1]) for violation in split_list])

# %%
df['violation_code_set'] = df['violations'].apply(lambda x: extract_violation_codes(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df['violation_code_set'] = df['violations'].apply(lambda x: extract_violation_codes(x))
#
# File ~/Documents/GitHub/ntu-msds-sd6104/.venv/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/Documents/GitHub/ntu-msds-sd6104/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Documents/GitHub/ntu-msds-sd6104/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/GitHub/ntu-msds-sd6104/.venv/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Documents/GitHub/ntu-msds-sd6104/.venv/lib/python3.10/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[52], line 1, in <lambda>(x)
# ----> 1 df['violation_code_set'] = df['violations'].apply(lambda x: extract_violation_codes(x))
#
# Cell In[51], line 5, in extract_violation_codes(x)
#       1 def extract_violation_codes(x):
#       3     split_list = str(x).split("|")
# ----> 5     return set([int(violation.strip().split(" ")[0][:-1]) for violation in split_list])
#
# Cell In[51], line 5, in <listcomp>(.0)
#       1 def extract_violation_codes(x):
#       3     split_list = str(x).split("|")
# ----> 5     return set([int(violation.strip().split(" ")[0][:-1]) for violation in split_list])
#
# ValueError: invalid literal for int() with base 10: 'na'

# %%
violation_test = df.violations.iloc[0]
split_list = violation_test.split("|")


set([int(violation.strip().split(" ")[0][:-1]) for violation in split_list])
# Out:
# {32, 34, 35}

# %%
for column in COLUMN_NAMES:
    calculate_summary_stats(df, column)
# Out:
# inspection_id is not in dataframe
# Summary stats for 'dba_name'
# Missing:         0 (0.0%)
# Distinct:        33107 (0.1%)
#
#
# aka_name is not in dataframe
# Summary stats for 'license_'
# Missing:         18 (0.0%)
# Distinct:        45990 (0.2%)
#
#
# Summary stats for 'facility_type'
# Missing:         5161 (0.0%)
# Distinct:        513 (0.0%)
#
#
# Summary stats for 'risk'
# Missing:         82 (0.0%)
# Distinct:        4 (0.0%)
#
#
# Summary stats for 'address'
# Missing:         0 (0.0%)
# Distinct:        30636 (0.1%)
#
#
# Summary stats for 'city'
# Missing:         0 (0.0%)
# Distinct:        23 (0.0%)
#
#
# Summary stats for 'state'
# Missing:         0 (0.0%)
# Distinct:        1 (0.0%)
#
#
# Summary stats for 'zip'
# Missing:         0 (0.0%)
# Distinct:        66 (0.0%)
#
#
# Summary stats for 'inspection_date'
# Missing:         0 (0.0%)
# Distinct:        3812 (0.0%)
#
#
# Summary stats for 'inspection_type'
# Missing:         0 (0.0%)
# Distinct:        110 (0.0%)
#
#
# Summary stats for 'results'
# Missing:         0 (0.0%)
# Distinct:        7 (0.0%)
#
#
# Summary stats for 'violations'
# Missing:         79255 (0.3%)
# Distinct:        205410 (0.7%)
#
#
# Summary stats for 'latitude'
# Missing:         0 (0.0%)
# Distinct:        18460 (0.1%)
#
#
# Summary stats for 'longitude'
# Missing:         0 (0.0%)
# Distinct:        18460 (0.1%)
#
#
# location is not in dataframe

# %% [markdown]
# ## Summary Findings
#
# - Removal of rows with null values led to the attribute state having only 1 unique value - this implies that records from other states have faulty data

# %%
import pandas as pd

# %%
file_path = "../../data/Food_Inspections_Violations_Expanded_with_cleandata.csv"
df = pd.read_csv(file_path, header=[0])
df.head()
# Out:
#    Inspection ID              DBA Name              AKA Name  License #  \
# 0        1106427  BLOOMING BUD DAYCARE  BLOOMING BUD DAYCARE  2215789.0
# 1        1106427  BLOOMING BUD DAYCARE  BLOOMING BUD DAYCARE  2215789.0
# 2        1106427  BLOOMING BUD DAYCARE  BLOOMING BUD DAYCARE  2215789.0
# 3        1106427  BLOOMING BUD DAYCARE  BLOOMING BUD DAYCARE  2215789.0
# 4        2608378           Babas Halal           Babas Halal  2684170.0
#
#         Facility Type           Risk             Address     City State  \
# 0  DAYCARE COMBO 1586  Risk 1 (High)  5715 N LINCOLN AVE  CHICAGO    IL
# 1  DAYCARE COMBO 1586  Risk 1 (High)  5715 N LINCOLN AVE  CHICAGO    IL
# 2  DAYCARE COMBO 1586  Risk 1 (High)  5715 N LINCOLN AVE  CHICAGO    IL
# 3  DAYCARE COMBO 1586  Risk 1 (High)  5715 N LINCOLN AVE  CHICAGO    IL
# 4          RESTAURANT  Risk 1 (High)    7901 S DAMEN AVE  CHICAGO    IL
#
#        Zip  ...                                  Location  \
# 0  60659.0  ...   (41.98538950526786, -87.69873407149943)
# 1  60659.0  ...   (41.98538950526786, -87.69873407149943)
# 2  60659.0  ...   (41.98538950526786, -87.69873407149943)
# 3  60659.0  ...   (41.98538950526786, -87.69873407149943)
# 4  60620.0  ...  (41.750189342293375, -87.67298583977204)
#
#   Facility Type Cleaned City Cleaned  Inspection Type Cleaned  \
# 0    DAYCARE COMBO 1586      CHICAGO                  LICENSE
# 1    DAYCARE COMBO 1586      CHICAGO                  LICENSE
# 2    DAYCARE COMBO 1586      CHICAGO                  LICENSE
# 3    DAYCARE COMBO 1586      CHICAGO                  LICENSE
# 4            RESTAURANT      CHICAGO                COMPLAINT
#
#                                        raw_violation violation_number  \
# 0  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...             32.0
# 1  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...             32.0
# 2  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...             34.0
# 3  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...             35.0
# 4  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...              1.0
#
#                                       violation_text  \
# 0  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 1  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 2  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 3  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 4  PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLED...
#
#                                    violation_comment parse_error error_reason
# 0   PROVIDE A DRAIN BOARD AT THREE COMPARTMENT SINK.       False          NaN
# 1  OBSERVED RUSTY GREASE TRAP UNDER THE THREE COM...       False          NaN
# 2  INSTRUCTED TO SWEEP FLOOR INSIDE THE FURNACE A...       False          NaN
# 3  OBSERVED DEAD BULB IN THE KITCHEN, INSTRUCTED ...       False          NaN
# 4  PIC DOESN'T HAVE A CERTIFIED FOOD MANAGERS CER...       False          NaN
#
# [5 rows x 25 columns]

# %%
col_names = ["_".join(col.lower().split(' ')) for col in df.columns]
df.columns = col_names

# %%
df.columns
# Out:
# Index(['inspection_id', 'dba_name', 'aka_name', 'license_#', 'facility_type',
#        'risk', 'address', 'city', 'state', 'zip', 'inspection_date',
#        'inspection_type', 'results', 'latitude', 'longitude', 'location',
#        'facility_type_cleaned', 'city_cleaned', 'inspection_type_cleaned',
#        'raw_violation', 'violation_number', 'violation_text',
#        'violation_comment', 'parse_error', 'error_reason'],
#       dtype='object')

# %%
new_df = df.drop(
    ['inspection_id','aka_name','facility_type','city','inspection_type','raw_violation','violation_text','location','violation_comment','error_reason','parse_error','state'],axis=1
)

# %%
# drop missing values
new_df.dropna(subset=['city_cleaned', 'zip', 'latitude', 'longitude'], inplace=True)

# fix data type
new_df = new_df.astype({'zip':'Int64', 'license_#':'Int64', 'violation_number':'Int64'})

# %%
new_df
# Out:
#                                   dba_name  license_#           risk  \
# 0                     BLOOMING BUD DAYCARE    2215789  Risk 1 (High)
# 1                     BLOOMING BUD DAYCARE    2215789  Risk 1 (High)
# 2                     BLOOMING BUD DAYCARE    2215789  Risk 1 (High)
# 3                     BLOOMING BUD DAYCARE    2215789  Risk 1 (High)
# 4                              Babas Halal    2684170  Risk 1 (High)
# ...                                    ...        ...            ...
# 939275            ACE SUSHI @POTASH MARKET    2808766  Risk 1 (High)
# 939276            ACE SUSHI @POTASH MARKET    2808766  Risk 1 (High)
# 939277                Kitchen Chicago, LLC    2119905  Risk 1 (High)
# 939278                Kitchen Chicago, LLC    2119905  Risk 1 (High)
# 939279  HANNAH'S BRETZEL 227 W. MONROE LLC    2428372  Risk 1 (High)
#
#                    address    zip inspection_date results   latitude  \
# 0       5715 N LINCOLN AVE  60659        3/7/2013    Pass  41.985390
# 1       5715 N LINCOLN AVE  60659        3/7/2013    Pass  41.985390
# 2       5715 N LINCOLN AVE  60659        3/7/2013    Pass  41.985390
# 3       5715 N LINCOLN AVE  60659        3/7/2013    Pass  41.985390
# 4         7901 S DAMEN AVE  60620       12/3/2024    Fail  41.750189
# ...                    ...    ...             ...     ...        ...
# 939275      875 N STATE ST  60610       1/13/2025    Pass  41.898878
# 939276      875 N STATE ST  60610       1/13/2025    Pass  41.898878
# 939277    324 N LEAVITT ST  60612       1/22/2025    Pass  41.887434
# 939278    324 N LEAVITT ST  60612       1/22/2025    Pass  41.887434
# 939279     227 W MONROE ST  60606        1/6/2025    Pass  41.880539
#
#         longitude facility_type_cleaned city_cleaned inspection_type_cleaned  \
# 0      -87.698734    DAYCARE COMBO 1586      CHICAGO                 LICENSE
# 1      -87.698734    DAYCARE COMBO 1586      CHICAGO                 LICENSE
# 2      -87.698734    DAYCARE COMBO 1586      CHICAGO                 LICENSE
# 3      -87.698734    DAYCARE COMBO 1586      CHICAGO                 LICENSE
# 4      -87.672986            RESTAURANT      CHICAGO               COMPLAINT
# ...           ...                   ...          ...                     ...
# 939275 -87.628111            RESTAURANT      CHICAGO                 CANVASS
# 939276 -87.628111            RESTAURANT      CHICAGO                 CANVASS
# 939277 -87.681849        SHARED KITCHEN      CHICAGO                 CANVASS
# 939278 -87.681849        SHARED KITCHEN      CHICAGO                 CANVASS
# 939279 -87.634592            RESTAURANT      CHICAGO                 CANVASS
#
#         violation_number
# 0                     32
# 1                     32
# 2                     34
# 3                     35
# 4                      1
# ...                  ...
# 939275                55
# 939276                58
# 939277                49
# 939278                55
# 939279                37
#
# [936839 rows x 13 columns]

# %%
new_df.to_parquet("../../data/Food_Inspections_Violations_Expanded_with_cleandata.parquet")

# %%
from collections import defaultdict
from thefuzz import process, fuzz

# %%
def fuzzy_normalize_column(df, column_name, threshold=80):
    """
    Normalize text values in a DataFrame column using fuzzy matching.
    
    Args:
    - df (pd.DataFrame): Input DataFrame.
    - column_name (str): Column name to normalize.
    - threshold (int): Similarity threshold for fuzzy matching (default is 80).
    
    Returns:
    - pd.DataFrame: DataFrame with a new normalized column.
    """
    df[column_name] = df[column_name].astype(str).fillna('')  # Convert to string

    unique_values = list(set(df[column_name].str.lower()))  # Unique values in lowercase

    # Reference mapping for normalization
    reference_mapping = {}
    groups = defaultdict(list)  # To store word clusters

    for value in unique_values:
        # Check if it's already in a group
        if value in reference_mapping:
            continue
        
        # Find similar words
        matches = process.extract(value, unique_values, limit=10, scorer=fuzz.ratio)
        matches = [(match, score) for match, score in matches if score >= threshold]
        
        if matches:
            best_match = max(matches, key=lambda x: x[1])[0]  # Pick the best-scoring match
        else:
            best_match = value  # Keep original if no good match found

        # Assign all similar words to the best match
        for match, score in matches:
            reference_mapping[match] = best_match
            groups[best_match].append(match)

    # Apply normalization mapping
    df[f'{column_name}'] = df[column_name].str.lower().map(reference_mapping)
    
    return df

# %%
new_df1 = fuzzy_normalize_column(new_df, 'address')

# %%
new_df.address.nunique()
# Out:
# 6778

# %%
new_df1.address.nunique()
# Out:
# 6778
